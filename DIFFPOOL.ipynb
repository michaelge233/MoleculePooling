# %%
import torch
import random
import pandas as pd
import torch
from torch_geometric.utils import from_smiles
import random
import pandas as pd
import numpy as np
from tqdm import tqdm




def split_list(input_list, ratio):
    input_list_copy = input_list.copy()
    total_length = len(input_list_copy)
    a_length = int(ratio[0] * total_length)
    b_length = int(ratio[1] * total_length)
    
    #random.seed(random_state)
    random.shuffle(input_list_copy)
    part_a = input_list_copy[:a_length]
    part_b = input_list_copy[a_length:a_length + b_length]
    part_c = input_list_copy[a_length + b_length:]

    return part_a, part_b, part_c

def load_dataset(filename,x_name,y_name1,y_name2):
    table=pd.read_csv(filename)
    result=[]
    for i in tqdm(range(table.shape[0])):
        cur_data=from_smiles(table[x_name][i])
        cur_data.y=torch.tensor([[table[y_name1][i],table[y_name2][i]]],dtype=torch.float32)
        result.append(cur_data)
    return result

def load_splited_dataset(filename,x_name,y_name1,y_name2,ratio=(0.8,0.1,0.1)):
    all_list=load_dataset(filename,x_name,y_name1,y_name2)
    return split_list(all_list,ratio)

# %%
import torch
from torch.nn import Linear, ReLU
from torch_geometric.nn import DenseGCNConv, global_mean_pool,dense_diff_pool

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels,normalize=False,lin=True):
        super(GNN, self).__init__()
        
        self.convs = torch.nn.ModuleList()
        self.convs.append(DenseGCNConv(in_channels, hidden_channels,normalize))
        self.convs.append(DenseGCNConv(hidden_channels, out_channels,normalize))
        self.act=ReLU()

    def forward(self, x, adj, mask=None):
        
        for step in range(len(self.convs)):
            x = self.act(self.convs[step](x, adj))
        
        return x



class DiffPool(torch.nn.Module):
    def __init__(self,in_channels, hidden_channels=32, out_channels=2,num_nodes=3):
        super(DiffPool, self).__init__()

        self.gnn1_pool = GNN(in_channels, hidden_channels, num_nodes)
        self.gnn1_embed = GNN(in_channels, hidden_channels, hidden_channels)

        self.gnn2_embed = GNN(hidden_channels, hidden_channels, hidden_channels)

        self.lin1 = torch.nn.Linear(hidden_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, out_channels)
        self.act=ReLU()

    def forward(self, x, adj, mask=None):
        s = self.gnn1_pool(x, adj, mask)
        x = self.gnn1_embed(x, adj, mask)

        x, adj, l1, e1 = dense_diff_pool(x, adj, s, mask)

        x = self.gnn2_embed(x, adj)

        x = x.mean(dim=1)
        x = self.act(self.lin1(x))
        x = self.lin2(x)
        return x

# %%
from torch_geometric.utils import to_dense_batch,to_dense_adj

def train(model, loader, optimizer, loss_func):

    model.train()
    mae=0
    for data in loader:
        data.x=to_dense_batch(data.x,batch=data.batch,max_num_nodes=max_nodes)[0].float()
        data.adj=to_dense_adj(data.edge_index,batch=data.batch,max_num_nodes=max_nodes)
        data=data.cuda()
        optimizer.zero_grad()
        pred=model(data.x, data.adj)
        mae+=torch.sum(torch.abs(pred-data.y)).item()/2
        loss=loss_func(pred,data.y)
        loss.backward()
        optimizer.step()

    return model,mae/len(loader.dataset)

def test(model, loader):
    model.eval()
    mae=0
    with torch.no_grad():
        for data in loader:
            data.x=to_dense_batch(data.x,batch=data.batch,max_num_nodes=max_nodes)[0].float()
            data.adj=to_dense_adj(data.edge_index,batch=data.batch,max_num_nodes=max_nodes)
            data=data.cuda()
            out = model(data.x,data.adj)  
            mae+=torch.sum(torch.abs(out-data.y)).item()/2
        
    return mae / len(loader.dataset)

# %% [markdown]
# # QM9

# %%
from torch_geometric.seed import seed_everything

max_nodes=9
QM9=load_dataset("./dataset/QM9/QM9.csv","smiles","homo","lumo")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 133247/133247 [01:06<00:00, 2013.99it/s]

# %% [markdown]
# ### Exp 1

# %%
seed_everything(1222)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(QM9_train,batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

diffpool=DiffPool(num_features)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.001)
loss_fn=MSELoss()

diffpool=diffpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.024062    Val MAE:0.017624    Test MAE:0.017495     Time:13.435047 s
# Epoch 2
# Train MAE:0.017118    Val MAE:0.016368    Test MAE:0.016327     Time:14.767745 s
# Epoch 3
# Train MAE:0.016203    Val MAE:0.015188    Test MAE:0.015100     Time:15.179350 s
# Epoch 4
# Train MAE:0.015326    Val MAE:0.014575    Test MAE:0.014571     Time:14.860917 s
# Epoch 5
# Train MAE:0.014662    Val MAE:0.014998    Test MAE:0.014989     Time:15.049303 s
# Epoch 6
# Train MAE:0.014148    Val MAE:0.014855    Test MAE:0.014791     Time:14.264054 s
# Epoch 7
# Train MAE:0.013586    Val MAE:0.012989    Test MAE:0.012967     Time:14.898383 s
# Epoch 8
# Train MAE:0.013336    Val MAE:0.012861    Test MAE:0.012921     Time:14.506850 s
# Epoch 9
# Train MAE:0.012828    Val MAE:0.012106    Test MAE:0.012167     Time:15.141315 s
# Epoch 10
# Train MAE:0.012647    Val MAE:0.012037    Test MAE:0.012080     Time:14.699220 s
# Epoch 11
# Train MAE:0.012340    Val MAE:0.011917    Test MAE:0.012031     Time:14.473908 s
# Epoch 12
# Train MAE:0.012246    Val MAE:0.011779    Test MAE:0.011877     Time:14.371186 s
# Epoch 13
# Train MAE:0.011945    Val MAE:0.012225    Test MAE:0.012277     Time:14.989545 s
# Epoch 14
# Train MAE:0.011708    Val MAE:0.011618    Test MAE:0.011687     Time:14.848961 s
# Epoch 15
# Train MAE:0.011608    Val MAE:0.011553    Test MAE:0.011608     Time:14.516785 s
# Epoch 16
# Train MAE:0.011518    Val MAE:0.011955    Test MAE:0.012068     Time:14.952784 s
# Epoch 17
# Train MAE:0.011274    Val MAE:0.011324    Test MAE:0.011498     Time:15.288050 s
# Epoch 18
# Train MAE:0.011210    Val MAE:0.010523    Test MAE:0.010646     Time:14.645239 s
# Epoch 19
# Train MAE:0.011028    Val MAE:0.010590    Test MAE:0.010718     Time:14.345920 s
# Epoch 20
# Train MAE:0.010846    Val MAE:0.010679    Test MAE:0.010912     Time:14.812636 s
# Epoch 21
# Train MAE:0.010866    Val MAE:0.010617    Test MAE:0.010750     Time:14.722410 s
# Epoch 22
# Train MAE:0.010674    Val MAE:0.011235    Test MAE:0.011389     Time:14.508537 s
# Epoch 23
# Train MAE:0.010629    Val MAE:0.010736    Test MAE:0.010906     Time:15.127069 s
# Epoch 24
# Train MAE:0.010574    Val MAE:0.009813    Test MAE:0.009965     Time:14.952503 s
# Epoch 25
# Train MAE:0.010425    Val MAE:0.010184    Test MAE:0.010230     Time:15.037428 s
# Epoch 26
# Train MAE:0.010416    Val MAE:0.011000    Test MAE:0.011094     Time:14.828417 s
# Epoch 27
# Train MAE:0.010274    Val MAE:0.010017    Test MAE:0.010134     Time:15.527033 s
# Epoch 28
# Train MAE:0.010193    Val MAE:0.010133    Test MAE:0.010184     Time:14.966952 s
# Epoch 29
# Train MAE:0.010224    Val MAE:0.010123    Test MAE:0.010215     Time:14.387378 s
# Epoch 30
# Train MAE:0.010146    Val MAE:0.010739    Test MAE:0.010923     Time:15.291232 s
# Epoch 31
# Train MAE:0.010077    Val MAE:0.009623    Test MAE:0.009762     Time:15.150645 s
# Epoch 32
# Train MAE:0.010078    Val MAE:0.009649    Test MAE:0.009800     Time:15.277096 s
# Epoch 33
# Train MAE:0.010062    Val MAE:0.010185    Test MAE:0.010257     Time:14.699742 s
# Epoch 34
# Train MAE:0.009957    Val MAE:0.009599    Test MAE:0.009739     Time:14.635643 s
# Epoch 35
# Train MAE:0.009889    Val MAE:0.009505    Test MAE:0.009624     Time:14.526905 s
# Epoch 36
# Train MAE:0.009879    Val MAE:0.009520    Test MAE:0.009661     Time:14.380021 s
# Epoch 37
# Train MAE:0.009784    Val MAE:0.009496    Test MAE:0.009594     Time:14.421441 s
# Epoch 38
# Train MAE:0.009794    Val MAE:0.009254    Test MAE:0.009294     Time:14.557569 s
# Epoch 39
# Train MAE:0.009779    Val MAE:0.009939    Test MAE:0.009954     Time:14.420255 s
# Epoch 40
# Train MAE:0.009727    Val MAE:0.009541    Test MAE:0.009578     Time:14.702769 s
# Epoch 41
# Train MAE:0.009658    Val MAE:0.010321    Test MAE:0.010407     Time:14.316276 s
# Epoch 42
# Train MAE:0.009698    Val MAE:0.009212    Test MAE:0.009335     Time:14.508519 s
# Epoch 43
# Train MAE:0.009613    Val MAE:0.009088    Test MAE:0.009195     Time:14.282954 s
# Epoch 44
# Train MAE:0.009622    Val MAE:0.009087    Test MAE:0.009190     Time:14.442527 s
# Epoch 45
# Train MAE:0.009593    Val MAE:0.009284    Test MAE:0.009361     Time:14.521555 s
# Epoch 46
# Train MAE:0.009626    Val MAE:0.010166    Test MAE:0.010269     Time:14.361810 s
# Epoch 47
# Train MAE:0.009496    Val MAE:0.009259    Test MAE:0.009330     Time:14.325231 s
# Epoch 48
# Train MAE:0.009496    Val MAE:0.009067    Test MAE:0.009098     Time:14.684472 s
# Epoch 49
# Train MAE:0.009478    Val MAE:0.009379    Test MAE:0.009437     Time:14.275373 s
# Epoch 50
# Train MAE:0.009496    Val MAE:0.009190    Test MAE:0.009243     Time:14.518762 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.0005)
train_loader = DataLoader(QM9_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.009577    Val MAE:0.009336    Test MAE:0.009388     Time:35.865411 s
# Epoch 2
# Train MAE:0.009590    Val MAE:0.009116    Test MAE:0.009225     Time:35.812259 s
# Epoch 3
# Train MAE:0.009572    Val MAE:0.010674    Test MAE:0.010776     Time:34.016861 s
# Epoch 4
# Train MAE:0.009503    Val MAE:0.009131    Test MAE:0.009231     Time:34.772415 s
# Epoch 5
# Train MAE:0.009464    Val MAE:0.009138    Test MAE:0.009234     Time:34.533585 s
# Epoch 6
# Train MAE:0.009454    Val MAE:0.009601    Test MAE:0.009669     Time:32.897979 s
# Epoch 7
# Train MAE:0.009411    Val MAE:0.009297    Test MAE:0.009370     Time:32.506943 s
# Epoch 8
# Train MAE:0.009493    Val MAE:0.009485    Test MAE:0.009623     Time:34.493815 s
# Epoch 9
# Train MAE:0.009337    Val MAE:0.009380    Test MAE:0.009427     Time:35.315694 s
# Epoch 10
# Train MAE:0.009358    Val MAE:0.009143    Test MAE:0.009197     Time:35.118951 s
# Epoch 11
# Train MAE:0.009329    Val MAE:0.008814    Test MAE:0.008906     Time:32.725700 s
# Epoch 12
# Train MAE:0.009302    Val MAE:0.008890    Test MAE:0.008979     Time:34.903684 s
# Epoch 13
# Train MAE:0.009263    Val MAE:0.008861    Test MAE:0.008974     Time:35.521725 s
# Epoch 14
# Train MAE:0.009215    Val MAE:0.008876    Test MAE:0.009017     Time:33.167730 s
# Epoch 15
# Train MAE:0.009186    Val MAE:0.009227    Test MAE:0.009367     Time:32.835349 s
# Epoch 16
# Train MAE:0.009185    Val MAE:0.009557    Test MAE:0.009726     Time:34.354890 s
# Epoch 17
# Train MAE:0.009153    Val MAE:0.009634    Test MAE:0.009663     Time:36.129063 s
# Epoch 18
# Train MAE:0.009166    Val MAE:0.009313    Test MAE:0.009383     Time:33.162204 s
# Epoch 19
# Train MAE:0.009106    Val MAE:0.009511    Test MAE:0.009605     Time:33.000642 s
# Epoch 20
# Train MAE:0.009061    Val MAE:0.008757    Test MAE:0.008844     Time:33.412909 s
# Epoch 21
# Train MAE:0.009097    Val MAE:0.008758    Test MAE:0.008868     Time:36.611889 s
# Epoch 22
# Train MAE:0.008998    Val MAE:0.009023    Test MAE:0.009072     Time:33.840606 s
# Epoch 23
# Train MAE:0.009027    Val MAE:0.008822    Test MAE:0.008916     Time:33.118962 s
# Epoch 24
# Train MAE:0.009033    Val MAE:0.009097    Test MAE:0.009168     Time:33.890566 s
# Epoch 25
# Train MAE:0.008985    Val MAE:0.009194    Test MAE:0.009260     Time:38.608010 s
# Epoch 26
# Train MAE:0.009026    Val MAE:0.008480    Test MAE:0.008588     Time:34.724155 s
# Epoch 27
# Train MAE:0.008948    Val MAE:0.008464    Test MAE:0.008620     Time:33.868922 s
# Epoch 28
# Train MAE:0.008911    Val MAE:0.008695    Test MAE:0.008764     Time:34.072821 s
# Epoch 29
# Train MAE:0.008856    Val MAE:0.008491    Test MAE:0.008599     Time:36.515272 s
# Epoch 30
# Train MAE:0.008894    Val MAE:0.008494    Test MAE:0.008596     Time:32.976523 s
# Epoch 31
# Train MAE:0.008853    Val MAE:0.008379    Test MAE:0.008458     Time:33.017206 s
# Epoch 32
# Train MAE:0.008814    Val MAE:0.008456    Test MAE:0.008543     Time:35.183191 s
# Epoch 33
# Train MAE:0.008795    Val MAE:0.008509    Test MAE:0.008562     Time:38.209758 s
# Epoch 34
# Train MAE:0.008800    Val MAE:0.008386    Test MAE:0.008451     Time:33.355622 s
# Epoch 35
# Train MAE:0.008761    Val MAE:0.008660    Test MAE:0.008748     Time:33.388525 s
# Epoch 36
# Train MAE:0.008734    Val MAE:0.009509    Test MAE:0.009575     Time:34.248556 s
# Epoch 37
# Train MAE:0.008767    Val MAE:0.008678    Test MAE:0.008760     Time:36.687749 s
# Epoch 38
# Train MAE:0.008694    Val MAE:0.008680    Test MAE:0.008823     Time:33.139755 s
# Epoch 39
# Train MAE:0.008688    Val MAE:0.009092    Test MAE:0.009229     Time:33.208848 s
# Epoch 40
# Train MAE:0.008705    Val MAE:0.008747    Test MAE:0.008906     Time:35.327766 s
# Epoch 41
# Train MAE:0.008640    Val MAE:0.008462    Test MAE:0.008551     Time:36.866269 s
# Epoch 42
# Train MAE:0.008586    Val MAE:0.008311    Test MAE:0.008404     Time:33.093597 s
# Epoch 43
# Train MAE:0.008608    Val MAE:0.008323    Test MAE:0.008498     Time:33.220255 s
# Epoch 44
# Train MAE:0.008594    Val MAE:0.008110    Test MAE:0.008199     Time:35.744689 s
# Epoch 45
# Train MAE:0.008600    Val MAE:0.008587    Test MAE:0.008692     Time:36.796003 s
# Epoch 46
# Train MAE:0.008603    Val MAE:0.008471    Test MAE:0.008561     Time:34.866592 s
# Epoch 47
# Train MAE:0.008549    Val MAE:0.008294    Test MAE:0.008413     Time:34.478223 s
# Epoch 48
# Train MAE:0.008597    Val MAE:0.009078    Test MAE:0.009147     Time:34.940268 s
# Epoch 49
# Train MAE:0.008572    Val MAE:0.008571    Test MAE:0.008663     Time:35.945442 s
# Epoch 50
# Train MAE:0.008551    Val MAE:0.009587    Test MAE:0.009752     Time:34.744678 s

# %%
with open("./result/DIFF_QM9_1.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %%
from torch_geometric.data import Batch

smiles_list=["C[C@H]1CCC(=O)OC1",
             "CCC1(O)CC=CC1"]

def get_S(smile_list,model):
    data_list=[]
    for smile in smiles_list:
        data_list.append(from_smiles(smile))
    batch=Batch.from_data_list(data_list)
    batch.x=to_dense_batch(batch.x,batch=batch.batch,max_num_nodes=max_nodes)[0].float()
    batch.adj=to_dense_adj(batch.edge_index,batch=batch.batch,max_num_nodes=max_nodes)
    batch=batch.cuda()

    model.eval()
    with torch.no_grad():
        S=model.gnn1_pool(batch.x,batch.adj)
    return S.cpu()

get_S(smiles_list,diffpool)
# Out:
# tensor([[[2.9548, 0.0000, 7.0829],
#          [4.6630, 0.0000, 9.3750],
#          [4.0158, 0.0000, 8.3664],
#          [3.6069, 0.0000, 6.2083],
#          [2.7244, 0.0000, 4.3757],
#          [0.2756, 0.0000, 0.3999],
#          [3.8084, 0.0000, 5.0550],
#          [4.2172, 0.0000, 7.2131],
#          [0.0000, 0.0000, 0.0000]],
#
#         [[2.9893, 0.0000, 7.1162],
#          [4.1858, 0.0000, 8.4671],
#          [5.2983, 0.0000, 8.3270],
#          [2.9852, 0.0000, 3.4018],
#          [4.6228, 0.0000, 7.5535],
#          [4.3397, 0.0000, 7.4099],
#          [4.3397, 0.0000, 7.4099],
#          [4.6228, 0.0000, 7.5535],
#          [0.0000, 0.0000, 0.0000]]])

# %% [markdown]
# ### Exp 2

# %%
seed_everything(324)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(QM9_train,batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

diffpool=DiffPool(num_features)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.001)
loss_fn=MSELoss()

diffpool=diffpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.020758    Val MAE:0.017022    Test MAE:0.016854     Time:12.850177 s
# Epoch 2
# Train MAE:0.016281    Val MAE:0.014884    Test MAE:0.014830     Time:12.685997 s
# Epoch 3
# Train MAE:0.015422    Val MAE:0.014831    Test MAE:0.014842     Time:12.650656 s
# Epoch 4
# Train MAE:0.014874    Val MAE:0.013747    Test MAE:0.013776     Time:13.121297 s
# Epoch 5
# Train MAE:0.014257    Val MAE:0.013179    Test MAE:0.013166     Time:13.513441 s
# Epoch 6
# Train MAE:0.013803    Val MAE:0.013720    Test MAE:0.013738     Time:13.544003 s
# Epoch 7
# Train MAE:0.013385    Val MAE:0.013176    Test MAE:0.013098     Time:13.957102 s
# Epoch 8
# Train MAE:0.013103    Val MAE:0.012766    Test MAE:0.012695     Time:13.892344 s
# Epoch 9
# Train MAE:0.012788    Val MAE:0.012681    Test MAE:0.012605     Time:13.700646 s
# Epoch 10
# Train MAE:0.012597    Val MAE:0.012140    Test MAE:0.012064     Time:13.980258 s
# Epoch 11
# Train MAE:0.012278    Val MAE:0.012270    Test MAE:0.012174     Time:13.884907 s
# Epoch 12
# Train MAE:0.012235    Val MAE:0.011921    Test MAE:0.011852     Time:14.183134 s
# Epoch 13
# Train MAE:0.011876    Val MAE:0.013021    Test MAE:0.013020     Time:14.049372 s
# Epoch 14
# Train MAE:0.011768    Val MAE:0.011446    Test MAE:0.011381     Time:14.268729 s
# Epoch 15
# Train MAE:0.011611    Val MAE:0.011394    Test MAE:0.011297     Time:14.246430 s
# Epoch 16
# Train MAE:0.011527    Val MAE:0.011783    Test MAE:0.011663     Time:14.484895 s
# Epoch 17
# Train MAE:0.011361    Val MAE:0.010691    Test MAE:0.010598     Time:14.142037 s
# Epoch 18
# Train MAE:0.011178    Val MAE:0.010860    Test MAE:0.010740     Time:14.417463 s
# Epoch 19
# Train MAE:0.011182    Val MAE:0.011110    Test MAE:0.011072     Time:14.549222 s
# Epoch 20
# Train MAE:0.011045    Val MAE:0.010650    Test MAE:0.010581     Time:14.341146 s
# Epoch 21
# Train MAE:0.010931    Val MAE:0.011006    Test MAE:0.010880     Time:14.464978 s
# Epoch 22
# Train MAE:0.010806    Val MAE:0.010388    Test MAE:0.010373     Time:15.293869 s
# Epoch 23
# Train MAE:0.010720    Val MAE:0.011522    Test MAE:0.011449     Time:15.578855 s
# Epoch 24
# Train MAE:0.010700    Val MAE:0.010222    Test MAE:0.010149     Time:14.203451 s
# Epoch 25
# Train MAE:0.010703    Val MAE:0.010304    Test MAE:0.010289     Time:13.984387 s
# Epoch 26
# Train MAE:0.010949    Val MAE:0.010858    Test MAE:0.010767     Time:14.329466 s
# Epoch 27
# Train MAE:0.010994    Val MAE:0.011069    Test MAE:0.010988     Time:14.110657 s
# Epoch 28
# Train MAE:0.010730    Val MAE:0.010268    Test MAE:0.010149     Time:14.111248 s
# Epoch 29
# Train MAE:0.010588    Val MAE:0.011625    Test MAE:0.011537     Time:14.001243 s
# Epoch 30
# Train MAE:0.010469    Val MAE:0.011228    Test MAE:0.011141     Time:14.158502 s
# Epoch 31
# Train MAE:0.010416    Val MAE:0.011041    Test MAE:0.010986     Time:14.468853 s
# Epoch 32
# Train MAE:0.010363    Val MAE:0.010682    Test MAE:0.010555     Time:13.983071 s
# Epoch 33
# Train MAE:0.010324    Val MAE:0.010246    Test MAE:0.010176     Time:14.234212 s
# Epoch 34
# Train MAE:0.010204    Val MAE:0.010270    Test MAE:0.010222     Time:14.346895 s
# Epoch 35
# Train MAE:0.010060    Val MAE:0.009778    Test MAE:0.009716     Time:14.438869 s
# Epoch 36
# Train MAE:0.009998    Val MAE:0.010168    Test MAE:0.010107     Time:14.454872 s
# Epoch 37
# Train MAE:0.010014    Val MAE:0.010377    Test MAE:0.010333     Time:14.312623 s
# Epoch 38
# Train MAE:0.009887    Val MAE:0.009392    Test MAE:0.009344     Time:14.452918 s
# Epoch 39
# Train MAE:0.009929    Val MAE:0.010654    Test MAE:0.010578     Time:14.682349 s
# Epoch 40
# Train MAE:0.009806    Val MAE:0.009980    Test MAE:0.009893     Time:14.281701 s
# Epoch 41
# Train MAE:0.009708    Val MAE:0.010220    Test MAE:0.010146     Time:14.767328 s
# Epoch 42
# Train MAE:0.009723    Val MAE:0.010729    Test MAE:0.010659     Time:14.469272 s
# Epoch 43
# Train MAE:0.009613    Val MAE:0.009806    Test MAE:0.009760     Time:14.484268 s
# Epoch 44
# Train MAE:0.009574    Val MAE:0.009457    Test MAE:0.009386     Time:14.548748 s
# Epoch 45
# Train MAE:0.009554    Val MAE:0.010497    Test MAE:0.010439     Time:14.375862 s
# Epoch 46
# Train MAE:0.009599    Val MAE:0.009151    Test MAE:0.009074     Time:14.639507 s
# Epoch 47
# Train MAE:0.009398    Val MAE:0.009114    Test MAE:0.008973     Time:14.887219 s
# Epoch 48
# Train MAE:0.009514    Val MAE:0.010012    Test MAE:0.009954     Time:14.501238 s
# Epoch 49
# Train MAE:0.009408    Val MAE:0.010439    Test MAE:0.010280     Time:14.724695 s
# Epoch 50
# Train MAE:0.009269    Val MAE:0.010209    Test MAE:0.010180     Time:15.339228 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.0005)
train_loader = DataLoader(QM9_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.009496    Val MAE:0.010511    Test MAE:0.010354     Time:33.155694 s
# Epoch 2
# Train MAE:0.009405    Val MAE:0.009575    Test MAE:0.009529     Time:33.679666 s
# Epoch 3
# Train MAE:0.009386    Val MAE:0.008937    Test MAE:0.008816     Time:36.936462 s
# Epoch 4
# Train MAE:0.009333    Val MAE:0.009628    Test MAE:0.009585     Time:34.060930 s
# Epoch 5
# Train MAE:0.009261    Val MAE:0.010397    Test MAE:0.010372     Time:33.644606 s
# Epoch 6
# Train MAE:0.009232    Val MAE:0.009119    Test MAE:0.009033     Time:34.029007 s
# Epoch 7
# Train MAE:0.009203    Val MAE:0.010691    Test MAE:0.010613     Time:37.026620 s
# Epoch 8
# Train MAE:0.009144    Val MAE:0.008684    Test MAE:0.008555     Time:34.136580 s
# Epoch 9
# Train MAE:0.009123    Val MAE:0.009072    Test MAE:0.009019     Time:33.657645 s
# Epoch 10
# Train MAE:0.009033    Val MAE:0.009086    Test MAE:0.008967     Time:33.569898 s
# Epoch 11
# Train MAE:0.009021    Val MAE:0.009308    Test MAE:0.009210     Time:38.066563 s
# Epoch 12
# Train MAE:0.008998    Val MAE:0.009059    Test MAE:0.008952     Time:34.147222 s
# Epoch 13
# Train MAE:0.008934    Val MAE:0.008545    Test MAE:0.008418     Time:33.613078 s
# Epoch 14
# Train MAE:0.008916    Val MAE:0.008875    Test MAE:0.008731     Time:33.648827 s
# Epoch 15
# Train MAE:0.008884    Val MAE:0.008824    Test MAE:0.008726     Time:36.598958 s
# Epoch 16
# Train MAE:0.008867    Val MAE:0.008831    Test MAE:0.008707     Time:34.053015 s
# Epoch 17
# Train MAE:0.008861    Val MAE:0.009166    Test MAE:0.009030     Time:33.966039 s
# Epoch 18
# Train MAE:0.008840    Val MAE:0.008453    Test MAE:0.008329     Time:33.599366 s
# Epoch 19
# Train MAE:0.008816    Val MAE:0.009233    Test MAE:0.009107     Time:36.679688 s
# Epoch 20
# Train MAE:0.008778    Val MAE:0.008771    Test MAE:0.008703     Time:33.783259 s
# Epoch 21
# Train MAE:0.008727    Val MAE:0.008766    Test MAE:0.008662     Time:33.465677 s
# Epoch 22
# Train MAE:0.008710    Val MAE:0.009011    Test MAE:0.008917     Time:33.504438 s
# Epoch 23
# Train MAE:0.008727    Val MAE:0.009582    Test MAE:0.009430     Time:37.342111 s
# Epoch 24
# Train MAE:0.008719    Val MAE:0.008670    Test MAE:0.008535     Time:33.553200 s
# Epoch 25
# Train MAE:0.008624    Val MAE:0.008502    Test MAE:0.008421     Time:33.524147 s
# Epoch 26
# Train MAE:0.008630    Val MAE:0.008494    Test MAE:0.008420     Time:33.490526 s
# Epoch 27
# Train MAE:0.008606    Val MAE:0.008717    Test MAE:0.008555     Time:36.910514 s
# Epoch 28
# Train MAE:0.008588    Val MAE:0.008297    Test MAE:0.008186     Time:33.586127 s
# Epoch 29
# Train MAE:0.008518    Val MAE:0.008306    Test MAE:0.008232     Time:33.552366 s
# Epoch 30
# Train MAE:0.008542    Val MAE:0.008715    Test MAE:0.008605     Time:33.659746 s
# Epoch 31
# Train MAE:0.008518    Val MAE:0.008781    Test MAE:0.008657     Time:37.178714 s
# Epoch 32
# Train MAE:0.008462    Val MAE:0.008766    Test MAE:0.008638     Time:33.972230 s
# Epoch 33
# Train MAE:0.008486    Val MAE:0.008255    Test MAE:0.008103     Time:33.459566 s
# Epoch 34
# Train MAE:0.008461    Val MAE:0.008274    Test MAE:0.008210     Time:33.519778 s
# Epoch 35
# Train MAE:0.008441    Val MAE:0.008252    Test MAE:0.008148     Time:36.802346 s
# Epoch 36
# Train MAE:0.008444    Val MAE:0.008251    Test MAE:0.008145     Time:34.019981 s
# Epoch 37
# Train MAE:0.008425    Val MAE:0.008440    Test MAE:0.008287     Time:33.719099 s
# Epoch 38
# Train MAE:0.008407    Val MAE:0.008602    Test MAE:0.008573     Time:33.866062 s
# Epoch 39
# Train MAE:0.008351    Val MAE:0.008534    Test MAE:0.008439     Time:37.146487 s
# Epoch 40
# Train MAE:0.008346    Val MAE:0.008742    Test MAE:0.008686     Time:33.908963 s
# Epoch 41
# Train MAE:0.008351    Val MAE:0.008861    Test MAE:0.008723     Time:33.567520 s
# Epoch 42
# Train MAE:0.008361    Val MAE:0.009502    Test MAE:0.009439     Time:33.272831 s
# Epoch 43
# Train MAE:0.008361    Val MAE:0.010218    Test MAE:0.010180     Time:37.770825 s
# Epoch 44
# Train MAE:0.008303    Val MAE:0.008037    Test MAE:0.007941     Time:33.844042 s
# Epoch 45
# Train MAE:0.008281    Val MAE:0.008616    Test MAE:0.008500     Time:33.460032 s
# Epoch 46
# Train MAE:0.008275    Val MAE:0.008316    Test MAE:0.008260     Time:33.443823 s
# Epoch 47
# Train MAE:0.008239    Val MAE:0.007978    Test MAE:0.007898     Time:36.802413 s
# Epoch 48
# Train MAE:0.008278    Val MAE:0.008250    Test MAE:0.008202     Time:33.719781 s
# Epoch 49
# Train MAE:0.008269    Val MAE:0.008382    Test MAE:0.008283     Time:33.460221 s
# Epoch 50
# Train MAE:0.008171    Val MAE:0.008390    Test MAE:0.008284     Time:33.549131 s

# %%
with open("./result/DIFF_QM9_2.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 3

# %%
seed_everything(10086)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(QM9_train,batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

diffpool=DiffPool(num_features)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.001)
loss_fn=MSELoss()

diffpool=diffpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.019519    Val MAE:0.016373    Test MAE:0.016314     Time:14.797408 s
# Epoch 2
# Train MAE:0.016010    Val MAE:0.017225    Test MAE:0.017231     Time:14.827670 s
# Epoch 3
# Train MAE:0.014842    Val MAE:0.015077    Test MAE:0.015091     Time:14.763676 s
# Epoch 4
# Train MAE:0.013773    Val MAE:0.014323    Test MAE:0.014366     Time:14.546332 s
# Epoch 5
# Train MAE:0.012824    Val MAE:0.012369    Test MAE:0.012437     Time:14.905575 s
# Epoch 6
# Train MAE:0.012430    Val MAE:0.011662    Test MAE:0.011758     Time:14.734825 s
# Epoch 7
# Train MAE:0.011939    Val MAE:0.011637    Test MAE:0.011764     Time:14.500009 s
# Epoch 8
# Train MAE:0.011771    Val MAE:0.012593    Test MAE:0.012643     Time:14.654719 s
# Epoch 9
# Train MAE:0.011471    Val MAE:0.011108    Test MAE:0.011232     Time:14.561376 s
# Epoch 10
# Train MAE:0.011291    Val MAE:0.011694    Test MAE:0.011811     Time:14.746042 s
# Epoch 11
# Train MAE:0.011258    Val MAE:0.011246    Test MAE:0.011298     Time:14.603122 s
# Epoch 12
# Train MAE:0.011044    Val MAE:0.011183    Test MAE:0.011178     Time:14.732869 s
# Epoch 13
# Train MAE:0.010905    Val MAE:0.010874    Test MAE:0.010926     Time:14.702323 s
# Epoch 14
# Train MAE:0.010760    Val MAE:0.011212    Test MAE:0.011288     Time:14.483340 s
# Epoch 15
# Train MAE:0.010758    Val MAE:0.010312    Test MAE:0.010355     Time:14.748379 s
# Epoch 16
# Train MAE:0.010590    Val MAE:0.010220    Test MAE:0.010307     Time:14.654263 s
# Epoch 17
# Train MAE:0.010562    Val MAE:0.010443    Test MAE:0.010521     Time:14.670017 s
# Epoch 18
# Train MAE:0.010423    Val MAE:0.010567    Test MAE:0.010699     Time:14.546607 s
# Epoch 19
# Train MAE:0.010394    Val MAE:0.010101    Test MAE:0.010181     Time:14.490638 s
# Epoch 20
# Train MAE:0.010298    Val MAE:0.010583    Test MAE:0.010643     Time:15.031058 s
# Epoch 21
# Train MAE:0.010192    Val MAE:0.009779    Test MAE:0.009845     Time:14.796825 s
# Epoch 22
# Train MAE:0.010153    Val MAE:0.009875    Test MAE:0.009900     Time:14.888859 s
# Epoch 23
# Train MAE:0.010055    Val MAE:0.011129    Test MAE:0.011162     Time:14.671046 s
# Epoch 24
# Train MAE:0.010000    Val MAE:0.009935    Test MAE:0.009951     Time:14.482029 s
# Epoch 25
# Train MAE:0.009984    Val MAE:0.010145    Test MAE:0.010206     Time:14.748544 s
# Epoch 26
# Train MAE:0.009902    Val MAE:0.010219    Test MAE:0.010256     Time:14.670896 s
# Epoch 27
# Train MAE:0.009804    Val MAE:0.010345    Test MAE:0.010353     Time:14.712564 s
# Epoch 28
# Train MAE:0.009845    Val MAE:0.010295    Test MAE:0.010328     Time:14.686751 s
# Epoch 29
# Train MAE:0.009741    Val MAE:0.009781    Test MAE:0.009743     Time:14.626042 s
# Epoch 30
# Train MAE:0.009676    Val MAE:0.009517    Test MAE:0.009486     Time:14.716910 s
# Epoch 31
# Train MAE:0.009619    Val MAE:0.009898    Test MAE:0.009928     Time:14.639890 s
# Epoch 32
# Train MAE:0.009580    Val MAE:0.009561    Test MAE:0.009578     Time:14.591701 s
# Epoch 33
# Train MAE:0.009495    Val MAE:0.009840    Test MAE:0.009858     Time:14.531941 s
# Epoch 34
# Train MAE:0.009523    Val MAE:0.009222    Test MAE:0.009266     Time:14.469235 s
# Epoch 35
# Train MAE:0.009417    Val MAE:0.010935    Test MAE:0.010885     Time:14.909484 s
# Epoch 36
# Train MAE:0.009931    Val MAE:0.009901    Test MAE:0.009955     Time:14.749566 s
# Epoch 37
# Train MAE:0.009818    Val MAE:0.009903    Test MAE:0.009925     Time:14.593432 s
# Epoch 38
# Train MAE:0.009794    Val MAE:0.009823    Test MAE:0.009803     Time:14.671206 s
# Epoch 39
# Train MAE:0.009712    Val MAE:0.009916    Test MAE:0.009935     Time:14.420558 s
# Epoch 40
# Train MAE:0.009642    Val MAE:0.010260    Test MAE:0.010342     Time:14.718070 s
# Epoch 41
# Train MAE:0.009627    Val MAE:0.010189    Test MAE:0.010178     Time:14.546499 s
# Epoch 42
# Train MAE:0.009595    Val MAE:0.009396    Test MAE:0.009488     Time:14.701833 s
# Epoch 43
# Train MAE:0.009477    Val MAE:0.009339    Test MAE:0.009384     Time:15.115477 s
# Epoch 44
# Train MAE:0.009404    Val MAE:0.009688    Test MAE:0.009710     Time:14.530503 s
# Epoch 45
# Train MAE:0.009371    Val MAE:0.009660    Test MAE:0.009745     Time:14.622845 s
# Epoch 46
# Train MAE:0.009319    Val MAE:0.010330    Test MAE:0.010363     Time:14.514312 s
# Epoch 47
# Train MAE:0.009350    Val MAE:0.009037    Test MAE:0.009083     Time:14.482684 s
# Epoch 48
# Train MAE:0.009235    Val MAE:0.009034    Test MAE:0.009128     Time:14.640419 s
# Epoch 49
# Train MAE:0.009239    Val MAE:0.008987    Test MAE:0.009037     Time:14.623582 s
# Epoch 50
# Train MAE:0.009140    Val MAE:0.009462    Test MAE:0.009541     Time:14.484645 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.0005)
train_loader = DataLoader(QM9_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.009279    Val MAE:0.009110    Test MAE:0.009158     Time:36.182680 s
# Epoch 2
# Train MAE:0.009209    Val MAE:0.009237    Test MAE:0.009257     Time:34.176524 s
# Epoch 3
# Train MAE:0.009167    Val MAE:0.009030    Test MAE:0.009084     Time:33.397826 s
# Epoch 4
# Train MAE:0.009172    Val MAE:0.009148    Test MAE:0.009162     Time:33.767055 s
# Epoch 5
# Train MAE:0.009054    Val MAE:0.008797    Test MAE:0.008889     Time:36.471446 s
# Epoch 6
# Train MAE:0.009041    Val MAE:0.008991    Test MAE:0.008996     Time:34.438837 s
# Epoch 7
# Train MAE:0.008988    Val MAE:0.009556    Test MAE:0.009598     Time:33.469681 s
# Epoch 8
# Train MAE:0.008985    Val MAE:0.011193    Test MAE:0.011354     Time:33.669780 s
# Epoch 9
# Train MAE:0.008966    Val MAE:0.008746    Test MAE:0.008717     Time:36.522151 s
# Epoch 10
# Train MAE:0.008941    Val MAE:0.008956    Test MAE:0.009013     Time:34.098759 s
# Epoch 11
# Train MAE:0.008851    Val MAE:0.009463    Test MAE:0.009419     Time:33.532637 s
# Epoch 12
# Train MAE:0.008844    Val MAE:0.008596    Test MAE:0.008637     Time:34.238557 s
# Epoch 13
# Train MAE:0.008825    Val MAE:0.008867    Test MAE:0.008936     Time:36.598662 s
# Epoch 14
# Train MAE:0.008823    Val MAE:0.008421    Test MAE:0.008490     Time:34.128095 s
# Epoch 15
# Train MAE:0.008778    Val MAE:0.008749    Test MAE:0.008783     Time:33.629610 s
# Epoch 16
# Train MAE:0.008793    Val MAE:0.008873    Test MAE:0.008898     Time:33.443472 s
# Epoch 17
# Train MAE:0.008710    Val MAE:0.008757    Test MAE:0.008790     Time:37.299513 s
# Epoch 18
# Train MAE:0.008699    Val MAE:0.008424    Test MAE:0.008450     Time:34.180453 s
# Epoch 19
# Train MAE:0.008664    Val MAE:0.008969    Test MAE:0.009007     Time:33.739595 s
# Epoch 20
# Train MAE:0.008673    Val MAE:0.009099    Test MAE:0.009111     Time:33.539102 s
# Epoch 21
# Train MAE:0.008630    Val MAE:0.008389    Test MAE:0.008501     Time:36.990022 s
# Epoch 22
# Train MAE:0.008600    Val MAE:0.008710    Test MAE:0.008757     Time:34.406589 s
# Epoch 23
# Train MAE:0.008595    Val MAE:0.008746    Test MAE:0.008810     Time:33.629799 s
# Epoch 24
# Train MAE:0.008560    Val MAE:0.008262    Test MAE:0.008312     Time:33.757187 s
# Epoch 25
# Train MAE:0.008535    Val MAE:0.008836    Test MAE:0.008856     Time:37.792682 s
# Epoch 26
# Train MAE:0.008496    Val MAE:0.008615    Test MAE:0.008676     Time:34.057378 s
# Epoch 27
# Train MAE:0.008504    Val MAE:0.008701    Test MAE:0.008779     Time:33.522341 s
# Epoch 28
# Train MAE:0.008520    Val MAE:0.008526    Test MAE:0.008578     Time:33.853974 s
# Epoch 29
# Train MAE:0.008443    Val MAE:0.008425    Test MAE:0.008455     Time:36.954021 s
# Epoch 30
# Train MAE:0.008409    Val MAE:0.008611    Test MAE:0.008726     Time:34.011135 s
# Epoch 31
# Train MAE:0.008389    Val MAE:0.008194    Test MAE:0.008261     Time:33.766079 s
# Epoch 32
# Train MAE:0.008383    Val MAE:0.008375    Test MAE:0.008477     Time:33.912313 s
# Epoch 33
# Train MAE:0.008330    Val MAE:0.008839    Test MAE:0.008800     Time:37.003375 s
# Epoch 34
# Train MAE:0.008362    Val MAE:0.008133    Test MAE:0.008201     Time:33.802127 s
# Epoch 35
# Train MAE:0.008289    Val MAE:0.008835    Test MAE:0.008910     Time:33.730128 s
# Epoch 36
# Train MAE:0.008312    Val MAE:0.008701    Test MAE:0.008714     Time:33.583673 s
# Epoch 37
# Train MAE:0.008324    Val MAE:0.009020    Test MAE:0.009027     Time:37.363596 s
# Epoch 38
# Train MAE:0.008287    Val MAE:0.008658    Test MAE:0.008694     Time:33.692871 s
# Epoch 39
# Train MAE:0.008308    Val MAE:0.008260    Test MAE:0.008347     Time:33.593251 s
# Epoch 40
# Train MAE:0.008235    Val MAE:0.007949    Test MAE:0.008017     Time:33.614765 s
# Epoch 41
# Train MAE:0.008247    Val MAE:0.008181    Test MAE:0.008252     Time:36.928483 s
# Epoch 42
# Train MAE:0.008212    Val MAE:0.008019    Test MAE:0.008094     Time:33.727122 s
# Epoch 43
# Train MAE:0.008197    Val MAE:0.007846    Test MAE:0.007963     Time:33.585557 s
# Epoch 44
# Train MAE:0.008245    Val MAE:0.008199    Test MAE:0.008317     Time:34.306459 s
# Epoch 45
# Train MAE:0.008144    Val MAE:0.008093    Test MAE:0.008157     Time:37.007379 s
# Epoch 46
# Train MAE:0.008159    Val MAE:0.008027    Test MAE:0.008117     Time:33.595586 s
# Epoch 47
# Train MAE:0.008156    Val MAE:0.008367    Test MAE:0.008396     Time:33.525635 s
# Epoch 48
# Train MAE:0.008138    Val MAE:0.008283    Test MAE:0.008351     Time:33.459289 s
# Epoch 49
# Train MAE:0.008124    Val MAE:0.008488    Test MAE:0.008571     Time:37.249473 s
# Epoch 50
# Train MAE:0.008092    Val MAE:0.009106    Test MAE:0.009151     Time:34.227805 s

# %%
with open("./result/DIFF_QM9_3.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# # OPV

# %%
from torch_geometric.seed import seed_everything

max_nodes=122
OPV=load_dataset("./dataset/OPV/OPV.csv","smile","homo","lumo")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 90823/90823 [02:05<00:00, 721.42it/s]

# %% [markdown]
# ### Exp 1

# %%
seed_everything(1222)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(OPV_train,batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

diffpool=DiffPool(num_features,num_nodes=30)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.001)
loss_fn=MSELoss()

diffpool=diffpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.561642    Val MAE:0.286996    Test MAE:0.288156     Time:12.145228 s
# Epoch 2
# Train MAE:0.275761    Val MAE:0.260087    Test MAE:0.259048     Time:12.548325 s
# Epoch 3
# Train MAE:0.245612    Val MAE:0.234242    Test MAE:0.233044     Time:13.046635 s
# Epoch 4
# Train MAE:0.229121    Val MAE:0.224023    Test MAE:0.221781     Time:13.293635 s
# Epoch 5
# Train MAE:0.222515    Val MAE:0.217101    Test MAE:0.215273     Time:13.300992 s
# Epoch 6
# Train MAE:0.216650    Val MAE:0.210829    Test MAE:0.208854     Time:14.225732 s
# Epoch 7
# Train MAE:0.211936    Val MAE:0.203942    Test MAE:0.201364     Time:14.994059 s
# Epoch 8
# Train MAE:0.209104    Val MAE:0.201797    Test MAE:0.200295     Time:13.871802 s
# Epoch 9
# Train MAE:0.206427    Val MAE:0.206001    Test MAE:0.204415     Time:14.278886 s
# Epoch 10
# Train MAE:0.199511    Val MAE:0.195341    Test MAE:0.193682     Time:14.581679 s
# Epoch 11
# Train MAE:0.195867    Val MAE:0.190640    Test MAE:0.187739     Time:14.630158 s
# Epoch 12
# Train MAE:0.192046    Val MAE:0.190655    Test MAE:0.187892     Time:15.901397 s
# Epoch 13
# Train MAE:0.190088    Val MAE:0.188266    Test MAE:0.185785     Time:14.688734 s
# Epoch 14
# Train MAE:0.187575    Val MAE:0.196958    Test MAE:0.195770     Time:14.994589 s
# Epoch 15
# Train MAE:0.184549    Val MAE:0.178056    Test MAE:0.175597     Time:15.987950 s
# Epoch 16
# Train MAE:0.182844    Val MAE:0.188182    Test MAE:0.185608     Time:15.465317 s
# Epoch 17
# Train MAE:0.181483    Val MAE:0.180576    Test MAE:0.178620     Time:14.845302 s
# Epoch 18
# Train MAE:0.181467    Val MAE:0.175371    Test MAE:0.172728     Time:14.932663 s
# Epoch 19
# Train MAE:0.178712    Val MAE:0.173918    Test MAE:0.171078     Time:15.167285 s
# Epoch 20
# Train MAE:0.179005    Val MAE:0.173553    Test MAE:0.170477     Time:15.661050 s
# Epoch 21
# Train MAE:0.176851    Val MAE:0.182107    Test MAE:0.178809     Time:16.055711 s
# Epoch 22
# Train MAE:0.176186    Val MAE:0.174431    Test MAE:0.172077     Time:16.041663 s
# Epoch 23
# Train MAE:0.175789    Val MAE:0.187187    Test MAE:0.185362     Time:15.346045 s
# Epoch 24
# Train MAE:0.174404    Val MAE:0.169698    Test MAE:0.166850     Time:15.158297 s
# Epoch 25
# Train MAE:0.174856    Val MAE:0.171024    Test MAE:0.168742     Time:15.429179 s
# Epoch 26
# Train MAE:0.171328    Val MAE:0.172883    Test MAE:0.169416     Time:16.090904 s
# Epoch 27
# Train MAE:0.171647    Val MAE:0.165380    Test MAE:0.162581     Time:15.656285 s
# Epoch 28
# Train MAE:0.171760    Val MAE:0.169005    Test MAE:0.165667     Time:15.343773 s
# Epoch 29
# Train MAE:0.169794    Val MAE:0.171435    Test MAE:0.168647     Time:15.197500 s
# Epoch 30
# Train MAE:0.169821    Val MAE:0.165369    Test MAE:0.163049     Time:16.488733 s
# Epoch 31
# Train MAE:0.168566    Val MAE:0.162674    Test MAE:0.160501     Time:17.539104 s
# Epoch 32
# Train MAE:0.167573    Val MAE:0.166197    Test MAE:0.164312     Time:15.389074 s
# Epoch 33
# Train MAE:0.167512    Val MAE:0.161190    Test MAE:0.158947     Time:15.926969 s
# Epoch 34
# Train MAE:0.165456    Val MAE:0.159473    Test MAE:0.156930     Time:15.344665 s
# Epoch 35
# Train MAE:0.165805    Val MAE:0.163207    Test MAE:0.159976     Time:15.484189 s
# Epoch 36
# Train MAE:0.164710    Val MAE:0.158353    Test MAE:0.155439     Time:15.422313 s
# Epoch 37
# Train MAE:0.164362    Val MAE:0.158004    Test MAE:0.155860     Time:15.490459 s
# Epoch 38
# Train MAE:0.163024    Val MAE:0.157768    Test MAE:0.155321     Time:15.343944 s
# Epoch 39
# Train MAE:0.162492    Val MAE:0.161304    Test MAE:0.158098     Time:15.545684 s
# Epoch 40
# Train MAE:0.161207    Val MAE:0.165476    Test MAE:0.163219     Time:15.483867 s
# Epoch 41
# Train MAE:0.160118    Val MAE:0.154693    Test MAE:0.152412     Time:15.418424 s
# Epoch 42
# Train MAE:0.158771    Val MAE:0.154092    Test MAE:0.151831     Time:17.852079 s
# Epoch 43
# Train MAE:0.160377    Val MAE:0.163870    Test MAE:0.160798     Time:15.627323 s
# Epoch 44
# Train MAE:0.158448    Val MAE:0.158260    Test MAE:0.155650     Time:15.480819 s
# Epoch 45
# Train MAE:0.157967    Val MAE:0.155839    Test MAE:0.152950     Time:15.648952 s
# Epoch 46
# Train MAE:0.156448    Val MAE:0.161718    Test MAE:0.158772     Time:15.480125 s
# Epoch 47
# Train MAE:0.155892    Val MAE:0.181752    Test MAE:0.180583     Time:16.729420 s
# Epoch 48
# Train MAE:0.156457    Val MAE:0.160126    Test MAE:0.157807     Time:17.386663 s
# Epoch 49
# Train MAE:0.155492    Val MAE:0.175462    Test MAE:0.171904     Time:15.595843 s
# Epoch 50
# Train MAE:0.156621    Val MAE:0.163883    Test MAE:0.162490     Time:15.773817 s

# %%
train_loader=DataLoader(OPV_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.0005)
epochs=50
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.156132    Val MAE:0.159048    Test MAE:0.156789     Time:35.307971 s
# Epoch 2
# Train MAE:0.156319    Val MAE:0.203168    Test MAE:0.202529     Time:36.647931 s
# Epoch 3
# Train MAE:0.154858    Val MAE:0.162606    Test MAE:0.161188     Time:36.513839 s
# Epoch 4
# Train MAE:0.154634    Val MAE:0.149092    Test MAE:0.146278     Time:38.580723 s
# Epoch 5
# Train MAE:0.153544    Val MAE:0.146196    Test MAE:0.144155     Time:39.681599 s
# Epoch 6
# Train MAE:0.153575    Val MAE:0.147840    Test MAE:0.145802     Time:37.568303 s
# Epoch 7
# Train MAE:0.152136    Val MAE:0.146167    Test MAE:0.143700     Time:39.901852 s
# Epoch 8
# Train MAE:0.152017    Val MAE:0.156364    Test MAE:0.154919     Time:38.697060 s
# Epoch 9
# Train MAE:0.151107    Val MAE:0.148168    Test MAE:0.146600     Time:42.020453 s
# Epoch 10
# Train MAE:0.150597    Val MAE:0.145460    Test MAE:0.144012     Time:39.251281 s
# Epoch 11
# Train MAE:0.150362    Val MAE:0.145809    Test MAE:0.143795     Time:38.964707 s
# Epoch 12
# Train MAE:0.149446    Val MAE:0.167101    Test MAE:0.166601     Time:39.287045 s
# Epoch 13
# Train MAE:0.148287    Val MAE:0.141987    Test MAE:0.140121     Time:38.043254 s
# Epoch 14
# Train MAE:0.147210    Val MAE:0.148262    Test MAE:0.147412     Time:39.617599 s
# Epoch 15
# Train MAE:0.146642    Val MAE:0.142068    Test MAE:0.141225     Time:38.793698 s
# Epoch 16
# Train MAE:0.145313    Val MAE:0.146194    Test MAE:0.144209     Time:39.472262 s
# Epoch 17
# Train MAE:0.144325    Val MAE:0.137297    Test MAE:0.135692     Time:38.447941 s
# Epoch 18
# Train MAE:0.143730    Val MAE:0.150096    Test MAE:0.148475     Time:38.499171 s
# Epoch 19
# Train MAE:0.142705    Val MAE:0.136810    Test MAE:0.135670     Time:41.500007 s
# Epoch 20
# Train MAE:0.141799    Val MAE:0.140482    Test MAE:0.139704     Time:38.870181 s
# Epoch 21
# Train MAE:0.141769    Val MAE:0.133573    Test MAE:0.131969     Time:37.437427 s
# Epoch 22
# Train MAE:0.140652    Val MAE:0.140520    Test MAE:0.139786     Time:39.254850 s
# Epoch 23
# Train MAE:0.139777    Val MAE:0.151937    Test MAE:0.150296     Time:45.487166 s
# Epoch 24
# Train MAE:0.139286    Val MAE:0.134148    Test MAE:0.133354     Time:39.125658 s
# Epoch 25
# Train MAE:0.139431    Val MAE:0.134846    Test MAE:0.133924     Time:40.830737 s
# Epoch 26
# Train MAE:0.138130    Val MAE:0.133062    Test MAE:0.132673     Time:43.693937 s
# Epoch 27
# Train MAE:0.137618    Val MAE:0.140779    Test MAE:0.140850     Time:42.127817 s
# Epoch 28
# Train MAE:0.137269    Val MAE:0.140435    Test MAE:0.139406     Time:39.589967 s
# Epoch 29
# Train MAE:0.135547    Val MAE:0.140039    Test MAE:0.140042     Time:38.100739 s
# Epoch 30
# Train MAE:0.135796    Val MAE:0.131414    Test MAE:0.130992     Time:39.734426 s
# Epoch 31
# Train MAE:0.134859    Val MAE:0.143993    Test MAE:0.142662     Time:39.046434 s
# Epoch 32
# Train MAE:0.134157    Val MAE:0.129908    Test MAE:0.130382     Time:39.738076 s
# Epoch 33
# Train MAE:0.133899    Val MAE:0.138155    Test MAE:0.138998     Time:38.814208 s
# Epoch 34
# Train MAE:0.133687    Val MAE:0.134581    Test MAE:0.135097     Time:38.737894 s
# Epoch 35
# Train MAE:0.132719    Val MAE:0.144744    Test MAE:0.143773     Time:38.724817 s
# Epoch 36
# Train MAE:0.132605    Val MAE:0.134995    Test MAE:0.133132     Time:40.977003 s
# Epoch 37
# Train MAE:0.131073    Val MAE:0.126918    Test MAE:0.125948     Time:39.112338 s
# Epoch 38
# Train MAE:0.131503    Val MAE:0.146588    Test MAE:0.148983     Time:40.003917 s
# Epoch 39
# Train MAE:0.130964    Val MAE:0.142288    Test MAE:0.141120     Time:39.196857 s
# Epoch 40
# Train MAE:0.129135    Val MAE:0.133827    Test MAE:0.132412     Time:39.704849 s
# Epoch 41
# Train MAE:0.129469    Val MAE:0.149733    Test MAE:0.151673     Time:37.942632 s
# Epoch 42
# Train MAE:0.129848    Val MAE:0.127869    Test MAE:0.127014     Time:40.436684 s
# Epoch 43
# Train MAE:0.127520    Val MAE:0.132165    Test MAE:0.133185     Time:38.227252 s
# Epoch 44
# Train MAE:0.127457    Val MAE:0.123700    Test MAE:0.122878     Time:40.692639 s
# Epoch 45
# Train MAE:0.127998    Val MAE:0.122135    Test MAE:0.122394     Time:41.405185 s
# Epoch 46
# Train MAE:0.126841    Val MAE:0.126724    Test MAE:0.128014     Time:41.593419 s
# Epoch 47
# Train MAE:0.127347    Val MAE:0.123264    Test MAE:0.122982     Time:37.421968 s
# Epoch 48
# Train MAE:0.125459    Val MAE:0.124169    Test MAE:0.125882     Time:37.165772 s
# Epoch 49
# Train MAE:0.125118    Val MAE:0.121944    Test MAE:0.122103     Time:37.776822 s
# Epoch 50
# Train MAE:0.125118    Val MAE:0.135450    Test MAE:0.135527     Time:39.613845 s

# %%
with open("./result/DIFF_OPV_1.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp2

# %%
seed_everything(324)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(OPV_train,batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

diffpool=DiffPool(num_features,num_nodes=30)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.001)
loss_fn=MSELoss()

diffpool=diffpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.691866    Val MAE:0.310651    Test MAE:0.306837     Time:12.669918 s
# Epoch 2
# Train MAE:0.300473    Val MAE:0.308800    Test MAE:0.305713     Time:12.999642 s
# Epoch 3
# Train MAE:0.293691    Val MAE:0.288932    Test MAE:0.287129     Time:13.461200 s
# Epoch 4
# Train MAE:0.287530    Val MAE:0.281904    Test MAE:0.282469     Time:13.925685 s
# Epoch 5
# Train MAE:0.275798    Val MAE:0.265980    Test MAE:0.267221     Time:14.244412 s
# Epoch 6
# Train MAE:0.250116    Val MAE:0.236978    Test MAE:0.238651     Time:14.254255 s
# Epoch 7
# Train MAE:0.234936    Val MAE:0.246464    Test MAE:0.249010     Time:14.768749 s
# Epoch 8
# Train MAE:0.225294    Val MAE:0.222559    Test MAE:0.224272     Time:14.776127 s
# Epoch 9
# Train MAE:0.219590    Val MAE:0.208398    Test MAE:0.209370     Time:14.710483 s
# Epoch 10
# Train MAE:0.212912    Val MAE:0.224103    Test MAE:0.224276     Time:15.035003 s
# Epoch 11
# Train MAE:0.211309    Val MAE:0.214227    Test MAE:0.213988     Time:15.867059 s
# Epoch 12
# Train MAE:0.204990    Val MAE:0.206697    Test MAE:0.207197     Time:15.063040 s
# Epoch 13
# Train MAE:0.203833    Val MAE:0.203970    Test MAE:0.203719     Time:15.326973 s
# Epoch 14
# Train MAE:0.201048    Val MAE:0.194331    Test MAE:0.194520     Time:15.256870 s
# Epoch 15
# Train MAE:0.200648    Val MAE:0.210794    Test MAE:0.210793     Time:15.084560 s
# Epoch 16
# Train MAE:0.197339    Val MAE:0.205956    Test MAE:0.205649     Time:15.267666 s
# Epoch 17
# Train MAE:0.194888    Val MAE:0.190378    Test MAE:0.190492     Time:15.245716 s
# Epoch 18
# Train MAE:0.193175    Val MAE:0.191630    Test MAE:0.192047     Time:15.274513 s
# Epoch 19
# Train MAE:0.192034    Val MAE:0.188713    Test MAE:0.189428     Time:15.294335 s
# Epoch 20
# Train MAE:0.191042    Val MAE:0.186163    Test MAE:0.185401     Time:15.428462 s
# Epoch 21
# Train MAE:0.188762    Val MAE:0.184185    Test MAE:0.183768     Time:15.248162 s
# Epoch 22
# Train MAE:0.188022    Val MAE:0.182636    Test MAE:0.182030     Time:15.357108 s
# Epoch 23
# Train MAE:0.187134    Val MAE:0.187214    Test MAE:0.186726     Time:15.246059 s
# Epoch 24
# Train MAE:0.184482    Val MAE:0.188892    Test MAE:0.188915     Time:15.333349 s
# Epoch 25
# Train MAE:0.183711    Val MAE:0.193615    Test MAE:0.194154     Time:15.916075 s
# Epoch 26
# Train MAE:0.181714    Val MAE:0.203416    Test MAE:0.203504     Time:15.541063 s
# Epoch 27
# Train MAE:0.182237    Val MAE:0.178509    Test MAE:0.178170     Time:15.310374 s
# Epoch 28
# Train MAE:0.179989    Val MAE:0.175566    Test MAE:0.175682     Time:15.491345 s
# Epoch 29
# Train MAE:0.177805    Val MAE:0.180881    Test MAE:0.181125     Time:15.466297 s
# Epoch 30
# Train MAE:0.176749    Val MAE:0.172260    Test MAE:0.171886     Time:15.237897 s
# Epoch 31
# Train MAE:0.176200    Val MAE:0.177579    Test MAE:0.176787     Time:15.513128 s
# Epoch 32
# Train MAE:0.175802    Val MAE:0.171727    Test MAE:0.172011     Time:15.327759 s
# Epoch 33
# Train MAE:0.174166    Val MAE:0.180850    Test MAE:0.180039     Time:15.202399 s
# Epoch 34
# Train MAE:0.173269    Val MAE:0.170552    Test MAE:0.169984     Time:15.244122 s
# Epoch 35
# Train MAE:0.172792    Val MAE:0.174645    Test MAE:0.173636     Time:15.219932 s
# Epoch 36
# Train MAE:0.172197    Val MAE:0.168724    Test MAE:0.168115     Time:15.326823 s
# Epoch 37
# Train MAE:0.171202    Val MAE:0.178335    Test MAE:0.178074     Time:15.654896 s
# Epoch 38
# Train MAE:0.170166    Val MAE:0.170644    Test MAE:0.169413     Time:15.358176 s
# Epoch 39
# Train MAE:0.169211    Val MAE:0.170651    Test MAE:0.170289     Time:15.299413 s
# Epoch 40
# Train MAE:0.170121    Val MAE:0.168663    Test MAE:0.167747     Time:15.265992 s
# Epoch 41
# Train MAE:0.167649    Val MAE:0.170349    Test MAE:0.169418     Time:15.110209 s
# Epoch 42
# Train MAE:0.168605    Val MAE:0.170498    Test MAE:0.169487     Time:15.296722 s
# Epoch 43
# Train MAE:0.166159    Val MAE:0.180845    Test MAE:0.180871     Time:15.420684 s
# Epoch 44
# Train MAE:0.167336    Val MAE:0.167545    Test MAE:0.166202     Time:15.094520 s
# Epoch 45
# Train MAE:0.164870    Val MAE:0.166400    Test MAE:0.165634     Time:15.204736 s
# Epoch 46
# Train MAE:0.166451    Val MAE:0.163349    Test MAE:0.162436     Time:15.484584 s
# Epoch 47
# Train MAE:0.163814    Val MAE:0.163646    Test MAE:0.162693     Time:15.359465 s
# Epoch 48
# Train MAE:0.163111    Val MAE:0.187176    Test MAE:0.187211     Time:15.235281 s
# Epoch 49
# Train MAE:0.163893    Val MAE:0.191838    Test MAE:0.191551     Time:15.187666 s
# Epoch 50
# Train MAE:0.163309    Val MAE:0.160661    Test MAE:0.159474     Time:15.109988 s

# %%
train_loader=DataLoader(OPV_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.0005)
epochs=50
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.164559    Val MAE:0.173227    Test MAE:0.172923     Time:38.333716 s
# Epoch 2
# Train MAE:0.163461    Val MAE:0.159884    Test MAE:0.159415     Time:37.282444 s
# Epoch 3
# Train MAE:0.162690    Val MAE:0.171963    Test MAE:0.171034     Time:37.586907 s
# Epoch 4
# Train MAE:0.160934    Val MAE:0.158010    Test MAE:0.157462     Time:37.243931 s
# Epoch 5
# Train MAE:0.160546    Val MAE:0.173043    Test MAE:0.171946     Time:37.467637 s
# Epoch 6
# Train MAE:0.160046    Val MAE:0.161135    Test MAE:0.159806     Time:37.125564 s
# Epoch 7
# Train MAE:0.160006    Val MAE:0.154708    Test MAE:0.153727     Time:36.664322 s
# Epoch 8
# Train MAE:0.158298    Val MAE:0.161585    Test MAE:0.160698     Time:37.314878 s
# Epoch 9
# Train MAE:0.158092    Val MAE:0.174135    Test MAE:0.173690     Time:37.427814 s
# Epoch 10
# Train MAE:0.157578    Val MAE:0.152306    Test MAE:0.151207     Time:37.498954 s
# Epoch 11
# Train MAE:0.157108    Val MAE:0.151924    Test MAE:0.150838     Time:37.041483 s
# Epoch 12
# Train MAE:0.156564    Val MAE:0.151295    Test MAE:0.150178     Time:36.625005 s
# Epoch 13
# Train MAE:0.154513    Val MAE:0.154431    Test MAE:0.154212     Time:37.250456 s
# Epoch 14
# Train MAE:0.154150    Val MAE:0.155290    Test MAE:0.154854     Time:36.799103 s
# Epoch 15
# Train MAE:0.153728    Val MAE:0.166553    Test MAE:0.165768     Time:38.041172 s
# Epoch 16
# Train MAE:0.152670    Val MAE:0.164818    Test MAE:0.163354     Time:36.249847 s
# Epoch 17
# Train MAE:0.151694    Val MAE:0.166179    Test MAE:0.165870     Time:36.311995 s
# Epoch 18
# Train MAE:0.151690    Val MAE:0.152337    Test MAE:0.151331     Time:36.113834 s
# Epoch 19
# Train MAE:0.151639    Val MAE:0.145532    Test MAE:0.144827     Time:36.196258 s
# Epoch 20
# Train MAE:0.149401    Val MAE:0.153587    Test MAE:0.153037     Time:35.987089 s
# Epoch 21
# Train MAE:0.148711    Val MAE:0.150390    Test MAE:0.149782     Time:36.187865 s
# Epoch 22
# Train MAE:0.147681    Val MAE:0.163626    Test MAE:0.163397     Time:35.849058 s
# Epoch 23
# Train MAE:0.147737    Val MAE:0.145763    Test MAE:0.144833     Time:36.175914 s
# Epoch 24
# Train MAE:0.146143    Val MAE:0.141992    Test MAE:0.141766     Time:35.718082 s
# Epoch 25
# Train MAE:0.146305    Val MAE:0.141739    Test MAE:0.140286     Time:36.361765 s
# Epoch 26
# Train MAE:0.145157    Val MAE:0.163979    Test MAE:0.164317     Time:36.236954 s
# Epoch 27
# Train MAE:0.144979    Val MAE:0.143808    Test MAE:0.142757     Time:36.205330 s
# Epoch 28
# Train MAE:0.144312    Val MAE:0.141337    Test MAE:0.140981     Time:728.603352 s
# Epoch 29
# Train MAE:0.143343    Val MAE:0.156700    Test MAE:0.156794     Time:28.926267 s
# Epoch 30
# Train MAE:0.142430    Val MAE:0.145399    Test MAE:0.144691     Time:31.282042 s
# Epoch 31
# Train MAE:0.141202    Val MAE:0.142704    Test MAE:0.142432     Time:33.015182 s
# Epoch 32
# Train MAE:0.140658    Val MAE:0.137477    Test MAE:0.136815     Time:32.942376 s
# Epoch 33
# Train MAE:0.139719    Val MAE:0.145119    Test MAE:0.144553     Time:33.892631 s
# Epoch 34
# Train MAE:0.139263    Val MAE:0.142837    Test MAE:0.142786     Time:34.105157 s
# Epoch 35
# Train MAE:0.138775    Val MAE:0.138958    Test MAE:0.138625     Time:34.882923 s
# Epoch 36
# Train MAE:0.137016    Val MAE:0.183835    Test MAE:0.182883     Time:35.680601 s
# Epoch 37
# Train MAE:0.137527    Val MAE:0.133273    Test MAE:0.132815     Time:35.381536 s
# Epoch 38
# Train MAE:0.136242    Val MAE:0.134664    Test MAE:0.133823     Time:37.349143 s
# Epoch 39
# Train MAE:0.135865    Val MAE:0.131340    Test MAE:0.130683     Time:35.795907 s
# Epoch 40
# Train MAE:0.135936    Val MAE:0.139417    Test MAE:0.138646     Time:37.093653 s
# Epoch 41
# Train MAE:0.134374    Val MAE:0.149186    Test MAE:0.149452     Time:36.434019 s
# Epoch 42
# Train MAE:0.134281    Val MAE:0.138212    Test MAE:0.137765     Time:38.512856 s
# Epoch 43
# Train MAE:0.133986    Val MAE:0.129432    Test MAE:0.129227     Time:36.987582 s
# Epoch 44
# Train MAE:0.133208    Val MAE:0.132827    Test MAE:0.131979     Time:36.906235 s
# Epoch 45
# Train MAE:0.132159    Val MAE:0.132156    Test MAE:0.131742     Time:40.070697 s
# Epoch 46
# Train MAE:0.131797    Val MAE:0.131406    Test MAE:0.130700     Time:38.518666 s
# Epoch 47
# Train MAE:0.131465    Val MAE:0.142310    Test MAE:0.142340     Time:36.868928 s
# Epoch 48
# Train MAE:0.131138    Val MAE:0.129892    Test MAE:0.129753     Time:37.839820 s
# Epoch 49
# Train MAE:0.131315    Val MAE:0.143107    Test MAE:0.143068     Time:36.650196 s
# Epoch 50
# Train MAE:0.129696    Val MAE:0.130298    Test MAE:0.129173     Time:36.487476 s

# %%
with open("./result/DIFF_OPV_2.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp3

# %%
seed_everything(10068)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(OPV_train,batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

diffpool=DiffPool(num_features,num_nodes=30)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.001)
loss_fn=MSELoss()

diffpool=diffpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.592505    Val MAE:0.294461    Test MAE:0.293699     Time:11.263473 s
# Epoch 2
# Train MAE:0.287370    Val MAE:0.273597    Test MAE:0.273819     Time:11.764177 s
# Epoch 3
# Train MAE:0.271121    Val MAE:0.258377    Test MAE:0.259417     Time:12.042249 s
# Epoch 4
# Train MAE:0.259242    Val MAE:0.250881    Test MAE:0.252133     Time:11.757219 s
# Epoch 5
# Train MAE:0.254201    Val MAE:0.248703    Test MAE:0.249377     Time:12.081896 s
# Epoch 6
# Train MAE:0.241740    Val MAE:0.231490    Test MAE:0.232392     Time:12.397175 s
# Epoch 7
# Train MAE:0.230682    Val MAE:0.220669    Test MAE:0.221407     Time:12.595804 s
# Epoch 8
# Train MAE:0.220275    Val MAE:0.213086    Test MAE:0.214012     Time:12.884266 s
# Epoch 9
# Train MAE:0.216207    Val MAE:0.228963    Test MAE:0.230330     Time:12.908219 s
# Epoch 10
# Train MAE:0.213869    Val MAE:0.216919    Test MAE:0.218067     Time:13.333025 s
# Epoch 11
# Train MAE:0.209940    Val MAE:0.207561    Test MAE:0.207854     Time:13.374297 s
# Epoch 12
# Train MAE:0.205592    Val MAE:0.211216    Test MAE:0.211888     Time:13.506041 s
# Epoch 13
# Train MAE:0.206147    Val MAE:0.198027    Test MAE:0.198228     Time:13.887593 s
# Epoch 14
# Train MAE:0.203195    Val MAE:0.199702    Test MAE:0.199934     Time:12.928353 s
# Epoch 15
# Train MAE:0.201512    Val MAE:0.204832    Test MAE:0.205436     Time:13.150559 s
# Epoch 16
# Train MAE:0.201298    Val MAE:0.198627    Test MAE:0.198503     Time:13.772321 s
# Epoch 17
# Train MAE:0.198827    Val MAE:0.203080    Test MAE:0.204045     Time:13.977904 s
# Epoch 18
# Train MAE:0.198968    Val MAE:0.191426    Test MAE:0.190714     Time:13.958502 s
# Epoch 19
# Train MAE:0.196819    Val MAE:0.195241    Test MAE:0.195262     Time:13.204663 s
# Epoch 20
# Train MAE:0.195676    Val MAE:0.193999    Test MAE:0.193667     Time:13.176419 s
# Epoch 21
# Train MAE:0.194149    Val MAE:0.200886    Test MAE:0.200205     Time:13.296860 s
# Epoch 22
# Train MAE:0.192882    Val MAE:0.187982    Test MAE:0.186584     Time:14.316286 s
# Epoch 23
# Train MAE:0.191676    Val MAE:0.186688    Test MAE:0.185696     Time:13.460036 s
# Epoch 24
# Train MAE:0.191806    Val MAE:0.185793    Test MAE:0.185313     Time:13.542481 s
# Epoch 25
# Train MAE:0.188177    Val MAE:0.185677    Test MAE:0.184448     Time:14.240953 s
# Epoch 26
# Train MAE:0.188228    Val MAE:0.181814    Test MAE:0.180803     Time:14.002776 s
# Epoch 27
# Train MAE:0.187345    Val MAE:0.187051    Test MAE:0.186382     Time:13.768926 s
# Epoch 28
# Train MAE:0.186609    Val MAE:0.201899    Test MAE:0.200169     Time:13.929396 s
# Epoch 29
# Train MAE:0.186681    Val MAE:0.203226    Test MAE:0.201608     Time:13.670743 s
# Epoch 30
# Train MAE:0.185651    Val MAE:0.179254    Test MAE:0.178545     Time:14.326944 s
# Epoch 31
# Train MAE:0.184177    Val MAE:0.191901    Test MAE:0.190654     Time:13.949675 s
# Epoch 32
# Train MAE:0.183517    Val MAE:0.190909    Test MAE:0.190845     Time:13.949986 s
# Epoch 33
# Train MAE:0.181015    Val MAE:0.175588    Test MAE:0.174254     Time:13.620036 s
# Epoch 34
# Train MAE:0.183430    Val MAE:0.175002    Test MAE:0.173971     Time:14.053282 s
# Epoch 35
# Train MAE:0.180322    Val MAE:0.178470    Test MAE:0.178191     Time:13.863320 s
# Epoch 36
# Train MAE:0.179627    Val MAE:0.179095    Test MAE:0.177634     Time:14.232821 s
# Epoch 37
# Train MAE:0.177418    Val MAE:0.176012    Test MAE:0.175360     Time:14.170660 s
# Epoch 38
# Train MAE:0.178169    Val MAE:0.179507    Test MAE:0.179689     Time:13.759290 s
# Epoch 39
# Train MAE:0.176439    Val MAE:0.175039    Test MAE:0.173855     Time:13.738386 s
# Epoch 40
# Train MAE:0.176696    Val MAE:0.187519    Test MAE:0.186037     Time:13.868624 s
# Epoch 41
# Train MAE:0.174966    Val MAE:0.173520    Test MAE:0.173195     Time:13.884134 s
# Epoch 42
# Train MAE:0.175524    Val MAE:0.171990    Test MAE:0.171586     Time:13.932842 s
# Epoch 43
# Train MAE:0.173746    Val MAE:0.173711    Test MAE:0.172992     Time:14.031807 s
# Epoch 44
# Train MAE:0.173965    Val MAE:0.168601    Test MAE:0.167948     Time:14.104497 s
# Epoch 45
# Train MAE:0.171995    Val MAE:0.179694    Test MAE:0.179675     Time:13.974391 s
# Epoch 46
# Train MAE:0.173028    Val MAE:0.167429    Test MAE:0.167093     Time:13.948550 s
# Epoch 47
# Train MAE:0.172342    Val MAE:0.167066    Test MAE:0.165928     Time:13.932847 s
# Epoch 48
# Train MAE:0.171158    Val MAE:0.176737    Test MAE:0.175505     Time:13.849998 s
# Epoch 49
# Train MAE:0.170215    Val MAE:0.202892    Test MAE:0.203441     Time:13.916535 s
# Epoch 50
# Train MAE:0.169621    Val MAE:0.178015    Test MAE:0.177484     Time:13.941447 s

# %%
train_loader=DataLoader(OPV_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=diffpool.parameters(), lr=0.0005)
epochs=50
for i in range(1,epochs+1):
    t_start=time.time()
    diffpool,train_mae = train(diffpool, train_loader, optimizer, loss_fn)
    val_mae=test(diffpool,val_loader)
    test_mae=test(diffpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.171824    Val MAE:0.167247    Test MAE:0.166558     Time:35.817431 s
# Epoch 2
# Train MAE:0.171199    Val MAE:0.165021    Test MAE:0.164752     Time:35.291419 s
# Epoch 3
# Train MAE:0.170794    Val MAE:0.163554    Test MAE:0.163574     Time:35.012333 s
# Epoch 4
# Train MAE:0.169550    Val MAE:0.165752    Test MAE:0.164930     Time:33.512813 s
# Epoch 5
# Train MAE:0.168629    Val MAE:0.163616    Test MAE:0.164026     Time:33.551322 s
# Epoch 6
# Train MAE:0.167865    Val MAE:0.169995    Test MAE:0.170590     Time:33.815075 s
# Epoch 7
# Train MAE:0.167572    Val MAE:0.165039    Test MAE:0.164134     Time:33.939149 s
# Epoch 8
# Train MAE:0.167552    Val MAE:0.164610    Test MAE:0.163254     Time:35.584588 s
# Epoch 9
# Train MAE:0.165740    Val MAE:0.160390    Test MAE:0.160343     Time:37.325290 s
# Epoch 10
# Train MAE:0.164947    Val MAE:0.156467    Test MAE:0.156143     Time:35.748142 s
# Epoch 11
# Train MAE:0.164791    Val MAE:0.161389    Test MAE:0.161092     Time:37.840164 s
# Epoch 12
# Train MAE:0.163278    Val MAE:0.157325    Test MAE:0.157497     Time:39.164754 s
# Epoch 13
# Train MAE:0.163361    Val MAE:0.168197    Test MAE:0.167411     Time:38.866076 s
# Epoch 14
# Train MAE:0.163283    Val MAE:0.156177    Test MAE:0.155417     Time:37.365213 s
# Epoch 15
# Train MAE:0.162292    Val MAE:0.160055    Test MAE:0.159142     Time:34.298714 s
# Epoch 16
# Train MAE:0.162154    Val MAE:0.155849    Test MAE:0.155610     Time:33.596540 s
# Epoch 17
# Train MAE:0.161307    Val MAE:0.158382    Test MAE:0.157994     Time:34.564984 s
# Epoch 18
# Train MAE:0.160326    Val MAE:0.155543    Test MAE:0.155423     Time:34.298698 s
# Epoch 19
# Train MAE:0.159981    Val MAE:0.171193    Test MAE:0.170317     Time:34.517455 s
# Epoch 20
# Train MAE:0.159057    Val MAE:0.156579    Test MAE:0.157402     Time:33.580674 s
# Epoch 21
# Train MAE:0.158630    Val MAE:0.151052    Test MAE:0.151093     Time:34.237420 s
# Epoch 22
# Train MAE:0.158103    Val MAE:0.164375    Test MAE:0.163396     Time:33.692133 s
# Epoch 23
# Train MAE:0.156974    Val MAE:0.151235    Test MAE:0.150026     Time:33.565646 s
# Epoch 24
# Train MAE:0.157008    Val MAE:0.150759    Test MAE:0.150869     Time:33.859961 s
# Epoch 25
# Train MAE:0.156049    Val MAE:0.168862    Test MAE:0.168920     Time:33.453377 s
# Epoch 26
# Train MAE:0.155404    Val MAE:0.150047    Test MAE:0.149524     Time:33.514896 s
# Epoch 27
# Train MAE:0.155393    Val MAE:0.170562    Test MAE:0.169489     Time:34.032224 s
# Epoch 28
# Train MAE:0.154638    Val MAE:0.149111    Test MAE:0.148431     Time:33.769438 s
# Epoch 29
# Train MAE:0.153885    Val MAE:0.148913    Test MAE:0.148577     Time:33.704215 s
# Epoch 30
# Train MAE:0.154102    Val MAE:0.174369    Test MAE:0.175454     Time:34.305281 s
# Epoch 31
# Train MAE:0.154137    Val MAE:0.149693    Test MAE:0.148954     Time:34.378164 s
# Epoch 32
# Train MAE:0.151511    Val MAE:0.149926    Test MAE:0.149572     Time:34.143349 s
# Epoch 33
# Train MAE:0.152406    Val MAE:0.146692    Test MAE:0.146367     Time:34.143749 s
# Epoch 34
# Train MAE:0.150892    Val MAE:0.146436    Test MAE:0.145876     Time:33.859814 s
# Epoch 35
# Train MAE:0.151152    Val MAE:0.149782    Test MAE:0.149177     Time:34.483851 s
# Epoch 36
# Train MAE:0.150707    Val MAE:0.158977    Test MAE:0.157587     Time:33.641110 s
# Epoch 37
# Train MAE:0.150486    Val MAE:0.148709    Test MAE:0.148371     Time:33.361770 s
# Epoch 38
# Train MAE:0.149522    Val MAE:0.157713    Test MAE:0.158122     Time:33.863072 s
# Epoch 39
# Train MAE:0.148843    Val MAE:0.150320    Test MAE:0.149476     Time:33.593668 s
# Epoch 40
# Train MAE:0.148164    Val MAE:0.144768    Test MAE:0.144435     Time:34.018015 s
# Epoch 41
# Train MAE:0.148428    Val MAE:0.152276    Test MAE:0.152634     Time:33.581095 s
# Epoch 42
# Train MAE:0.147772    Val MAE:0.205703    Test MAE:0.205904     Time:33.593311 s
# Epoch 43
# Train MAE:0.147785    Val MAE:0.149567    Test MAE:0.149382     Time:35.043352 s
# Epoch 44
# Train MAE:0.147417    Val MAE:0.140112    Test MAE:0.139989     Time:36.069591 s
# Epoch 45
# Train MAE:0.146695    Val MAE:0.154516    Test MAE:0.152999     Time:35.749681 s
# Epoch 46
# Train MAE:0.145892    Val MAE:0.143749    Test MAE:0.142965     Time:34.532901 s
# Epoch 47
# Train MAE:0.146808    Val MAE:0.177504    Test MAE:0.175902     Time:34.551093 s
# Epoch 48
# Train MAE:0.145962    Val MAE:0.140183    Test MAE:0.139296     Time:34.233618 s
# Epoch 49
# Train MAE:0.145764    Val MAE:0.139931    Test MAE:0.139273     Time:34.257381 s
# Epoch 50
# Train MAE:0.145413    Val MAE:0.141564    Test MAE:0.140443     Time:34.228653 s

# %%
with open("./result/DIFF_OPV_3.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %%
from torch_geometric.data import Batch

smiles_list=["Cc1c(C)c2c(F)c(-c3nc4c(C)c5c(ncn5C)c(C)c4n3C)sc2c2scc(F)c12",
             "COC(=O)N1C(F)(F)c2cccc(-c3ccc(-c4ccc5c6ccc(-c7cccs7)cc6n(C)c5c4)s3)c2C1(F)F"]

def get_S(smile_list,model):
    data_list=[]
    for smile in smiles_list:
        data_list.append(from_smiles(smile))
    batch=Batch.from_data_list(data_list)
    batch.x=to_dense_batch(batch.x,batch=batch.batch,max_num_nodes=max_nodes)[0].float()
    batch.adj=to_dense_adj(batch.edge_index,batch=batch.batch,max_num_nodes=max_nodes)
    batch=batch.cuda()

    model.eval()
    with torch.no_grad():
        S=model.gnn1_pool(batch.x,batch.adj)
    return S.cpu()

S=get_S(smiles_list,diffpool).numpy()
np.save("./saved_models/DIFF_OPV_S.npy",S)
