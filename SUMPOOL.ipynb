# %%
import torch
from torch_geometric.utils import from_smiles
import random
import pandas as pd
import numpy as np
from tqdm import tqdm


def split_list(input_list, ratio):
    input_list_copy = input_list.copy()
    total_length = len(input_list_copy)
    a_length = int(ratio[0] * total_length)
    b_length = int(ratio[1] * total_length)
    
    #random.seed(random_state)
    random.shuffle(input_list_copy)
    part_a = input_list_copy[:a_length]
    part_b = input_list_copy[a_length:a_length + b_length]
    part_c = input_list_copy[a_length + b_length:]

    return part_a, part_b, part_c

def load_dataset(filename,x_name,y_name1,y_name2):
    table=pd.read_csv(filename)
    result=[]
    for i in tqdm(range(table.shape[0])):
        cur_data=from_smiles(table[x_name][i])
        cur_data.y=torch.tensor([[table[y_name1][i],table[y_name2][i]]],dtype=torch.float32)
        result.append(cur_data)
    return result

def load_splited_dataset(filename,x_name,y_name1,y_name2,ratio=(0.8,0.1,0.1)):
    all_list=load_dataset(filename,x_name,y_name1,y_name2)
    return split_list(all_list,ratio)

# %%
from torch.nn import Linear, ReLU
from torch_geometric.nn import global_add_pool, global_mean_pool, global_max_pool,GCNConv

class GCN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels=32, out_channels=2,pool="add"):
        super(GCN, self).__init__()
        self.convs = torch.nn.ModuleList()
        self.convs.append(GCNConv(in_channels, hidden_channels))
        self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.convs.append(GCNConv(hidden_channels, hidden_channels))
        self.convs.append(GCNConv(hidden_channels, hidden_channels))
        
        self.lin1=Linear(hidden_channels, hidden_channels)
        self.lin2=Linear(hidden_channels, out_channels)
        
        if pool=="mean":
            self.pool=global_mean_pool
        elif pool=="add":
            self.pool=global_add_pool
        else:
            self.pool=global_max_pool
        
        self.act=ReLU()
        
    def forward(self, x, edge_index, batch):
        for step in range(len(self.convs)):
            x = self.act(self.convs[step](x, edge_index))
       
        x = self.pool(x,batch)
        
        x = self.act(self.lin1(x))
        x = self.lin2(x)
        
        return x

# %%
def train(model, loader, optimizer, loss_func):

    model.train()
    mae=0
    for data in loader:
        #data.y=data.y.reshape(-1,1)
        data.x=data.x.float()
        data=data.cuda()
        optimizer.zero_grad()
        pred=model(data.x, data.edge_index, data.batch)
        mae+=torch.sum(torch.abs(pred-data.y)).item()/2
        loss=loss_func(pred,data.y)
        loss.backward()
        optimizer.step()

    return model,mae/len(loader.dataset)

def test(model, loader):
    model.eval()
    mae=0
    with torch.no_grad():
        for data in loader:
            #data.y=data.y.reshape(-1,1)
            data.x=data.x.float()
            data=data.cuda()
            out = model(data.x, data.edge_index, data.batch)  
            mae+=torch.sum(torch.abs(out-data.y)).item()/2
        
    return mae / len(loader.dataset)

# %% [markdown]
# # QM9

# %%
from torch_geometric.seed import seed_everything

max_nodes=9
QM9=load_dataset("./dataset/QM9/QM9.csv","smiles","homo","lumo")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 133247/133247 [01:04<00:00, 2064.76it/s]

# %% [markdown]
# ### Exp 1

# %%
seed_everything(1222)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.data import Batch



train_loader = DataLoader(QM9_train, batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

gcn=GCN(num_features)
optimizer = torch.optim.Adam(params=gcn.parameters(), lr=0.001)
loss_fn=MSELoss()

gcn=gcn.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.032048    Val MAE:0.021600    Test MAE:0.021668     Time:10.144664 s
# Epoch 2
# Train MAE:0.020759    Val MAE:0.019258    Test MAE:0.019362     Time:10.989016 s
# Epoch 3
# Train MAE:0.018648    Val MAE:0.017207    Test MAE:0.017263     Time:11.041065 s
# Epoch 4
# Train MAE:0.017311    Val MAE:0.015623    Test MAE:0.015724     Time:11.301169 s
# Epoch 5
# Train MAE:0.016102    Val MAE:0.015455    Test MAE:0.015560     Time:10.931112 s
# Epoch 6
# Train MAE:0.015399    Val MAE:0.015892    Test MAE:0.015985     Time:10.975624 s
# Epoch 7
# Train MAE:0.014817    Val MAE:0.013830    Test MAE:0.013958     Time:10.683165 s
# Epoch 8
# Train MAE:0.014110    Val MAE:0.015053    Test MAE:0.015136     Time:10.381951 s
# Epoch 9
# Train MAE:0.013694    Val MAE:0.016018    Test MAE:0.016141     Time:10.550438 s
# Epoch 10
# Train MAE:0.013337    Val MAE:0.012391    Test MAE:0.012448     Time:11.256263 s
# Epoch 11
# Train MAE:0.012955    Val MAE:0.013204    Test MAE:0.013175     Time:11.008290 s
# Epoch 12
# Train MAE:0.012578    Val MAE:0.013105    Test MAE:0.013080     Time:10.834517 s
# Epoch 13
# Train MAE:0.012295    Val MAE:0.011427    Test MAE:0.011428     Time:10.551362 s
# Epoch 14
# Train MAE:0.011985    Val MAE:0.011412    Test MAE:0.011381     Time:10.398944 s
# Epoch 15
# Train MAE:0.011746    Val MAE:0.012089    Test MAE:0.012054     Time:10.710800 s
# Epoch 16
# Train MAE:0.011421    Val MAE:0.011569    Test MAE:0.011534     Time:10.746561 s
# Epoch 17
# Train MAE:0.011221    Val MAE:0.011808    Test MAE:0.011754     Time:10.926780 s
# Epoch 18
# Train MAE:0.010945    Val MAE:0.010554    Test MAE:0.010544     Time:11.112649 s
# Epoch 19
# Train MAE:0.010620    Val MAE:0.010264    Test MAE:0.010296     Time:11.008878 s
# Epoch 20
# Train MAE:0.010442    Val MAE:0.011032    Test MAE:0.011038     Time:10.896088 s
# Epoch 21
# Train MAE:0.010390    Val MAE:0.009970    Test MAE:0.010067     Time:10.505179 s
# Epoch 22
# Train MAE:0.010258    Val MAE:0.010001    Test MAE:0.010144     Time:10.503689 s
# Epoch 23
# Train MAE:0.010122    Val MAE:0.009356    Test MAE:0.009426     Time:11.004657 s
# Epoch 24
# Train MAE:0.010034    Val MAE:0.010056    Test MAE:0.010132     Time:11.077314 s
# Epoch 25
# Train MAE:0.009910    Val MAE:0.009800    Test MAE:0.009906     Time:10.755958 s
# Epoch 26
# Train MAE:0.009852    Val MAE:0.009928    Test MAE:0.009946     Time:11.179114 s
# Epoch 27
# Train MAE:0.009717    Val MAE:0.009483    Test MAE:0.009519     Time:10.978576 s
# Epoch 28
# Train MAE:0.009628    Val MAE:0.009197    Test MAE:0.009293     Time:14.089873 s
# Epoch 29
# Train MAE:0.009578    Val MAE:0.009417    Test MAE:0.009453     Time:10.479124 s
# Epoch 30
# Train MAE:0.009569    Val MAE:0.009657    Test MAE:0.009761     Time:10.558720 s
# Epoch 31
# Train MAE:0.009457    Val MAE:0.008562    Test MAE:0.008639     Time:11.252158 s
# Epoch 32
# Train MAE:0.009383    Val MAE:0.009072    Test MAE:0.009129     Time:11.506183 s
# Epoch 33
# Train MAE:0.009340    Val MAE:0.009647    Test MAE:0.009726     Time:11.194632 s
# Epoch 34
# Train MAE:0.009309    Val MAE:0.009307    Test MAE:0.009321     Time:11.210988 s
# Epoch 35
# Train MAE:0.009350    Val MAE:0.008777    Test MAE:0.008861     Time:10.961348 s
# Epoch 36
# Train MAE:0.009164    Val MAE:0.009190    Test MAE:0.009325     Time:10.865178 s
# Epoch 37
# Train MAE:0.009163    Val MAE:0.009234    Test MAE:0.009333     Time:11.162225 s
# Epoch 38
# Train MAE:0.009102    Val MAE:0.008839    Test MAE:0.008887     Time:10.678110 s
# Epoch 39
# Train MAE:0.009083    Val MAE:0.008662    Test MAE:0.008771     Time:10.741314 s
# Epoch 40
# Train MAE:0.009099    Val MAE:0.009070    Test MAE:0.009057     Time:11.677043 s
# Epoch 41
# Train MAE:0.008930    Val MAE:0.008389    Test MAE:0.008439     Time:10.950240 s
# Epoch 42
# Train MAE:0.009008    Val MAE:0.008830    Test MAE:0.008881     Time:11.343342 s
# Epoch 43
# Train MAE:0.008959    Val MAE:0.008311    Test MAE:0.008389     Time:11.179871 s
# Epoch 44
# Train MAE:0.008746    Val MAE:0.008399    Test MAE:0.008418     Time:11.075173 s
# Epoch 45
# Train MAE:0.008878    Val MAE:0.008266    Test MAE:0.008354     Time:11.146942 s
# Epoch 46
# Train MAE:0.008973    Val MAE:0.010333    Test MAE:0.010452     Time:11.052047 s
# Epoch 47
# Train MAE:0.008850    Val MAE:0.009103    Test MAE:0.009210     Time:10.731787 s
# Epoch 48
# Train MAE:0.008772    Val MAE:0.008982    Test MAE:0.009111     Time:11.042055 s
# Epoch 49
# Train MAE:0.008824    Val MAE:0.009324    Test MAE:0.009370     Time:10.807302 s
# Epoch 50
# Train MAE:0.008712    Val MAE:0.008255    Test MAE:0.008325     Time:10.979765 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=gcn.parameters(), lr=0.0005)
train_loader = DataLoader(QM9_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.008903    Val MAE:0.009112    Test MAE:0.009189     Time:28.918895 s
# Epoch 2
# Train MAE:0.008925    Val MAE:0.008532    Test MAE:0.008614     Time:29.637086 s
# Epoch 3
# Train MAE:0.008810    Val MAE:0.008352    Test MAE:0.008355     Time:30.206611 s
# Epoch 4
# Train MAE:0.008781    Val MAE:0.008310    Test MAE:0.008335     Time:30.487760 s
# Epoch 5
# Train MAE:0.008741    Val MAE:0.008644    Test MAE:0.008667     Time:31.969428 s
# Epoch 6
# Train MAE:0.008692    Val MAE:0.012028    Test MAE:0.011903     Time:30.426583 s
# Epoch 7
# Train MAE:0.008715    Val MAE:0.008191    Test MAE:0.008220     Time:29.549383 s
# Epoch 8
# Train MAE:0.008621    Val MAE:0.009043    Test MAE:0.009073     Time:30.268893 s
# Epoch 9
# Train MAE:0.008584    Val MAE:0.008209    Test MAE:0.008193     Time:28.172728 s
# Epoch 10
# Train MAE:0.008560    Val MAE:0.008689    Test MAE:0.008817     Time:28.165795 s
# Epoch 11
# Train MAE:0.008524    Val MAE:0.008913    Test MAE:0.008936     Time:28.103331 s
# Epoch 12
# Train MAE:0.008477    Val MAE:0.008214    Test MAE:0.008214     Time:30.062630 s
# Epoch 13
# Train MAE:0.008462    Val MAE:0.008599    Test MAE:0.008639     Time:29.652303 s
# Epoch 14
# Train MAE:0.008463    Val MAE:0.008360    Test MAE:0.008407     Time:29.347081 s
# Epoch 15
# Train MAE:0.008437    Val MAE:0.008998    Test MAE:0.009018     Time:28.023877 s
# Epoch 16
# Train MAE:0.008385    Val MAE:0.008500    Test MAE:0.008507     Time:28.009470 s
# Epoch 17
# Train MAE:0.008377    Val MAE:0.008292    Test MAE:0.008335     Time:28.110261 s
# Epoch 18
# Train MAE:0.008310    Val MAE:0.008500    Test MAE:0.008532     Time:27.891666 s
# Epoch 19
# Train MAE:0.008329    Val MAE:0.007974    Test MAE:0.007986     Time:27.757702 s
# Epoch 20
# Train MAE:0.008290    Val MAE:0.008025    Test MAE:0.008029     Time:27.864907 s
# Epoch 21
# Train MAE:0.008285    Val MAE:0.007914    Test MAE:0.007925     Time:28.130079 s
# Epoch 22
# Train MAE:0.008233    Val MAE:0.008123    Test MAE:0.008133     Time:29.299269 s
# Epoch 23
# Train MAE:0.008319    Val MAE:0.008386    Test MAE:0.008328     Time:29.705827 s
# Epoch 24
# Train MAE:0.008225    Val MAE:0.009590    Test MAE:0.009658     Time:29.487008 s
# Epoch 25
# Train MAE:0.008355    Val MAE:0.009021    Test MAE:0.009055     Time:29.424988 s
# Epoch 26
# Train MAE:0.008705    Val MAE:0.008163    Test MAE:0.008197     Time:29.924025 s
# Epoch 27
# Train MAE:0.008400    Val MAE:0.008512    Test MAE:0.008614     Time:31.222213 s
# Epoch 28
# Train MAE:0.008258    Val MAE:0.008501    Test MAE:0.008480     Time:31.095879 s
# Epoch 29
# Train MAE:0.008193    Val MAE:0.007913    Test MAE:0.007926     Time:29.472828 s
# Epoch 30
# Train MAE:0.008182    Val MAE:0.007973    Test MAE:0.007927     Time:29.281555 s
# Epoch 31
# Train MAE:0.008147    Val MAE:0.007962    Test MAE:0.008010     Time:29.598971 s
# Epoch 32
# Train MAE:0.008113    Val MAE:0.008059    Test MAE:0.008090     Time:28.249717 s
# Epoch 33
# Train MAE:0.008091    Val MAE:0.009158    Test MAE:0.009125     Time:27.601689 s
# Epoch 34
# Train MAE:0.008042    Val MAE:0.007739    Test MAE:0.007791     Time:27.765039 s
# Epoch 35
# Train MAE:0.008023    Val MAE:0.007890    Test MAE:0.007919     Time:27.857788 s
# Epoch 36
# Train MAE:0.008034    Val MAE:0.007977    Test MAE:0.007985     Time:27.765951 s
# Epoch 37
# Train MAE:0.008101    Val MAE:0.009040    Test MAE:0.009106     Time:27.584475 s
# Epoch 38
# Train MAE:0.008014    Val MAE:0.008318    Test MAE:0.008406     Time:27.779794 s
# Epoch 39
# Train MAE:0.007958    Val MAE:0.007833    Test MAE:0.007836     Time:28.015606 s
# Epoch 40
# Train MAE:0.007988    Val MAE:0.007695    Test MAE:0.007755     Time:30.227021 s
# Epoch 41
# Train MAE:0.007969    Val MAE:0.007525    Test MAE:0.007543     Time:30.778841 s
# Epoch 42
# Train MAE:0.007929    Val MAE:0.007426    Test MAE:0.007478     Time:31.326870 s
# Epoch 43
# Train MAE:0.007938    Val MAE:0.007453    Test MAE:0.007506     Time:29.644920 s
# Epoch 44
# Train MAE:0.007902    Val MAE:0.007709    Test MAE:0.007739     Time:29.628252 s
# Epoch 45
# Train MAE:0.007905    Val MAE:0.008137    Test MAE:0.008235     Time:29.048637 s
# Epoch 46
# Train MAE:0.007940    Val MAE:0.007713    Test MAE:0.007754     Time:29.174687 s
# Epoch 47
# Train MAE:0.007882    Val MAE:0.008146    Test MAE:0.008137     Time:30.628232 s
# Epoch 48
# Train MAE:0.007934    Val MAE:0.007614    Test MAE:0.007686     Time:30.534842 s
# Epoch 49
# Train MAE:0.007887    Val MAE:0.008586    Test MAE:0.008679     Time:30.722191 s
# Epoch 50
# Train MAE:0.007823    Val MAE:0.007649    Test MAE:0.007732     Time:29.225517 s

# %%
with open("./result/add_QM9_1.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 2

# %%
seed_everything(324)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.data import Batch



train_loader = DataLoader(QM9_train, batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

gcn=GCN(num_features)
optimizer = torch.optim.Adam(params=gcn.parameters(), lr=0.001)
loss_fn=MSELoss()

gcn=gcn.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.024230    Val MAE:0.018960    Test MAE:0.018890     Time:11.190283 s
# Epoch 2
# Train MAE:0.018027    Val MAE:0.016971    Test MAE:0.016903     Time:10.907537 s
# Epoch 3
# Train MAE:0.016321    Val MAE:0.016888    Test MAE:0.016880     Time:11.001810 s
# Epoch 4
# Train MAE:0.015212    Val MAE:0.016265    Test MAE:0.016207     Time:10.906961 s
# Epoch 5
# Train MAE:0.014623    Val MAE:0.014076    Test MAE:0.013955     Time:11.001211 s
# Epoch 6
# Train MAE:0.014015    Val MAE:0.014332    Test MAE:0.014208     Time:10.969944 s
# Epoch 7
# Train MAE:0.013498    Val MAE:0.013178    Test MAE:0.013054     Time:10.719079 s
# Epoch 8
# Train MAE:0.013300    Val MAE:0.012449    Test MAE:0.012288     Time:10.877997 s
# Epoch 9
# Train MAE:0.013075    Val MAE:0.012916    Test MAE:0.012775     Time:10.923617 s
# Epoch 10
# Train MAE:0.012859    Val MAE:0.012776    Test MAE:0.012696     Time:10.938210 s
# Epoch 11
# Train MAE:0.012642    Val MAE:0.011670    Test MAE:0.011521     Time:10.981494 s
# Epoch 12
# Train MAE:0.012304    Val MAE:0.012508    Test MAE:0.012355     Time:10.773714 s
# Epoch 13
# Train MAE:0.012152    Val MAE:0.011650    Test MAE:0.011490     Time:10.893483 s
# Epoch 14
# Train MAE:0.011923    Val MAE:0.012854    Test MAE:0.012808     Time:10.958358 s
# Epoch 15
# Train MAE:0.011694    Val MAE:0.011526    Test MAE:0.011478     Time:10.937649 s
# Epoch 16
# Train MAE:0.011363    Val MAE:0.011067    Test MAE:0.011013     Time:11.016210 s
# Epoch 17
# Train MAE:0.011081    Val MAE:0.012281    Test MAE:0.012224     Time:10.660103 s
# Epoch 18
# Train MAE:0.010810    Val MAE:0.011388    Test MAE:0.011349     Time:10.802471 s
# Epoch 19
# Train MAE:0.010698    Val MAE:0.010371    Test MAE:0.010322     Time:10.590844 s
# Epoch 20
# Train MAE:0.010640    Val MAE:0.010772    Test MAE:0.010657     Time:10.483784 s
# Epoch 21
# Train MAE:0.010537    Val MAE:0.010649    Test MAE:0.010545     Time:10.623953 s
# Epoch 22
# Train MAE:0.010356    Val MAE:0.010615    Test MAE:0.010545     Time:10.514270 s
# Epoch 23
# Train MAE:0.010140    Val MAE:0.010079    Test MAE:0.010042     Time:10.467849 s
# Epoch 24
# Train MAE:0.010349    Val MAE:0.010415    Test MAE:0.010365     Time:10.779458 s
# Epoch 25
# Train MAE:0.010201    Val MAE:0.009936    Test MAE:0.009874     Time:10.685871 s
# Epoch 26
# Train MAE:0.009864    Val MAE:0.009643    Test MAE:0.009615     Time:11.013613 s
# Epoch 27
# Train MAE:0.009588    Val MAE:0.009662    Test MAE:0.009629     Time:10.954056 s
# Epoch 28
# Train MAE:0.009683    Val MAE:0.009131    Test MAE:0.009045     Time:10.967717 s
# Epoch 29
# Train MAE:0.009339    Val MAE:0.009431    Test MAE:0.009363     Time:10.608216 s
# Epoch 30
# Train MAE:0.009205    Val MAE:0.008921    Test MAE:0.008905     Time:11.237587 s
# Epoch 31
# Train MAE:0.009230    Val MAE:0.008907    Test MAE:0.008873     Time:10.846016 s
# Epoch 32
# Train MAE:0.009141    Val MAE:0.008994    Test MAE:0.008972     Time:10.871435 s
# Epoch 33
# Train MAE:0.009358    Val MAE:0.008884    Test MAE:0.008852     Time:11.349601 s
# Epoch 34
# Train MAE:0.008903    Val MAE:0.009634    Test MAE:0.009525     Time:11.137116 s
# Epoch 35
# Train MAE:0.008896    Val MAE:0.008780    Test MAE:0.008684     Time:11.307260 s
# Epoch 36
# Train MAE:0.008884    Val MAE:0.009182    Test MAE:0.009142     Time:11.280108 s
# Epoch 37
# Train MAE:0.008953    Val MAE:0.008777    Test MAE:0.008697     Time:11.584253 s
# Epoch 38
# Train MAE:0.008776    Val MAE:0.008853    Test MAE:0.008769     Time:11.208670 s
# Epoch 39
# Train MAE:0.008768    Val MAE:0.008571    Test MAE:0.008533     Time:10.974087 s
# Epoch 40
# Train MAE:0.008759    Val MAE:0.008594    Test MAE:0.008500     Time:10.558021 s
# Epoch 41
# Train MAE:0.008689    Val MAE:0.009039    Test MAE:0.008996     Time:10.511151 s
# Epoch 42
# Train MAE:0.008639    Val MAE:0.008514    Test MAE:0.008426     Time:10.473656 s
# Epoch 43
# Train MAE:0.008543    Val MAE:0.008451    Test MAE:0.008375     Time:10.498085 s
# Epoch 44
# Train MAE:0.008579    Val MAE:0.008346    Test MAE:0.008311     Time:10.604017 s
# Epoch 45
# Train MAE:0.008597    Val MAE:0.008938    Test MAE:0.008906     Time:10.627705 s
# Epoch 46
# Train MAE:0.008514    Val MAE:0.008195    Test MAE:0.008156     Time:10.862525 s
# Epoch 47
# Train MAE:0.008472    Val MAE:0.008117    Test MAE:0.008018     Time:10.624698 s
# Epoch 48
# Train MAE:0.008593    Val MAE:0.008912    Test MAE:0.008773     Time:10.828412 s
# Epoch 49
# Train MAE:0.008322    Val MAE:0.008510    Test MAE:0.008391     Time:11.066591 s
# Epoch 50
# Train MAE:0.008352    Val MAE:0.008356    Test MAE:0.008246     Time:10.484723 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=gcn.parameters(), lr=0.0005)
train_loader = DataLoader(QM9_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.008628    Val MAE:0.009772    Test MAE:0.009671     Time:28.126235 s
# Epoch 2
# Train MAE:0.008503    Val MAE:0.008456    Test MAE:0.008340     Time:28.621672 s
# Epoch 3
# Train MAE:0.008564    Val MAE:0.008066    Test MAE:0.008002     Time:29.464919 s
# Epoch 4
# Train MAE:0.008436    Val MAE:0.008345    Test MAE:0.008274     Time:29.105677 s
# Epoch 5
# Train MAE:0.008380    Val MAE:0.008773    Test MAE:0.008693     Time:28.268985 s
# Epoch 6
# Train MAE:0.008476    Val MAE:0.008121    Test MAE:0.008038     Time:27.933624 s
# Epoch 7
# Train MAE:0.008412    Val MAE:0.009157    Test MAE:0.009104     Time:30.227737 s
# Epoch 8
# Train MAE:0.008444    Val MAE:0.009291    Test MAE:0.009190     Time:31.236367 s
# Epoch 9
# Train MAE:0.008301    Val MAE:0.008200    Test MAE:0.008120     Time:28.104127 s
# Epoch 10
# Train MAE:0.008382    Val MAE:0.008334    Test MAE:0.008274     Time:31.090159 s
# Epoch 11
# Train MAE:0.008272    Val MAE:0.008258    Test MAE:0.008133     Time:29.598911 s
# Epoch 12
# Train MAE:0.008305    Val MAE:0.008418    Test MAE:0.008347     Time:31.008630 s
# Epoch 13
# Train MAE:0.008255    Val MAE:0.008069    Test MAE:0.008007     Time:31.740269 s
# Epoch 14
# Train MAE:0.008161    Val MAE:0.008329    Test MAE:0.008284     Time:32.082961 s
# Epoch 15
# Train MAE:0.008222    Val MAE:0.008008    Test MAE:0.007927     Time:29.350324 s
# Epoch 16
# Train MAE:0.008181    Val MAE:0.007910    Test MAE:0.007850     Time:30.801355 s
# Epoch 17
# Train MAE:0.008154    Val MAE:0.007955    Test MAE:0.007864     Time:29.125721 s
# Epoch 18
# Train MAE:0.008126    Val MAE:0.007929    Test MAE:0.007838     Time:30.246142 s
# Epoch 19
# Train MAE:0.008097    Val MAE:0.007927    Test MAE:0.007824     Time:30.899990 s
# Epoch 20
# Train MAE:0.008201    Val MAE:0.008131    Test MAE:0.008018     Time:30.486959 s
# Epoch 21
# Train MAE:0.008131    Val MAE:0.008286    Test MAE:0.008253     Time:30.395745 s
# Epoch 22
# Train MAE:0.008255    Val MAE:0.008271    Test MAE:0.008170     Time:28.315178 s
# Epoch 23
# Train MAE:0.008039    Val MAE:0.007610    Test MAE:0.007528     Time:28.748578 s
# Epoch 24
# Train MAE:0.008051    Val MAE:0.008022    Test MAE:0.007923     Time:29.474638 s
# Epoch 25
# Train MAE:0.007998    Val MAE:0.008186    Test MAE:0.008121     Time:29.057627 s
# Epoch 26
# Train MAE:0.007972    Val MAE:0.007646    Test MAE:0.007584     Time:29.096990 s
# Epoch 27
# Train MAE:0.007917    Val MAE:0.008095    Test MAE:0.007978     Time:28.292822 s
# Epoch 28
# Train MAE:0.008012    Val MAE:0.008135    Test MAE:0.007999     Time:30.817776 s
# Epoch 29
# Train MAE:0.007927    Val MAE:0.007888    Test MAE:0.007816     Time:30.800132 s
# Epoch 30
# Train MAE:0.007929    Val MAE:0.008231    Test MAE:0.008114     Time:30.584022 s
# Epoch 31
# Train MAE:0.008090    Val MAE:0.007662    Test MAE:0.007578     Time:32.160452 s
# Epoch 32
# Train MAE:0.008150    Val MAE:0.007719    Test MAE:0.007644     Time:53.353314 s
# Epoch 33
# Train MAE:0.007844    Val MAE:0.007790    Test MAE:0.007711     Time:28.313233 s
# Epoch 34
# Train MAE:0.007919    Val MAE:0.007882    Test MAE:0.007871     Time:28.009582 s
# Epoch 35
# Train MAE:0.007918    Val MAE:0.007649    Test MAE:0.007567     Time:27.924412 s
# Epoch 36
# Train MAE:0.007835    Val MAE:0.007694    Test MAE:0.007617     Time:27.976685 s
# Epoch 37
# Train MAE:0.007771    Val MAE:0.008051    Test MAE:0.008005     Time:28.865091 s
# Epoch 38
# Train MAE:0.007927    Val MAE:0.008123    Test MAE:0.008072     Time:29.590405 s
# Epoch 39
# Train MAE:0.007900    Val MAE:0.008768    Test MAE:0.008688     Time:28.134451 s
# Epoch 40
# Train MAE:0.007824    Val MAE:0.009349    Test MAE:0.009324     Time:28.009562 s
# Epoch 41
# Train MAE:0.007967    Val MAE:0.007706    Test MAE:0.007685     Time:28.087696 s
# Epoch 42
# Train MAE:0.007886    Val MAE:0.007880    Test MAE:0.007789     Time:28.110253 s
# Epoch 43
# Train MAE:0.007685    Val MAE:0.007510    Test MAE:0.007406     Time:27.711934 s
# Epoch 44
# Train MAE:0.008098    Val MAE:0.007591    Test MAE:0.007531     Time:27.695402 s
# Epoch 45
# Train MAE:0.007868    Val MAE:0.010323    Test MAE:0.010264     Time:28.067749 s
# Epoch 46
# Train MAE:0.007750    Val MAE:0.007640    Test MAE:0.007552     Time:28.630544 s
# Epoch 47
# Train MAE:0.007734    Val MAE:0.007565    Test MAE:0.007498     Time:29.910975 s
# Epoch 48
# Train MAE:0.007841    Val MAE:0.007628    Test MAE:0.007560     Time:28.504653 s
# Epoch 49
# Train MAE:0.007704    Val MAE:0.007903    Test MAE:0.007820     Time:28.362208 s
# Epoch 50
# Train MAE:0.007676    Val MAE:0.008307    Test MAE:0.008179     Time:28.084399 s

# %%
with open("./result/add_QM9_2.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 3

# %%
seed_everything(10086)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.data import Batch



train_loader = DataLoader(QM9_train, batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

gcn=GCN(num_features)
optimizer = torch.optim.Adam(params=gcn.parameters(), lr=0.001)
loss_fn=MSELoss()

gcn=gcn.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.038906    Val MAE:0.019501    Test MAE:0.019511     Time:10.660135 s
# Epoch 2
# Train MAE:0.018903    Val MAE:0.018323    Test MAE:0.018324     Time:10.596021 s
# Epoch 3
# Train MAE:0.018236    Val MAE:0.017977    Test MAE:0.017907     Time:10.534784 s
# Epoch 4
# Train MAE:0.017786    Val MAE:0.017808    Test MAE:0.017727     Time:10.579240 s
# Epoch 5
# Train MAE:0.017291    Val MAE:0.017025    Test MAE:0.016907     Time:10.564251 s
# Epoch 6
# Train MAE:0.016904    Val MAE:0.017248    Test MAE:0.017201     Time:10.500715 s
# Epoch 7
# Train MAE:0.016447    Val MAE:0.015901    Test MAE:0.015800     Time:10.547025 s
# Epoch 8
# Train MAE:0.016139    Val MAE:0.015664    Test MAE:0.015616     Time:10.486035 s
# Epoch 9
# Train MAE:0.015722    Val MAE:0.015987    Test MAE:0.016010     Time:10.938538 s
# Epoch 10
# Train MAE:0.015525    Val MAE:0.015217    Test MAE:0.015260     Time:11.125907 s
# Epoch 11
# Train MAE:0.015108    Val MAE:0.014248    Test MAE:0.014272     Time:10.845234 s
# Epoch 12
# Train MAE:0.014570    Val MAE:0.014845    Test MAE:0.014807     Time:11.282072 s
# Epoch 13
# Train MAE:0.014312    Val MAE:0.013938    Test MAE:0.013930     Time:11.126466 s
# Epoch 14
# Train MAE:0.014012    Val MAE:0.013264    Test MAE:0.013303     Time:10.893090 s
# Epoch 15
# Train MAE:0.013517    Val MAE:0.012769    Test MAE:0.012823     Time:11.624190 s
# Epoch 16
# Train MAE:0.013256    Val MAE:0.013940    Test MAE:0.013962     Time:10.708655 s
# Epoch 17
# Train MAE:0.013003    Val MAE:0.013729    Test MAE:0.013870     Time:10.919988 s
# Epoch 18
# Train MAE:0.012783    Val MAE:0.013623    Test MAE:0.013709     Time:11.244976 s
# Epoch 19
# Train MAE:0.012426    Val MAE:0.013020    Test MAE:0.013133     Time:11.054363 s
# Epoch 20
# Train MAE:0.012201    Val MAE:0.011549    Test MAE:0.011649     Time:11.117262 s
# Epoch 21
# Train MAE:0.011884    Val MAE:0.011716    Test MAE:0.011843     Time:11.097150 s
# Epoch 22
# Train MAE:0.011684    Val MAE:0.011917    Test MAE:0.012067     Time:10.852878 s
# Epoch 23
# Train MAE:0.011404    Val MAE:0.010717    Test MAE:0.010771     Time:10.667473 s
# Epoch 24
# Train MAE:0.011275    Val MAE:0.011005    Test MAE:0.010983     Time:10.707645 s
# Epoch 25
# Train MAE:0.011056    Val MAE:0.010480    Test MAE:0.010522     Time:10.651369 s
# Epoch 26
# Train MAE:0.010809    Val MAE:0.011352    Test MAE:0.011346     Time:10.519828 s
# Epoch 27
# Train MAE:0.010563    Val MAE:0.010214    Test MAE:0.010153     Time:10.551149 s
# Epoch 28
# Train MAE:0.010663    Val MAE:0.009989    Test MAE:0.010016     Time:10.551060 s
# Epoch 29
# Train MAE:0.010378    Val MAE:0.010081    Test MAE:0.010194     Time:10.526745 s
# Epoch 30
# Train MAE:0.010291    Val MAE:0.010218    Test MAE:0.010311     Time:10.573769 s
# Epoch 31
# Train MAE:0.010218    Val MAE:0.009900    Test MAE:0.010067     Time:10.544070 s
# Epoch 32
# Train MAE:0.010126    Val MAE:0.009857    Test MAE:0.009879     Time:10.589987 s
# Epoch 33
# Train MAE:0.009924    Val MAE:0.010046    Test MAE:0.010107     Time:10.597262 s
# Epoch 34
# Train MAE:0.009836    Val MAE:0.009804    Test MAE:0.009812     Time:10.551110 s
# Epoch 35
# Train MAE:0.009908    Val MAE:0.009628    Test MAE:0.009662     Time:10.508245 s
# Epoch 36
# Train MAE:0.009827    Val MAE:0.009725    Test MAE:0.009747     Time:10.448915 s
# Epoch 37
# Train MAE:0.009738    Val MAE:0.009335    Test MAE:0.009315     Time:10.510514 s
# Epoch 38
# Train MAE:0.009618    Val MAE:0.009126    Test MAE:0.009182     Time:10.832190 s
# Epoch 39
# Train MAE:0.010049    Val MAE:0.009774    Test MAE:0.009832     Time:10.913685 s
# Epoch 40
# Train MAE:0.009676    Val MAE:0.010011    Test MAE:0.010133     Time:11.274705 s
# Epoch 41
# Train MAE:0.009599    Val MAE:0.009126    Test MAE:0.009174     Time:11.347412 s
# Epoch 42
# Train MAE:0.009486    Val MAE:0.009562    Test MAE:0.009618     Time:11.124054 s
# Epoch 43
# Train MAE:0.009657    Val MAE:0.009097    Test MAE:0.009128     Time:11.459866 s
# Epoch 44
# Train MAE:0.010299    Val MAE:0.010417    Test MAE:0.010484     Time:11.219342 s
# Epoch 45
# Train MAE:0.009935    Val MAE:0.009693    Test MAE:0.009721     Time:10.859020 s
# Epoch 46
# Train MAE:0.009632    Val MAE:0.009756    Test MAE:0.009858     Time:11.344068 s
# Epoch 47
# Train MAE:0.009475    Val MAE:0.009751    Test MAE:0.009817     Time:11.345614 s
# Epoch 48
# Train MAE:0.009395    Val MAE:0.009477    Test MAE:0.009643     Time:11.609893 s
# Epoch 49
# Train MAE:0.009367    Val MAE:0.009063    Test MAE:0.009088     Time:11.220037 s
# Epoch 50
# Train MAE:0.009977    Val MAE:0.009780    Test MAE:0.009856     Time:11.172163 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=gcn.parameters(), lr=0.0005)
train_loader = DataLoader(QM9_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.010025    Val MAE:0.010322    Test MAE:0.010374     Time:29.782142 s
# Epoch 2
# Train MAE:0.009756    Val MAE:0.009345    Test MAE:0.009393     Time:29.940613 s
# Epoch 3
# Train MAE:0.009641    Val MAE:0.009745    Test MAE:0.009857     Time:29.658635 s
# Epoch 4
# Train MAE:0.009426    Val MAE:0.009764    Test MAE:0.009752     Time:29.971265 s
# Epoch 5
# Train MAE:0.009345    Val MAE:0.010614    Test MAE:0.010666     Time:30.551906 s
# Epoch 6
# Train MAE:0.009303    Val MAE:0.008996    Test MAE:0.009136     Time:30.758164 s
# Epoch 7
# Train MAE:0.009243    Val MAE:0.012012    Test MAE:0.012158     Time:30.849506 s
# Epoch 8
# Train MAE:0.009238    Val MAE:0.009364    Test MAE:0.009388     Time:30.410216 s
# Epoch 9
# Train MAE:0.009099    Val MAE:0.008670    Test MAE:0.008767     Time:29.675457 s
# Epoch 10
# Train MAE:0.009005    Val MAE:0.009370    Test MAE:0.009486     Time:29.861810 s
# Epoch 11
# Train MAE:0.009007    Val MAE:0.008680    Test MAE:0.008752     Time:30.004535 s
# Epoch 12
# Train MAE:0.008955    Val MAE:0.009279    Test MAE:0.009315     Time:30.064974 s
# Epoch 13
# Train MAE:0.008936    Val MAE:0.008471    Test MAE:0.008553     Time:31.238368 s
# Epoch 14
# Train MAE:0.008893    Val MAE:0.009752    Test MAE:0.009765     Time:31.098563 s
# Epoch 15
# Train MAE:0.008945    Val MAE:0.009181    Test MAE:0.009370     Time:30.300275 s
# Epoch 16
# Train MAE:0.008796    Val MAE:0.008548    Test MAE:0.008616     Time:30.034589 s
# Epoch 17
# Train MAE:0.008865    Val MAE:0.009412    Test MAE:0.009470     Time:29.847920 s
# Epoch 18
# Train MAE:0.008822    Val MAE:0.008929    Test MAE:0.008979     Time:29.848804 s
# Epoch 19
# Train MAE:0.008735    Val MAE:0.008918    Test MAE:0.008999     Time:30.600019 s
# Epoch 20
# Train MAE:0.008700    Val MAE:0.008956    Test MAE:0.009090     Time:31.723890 s
# Epoch 21
# Train MAE:0.008708    Val MAE:0.009273    Test MAE:0.009324     Time:30.285580 s
# Epoch 22
# Train MAE:0.008726    Val MAE:0.008265    Test MAE:0.008378     Time:29.491610 s
# Epoch 23
# Train MAE:0.008649    Val MAE:0.008490    Test MAE:0.008664     Time:29.644521 s
# Epoch 24
# Train MAE:0.008631    Val MAE:0.008428    Test MAE:0.008506     Time:29.988865 s
# Epoch 25
# Train MAE:0.008872    Val MAE:0.008466    Test MAE:0.008597     Time:31.192765 s
# Epoch 26
# Train MAE:0.008497    Val MAE:0.008854    Test MAE:0.008970     Time:31.005178 s
# Epoch 27
# Train MAE:0.008620    Val MAE:0.008281    Test MAE:0.008451     Time:31.115313 s
# Epoch 28
# Train MAE:0.008526    Val MAE:0.008965    Test MAE:0.009144     Time:29.988081 s
# Epoch 29
# Train MAE:0.008592    Val MAE:0.009272    Test MAE:0.009347     Time:30.019533 s
# Epoch 30
# Train MAE:0.008587    Val MAE:0.008964    Test MAE:0.008999     Time:29.629236 s
# Epoch 31
# Train MAE:0.008500    Val MAE:0.008606    Test MAE:0.008693     Time:30.316146 s
# Epoch 32
# Train MAE:0.008528    Val MAE:0.008847    Test MAE:0.008955     Time:30.176033 s
# Epoch 33
# Train MAE:0.008546    Val MAE:0.013163    Test MAE:0.013262     Time:31.771848 s
# Epoch 34
# Train MAE:0.008509    Val MAE:0.008421    Test MAE:0.008482     Time:30.784544 s
# Epoch 35
# Train MAE:0.008451    Val MAE:0.009732    Test MAE:0.009774     Time:29.957197 s
# Epoch 36
# Train MAE:0.008503    Val MAE:0.008188    Test MAE:0.008292     Time:30.080993 s
# Epoch 37
# Train MAE:0.008463    Val MAE:0.008308    Test MAE:0.008470     Time:29.784185 s
# Epoch 38
# Train MAE:0.008377    Val MAE:0.008771    Test MAE:0.008954     Time:30.066365 s
# Epoch 39
# Train MAE:0.008372    Val MAE:0.008027    Test MAE:0.008183     Time:30.460272 s
# Epoch 40
# Train MAE:0.008408    Val MAE:0.008078    Test MAE:0.008215     Time:29.787054 s
# Epoch 41
# Train MAE:0.008384    Val MAE:0.007838    Test MAE:0.007981     Time:28.305047 s
# Epoch 42
# Train MAE:0.008324    Val MAE:0.008066    Test MAE:0.008145     Time:28.489416 s
# Epoch 43
# Train MAE:0.008389    Val MAE:0.009023    Test MAE:0.009085     Time:29.521829 s
# Epoch 44
# Train MAE:0.008290    Val MAE:0.008024    Test MAE:0.008174     Time:30.065607 s
# Epoch 45
# Train MAE:0.008349    Val MAE:0.008055    Test MAE:0.008138     Time:28.564827 s
# Epoch 46
# Train MAE:0.008407    Val MAE:0.008277    Test MAE:0.008458     Time:28.506554 s
# Epoch 47
# Train MAE:0.008349    Val MAE:0.008383    Test MAE:0.008446     Time:28.563281 s
# Epoch 48
# Train MAE:0.008271    Val MAE:0.007818    Test MAE:0.007903     Time:28.396591 s
# Epoch 49
# Train MAE:0.008362    Val MAE:0.008827    Test MAE:0.008937     Time:28.161197 s
# Epoch 50
# Train MAE:0.008226    Val MAE:0.008310    Test MAE:0.008472     Time:28.319630 s

# %%
with open("./result/add_QM9_3.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# # OPV

# %%
from torch_geometric.seed import seed_everything


max_nodes=122
OPV=load_dataset("./dataset/OPV/OPV.csv","smile","homo","lumo")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 90823/90823 [02:10<00:00, 696.74it/s]

# %% [markdown]
# ### Exp 1

# %%
seed_everything(1222)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.data import Batch



train_loader = DataLoader(OPV_train, batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

gcn=GCN(num_features)
optimizer = torch.optim.Adam(params=gcn.parameters(), lr=0.001)
loss_fn=MSELoss()

gcn=gcn.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:1.029906    Val MAE:0.840099    Test MAE:0.834244     Time:7.757654 s
# Epoch 2
# Train MAE:0.734528    Val MAE:0.651267    Test MAE:0.646685     Time:7.629367 s
# Epoch 3
# Train MAE:0.475745    Val MAE:0.354436    Test MAE:0.357872     Time:8.507131 s
# Epoch 4
# Train MAE:0.300074    Val MAE:0.266318    Test MAE:0.267701     Time:8.975364 s
# Epoch 5
# Train MAE:0.269408    Val MAE:0.260329    Test MAE:0.261090     Time:8.302126 s
# Epoch 6
# Train MAE:0.259677    Val MAE:0.243091    Test MAE:0.243489     Time:8.719703 s
# Epoch 7
# Train MAE:0.248404    Val MAE:0.240666    Test MAE:0.241590     Time:8.734623 s
# Epoch 8
# Train MAE:0.244723    Val MAE:0.242691    Test MAE:0.242118     Time:8.546660 s
# Epoch 9
# Train MAE:0.241106    Val MAE:0.236973    Test MAE:0.236846     Time:8.561647 s
# Epoch 10
# Train MAE:0.237861    Val MAE:0.233309    Test MAE:0.232794     Time:9.014513 s
# Epoch 11
# Train MAE:0.228343    Val MAE:0.256211    Test MAE:0.255089     Time:8.608917 s
# Epoch 12
# Train MAE:0.223991    Val MAE:0.213314    Test MAE:0.212721     Time:9.046817 s
# Epoch 13
# Train MAE:0.217999    Val MAE:0.209288    Test MAE:0.209986     Time:9.015246 s
# Epoch 14
# Train MAE:0.212491    Val MAE:0.200655    Test MAE:0.201006     Time:9.045213 s
# Epoch 15
# Train MAE:0.209584    Val MAE:0.203080    Test MAE:0.204121     Time:8.824170 s
# Epoch 16
# Train MAE:0.201730    Val MAE:0.223126    Test MAE:0.223559     Time:9.809750 s
# Epoch 17
# Train MAE:0.198824    Val MAE:0.192686    Test MAE:0.192461     Time:10.142535 s
# Epoch 18
# Train MAE:0.193072    Val MAE:0.190237    Test MAE:0.190663     Time:9.364357 s
# Epoch 19
# Train MAE:0.190803    Val MAE:0.188668    Test MAE:0.190083     Time:9.227463 s
# Epoch 20
# Train MAE:0.188711    Val MAE:0.177459    Test MAE:0.177780     Time:8.759570 s
# Epoch 21
# Train MAE:0.183415    Val MAE:0.174637    Test MAE:0.175327     Time:9.001876 s
# Epoch 22
# Train MAE:0.181120    Val MAE:0.170824    Test MAE:0.171397     Time:8.954219 s
# Epoch 23
# Train MAE:0.177192    Val MAE:0.176138    Test MAE:0.175855     Time:9.528665 s
# Epoch 24
# Train MAE:0.175491    Val MAE:0.177162    Test MAE:0.176539     Time:9.094891 s
# Epoch 25
# Train MAE:0.173031    Val MAE:0.163034    Test MAE:0.163473     Time:9.153100 s
# Epoch 26
# Train MAE:0.169574    Val MAE:0.161938    Test MAE:0.162508     Time:9.105659 s
# Epoch 27
# Train MAE:0.170895    Val MAE:0.163266    Test MAE:0.163534     Time:9.497638 s
# Epoch 28
# Train MAE:0.164639    Val MAE:0.172995    Test MAE:0.172962     Time:10.243953 s
# Epoch 29
# Train MAE:0.164153    Val MAE:0.161422    Test MAE:0.160708     Time:9.432180 s
# Epoch 30
# Train MAE:0.162746    Val MAE:0.154597    Test MAE:0.154537     Time:9.503093 s
# Epoch 31
# Train MAE:0.161388    Val MAE:0.177453    Test MAE:0.177830     Time:9.285434 s
# Epoch 32
# Train MAE:0.159234    Val MAE:0.156821    Test MAE:0.156476     Time:9.581598 s
# Epoch 33
# Train MAE:0.156994    Val MAE:0.157303    Test MAE:0.156587     Time:9.301236 s
# Epoch 34
# Train MAE:0.156081    Val MAE:0.156948    Test MAE:0.155751     Time:9.297392 s
# Epoch 35
# Train MAE:0.155343    Val MAE:0.150334    Test MAE:0.150062     Time:9.340492 s
# Epoch 36
# Train MAE:0.153005    Val MAE:0.152665    Test MAE:0.152285     Time:9.496296 s
# Epoch 37
# Train MAE:0.149938    Val MAE:0.149521    Test MAE:0.148851     Time:9.990241 s
# Epoch 38
# Train MAE:0.149993    Val MAE:0.161515    Test MAE:0.160572     Time:9.883228 s
# Epoch 39
# Train MAE:0.149029    Val MAE:0.147995    Test MAE:0.147525     Time:9.904386 s
# Epoch 40
# Train MAE:0.146742    Val MAE:0.154351    Test MAE:0.153392     Time:9.072588 s
# Epoch 41
# Train MAE:0.146451    Val MAE:0.142316    Test MAE:0.141744     Time:9.498889 s
# Epoch 42
# Train MAE:0.144574    Val MAE:0.140761    Test MAE:0.138826     Time:9.266613 s
# Epoch 43
# Train MAE:0.143694    Val MAE:0.144634    Test MAE:0.142543     Time:9.233284 s
# Epoch 44
# Train MAE:0.142985    Val MAE:0.155029    Test MAE:0.152989     Time:9.530878 s
# Epoch 45
# Train MAE:0.140007    Val MAE:0.140102    Test MAE:0.139392     Time:9.563250 s
# Epoch 46
# Train MAE:0.139768    Val MAE:0.135345    Test MAE:0.133049     Time:9.359118 s
# Epoch 47
# Train MAE:0.138938    Val MAE:0.134106    Test MAE:0.133183     Time:9.639765 s
# Epoch 48
# Train MAE:0.137119    Val MAE:0.139439    Test MAE:0.136958     Time:9.783932 s
# Epoch 49
# Train MAE:0.136542    Val MAE:0.138123    Test MAE:0.136341     Time:9.683001 s
# Epoch 50
# Train MAE:0.135192    Val MAE:0.130862    Test MAE:0.129564     Time:9.577816 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=gcn.parameters(), lr=0.0005)
train_loader = DataLoader(OPV_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.138364    Val MAE:0.133369    Test MAE:0.132632     Time:22.488034 s
# Epoch 2
# Train MAE:0.136205    Val MAE:0.135285    Test MAE:0.133737     Time:22.139810 s
# Epoch 3
# Train MAE:0.134900    Val MAE:0.137306    Test MAE:0.135755     Time:23.335250 s
# Epoch 4
# Train MAE:0.133748    Val MAE:0.139698    Test MAE:0.137180     Time:21.699088 s
# Epoch 5
# Train MAE:0.133177    Val MAE:0.130258    Test MAE:0.128920     Time:21.515346 s
# Epoch 6
# Train MAE:0.131533    Val MAE:0.125676    Test MAE:0.124984     Time:21.683317 s
# Epoch 7
# Train MAE:0.131318    Val MAE:0.129066    Test MAE:0.128134     Time:21.656097 s
# Epoch 8
# Train MAE:0.130681    Val MAE:0.121209    Test MAE:0.119193     Time:22.364965 s
# Epoch 9
# Train MAE:0.129105    Val MAE:0.121675    Test MAE:0.120299     Time:22.866952 s
# Epoch 10
# Train MAE:0.128735    Val MAE:0.123574    Test MAE:0.122148     Time:22.925816 s
# Epoch 11
# Train MAE:0.127870    Val MAE:0.130467    Test MAE:0.129510     Time:23.018086 s
# Epoch 12
# Train MAE:0.126882    Val MAE:0.130353    Test MAE:0.129164     Time:23.867610 s
# Epoch 13
# Train MAE:0.125425    Val MAE:0.117443    Test MAE:0.116504     Time:23.269212 s
# Epoch 14
# Train MAE:0.124414    Val MAE:0.117794    Test MAE:0.116581     Time:23.270239 s
# Epoch 15
# Train MAE:0.123430    Val MAE:0.125728    Test MAE:0.125723     Time:23.686374 s
# Epoch 16
# Train MAE:0.123887    Val MAE:0.122565    Test MAE:0.121765     Time:22.713349 s
# Epoch 17
# Train MAE:0.121869    Val MAE:0.118712    Test MAE:0.117284     Time:22.318248 s
# Epoch 18
# Train MAE:0.121418    Val MAE:0.117999    Test MAE:0.117069     Time:22.787860 s
# Epoch 19
# Train MAE:0.120647    Val MAE:0.116555    Test MAE:0.115174     Time:21.848210 s
# Epoch 20
# Train MAE:0.120053    Val MAE:0.120046    Test MAE:0.118959     Time:21.961035 s
# Epoch 21
# Train MAE:0.118918    Val MAE:0.110972    Test MAE:0.109534     Time:21.865327 s
# Epoch 22
# Train MAE:0.117704    Val MAE:0.138631    Test MAE:0.137137     Time:22.118792 s
# Epoch 23
# Train MAE:0.118265    Val MAE:0.114201    Test MAE:0.112994     Time:21.800166 s
# Epoch 24
# Train MAE:0.117698    Val MAE:0.126036    Test MAE:0.124105     Time:21.771422 s
# Epoch 25
# Train MAE:0.116376    Val MAE:0.109281    Test MAE:0.108559     Time:21.913444 s
# Epoch 26
# Train MAE:0.115100    Val MAE:0.123700    Test MAE:0.122654     Time:21.833607 s
# Epoch 27
# Train MAE:0.114959    Val MAE:0.111520    Test MAE:0.110520     Time:21.594124 s
# Epoch 28
# Train MAE:0.114187    Val MAE:0.142157    Test MAE:0.140901     Time:21.942714 s
# Epoch 29
# Train MAE:0.112937    Val MAE:0.110210    Test MAE:0.110672     Time:22.054453 s
# Epoch 30
# Train MAE:0.112793    Val MAE:0.106771    Test MAE:0.105784     Time:21.632233 s
# Epoch 31
# Train MAE:0.111797    Val MAE:0.113130    Test MAE:0.113017     Time:21.868328 s
# Epoch 32
# Train MAE:0.111439    Val MAE:0.109522    Test MAE:0.108382     Time:21.807850 s
# Epoch 33
# Train MAE:0.110923    Val MAE:0.112541    Test MAE:0.111876     Time:21.690931 s
# Epoch 34
# Train MAE:0.109714    Val MAE:0.113261    Test MAE:0.112620     Time:22.325306 s
# Epoch 35
# Train MAE:0.109071    Val MAE:0.107713    Test MAE:0.106457     Time:22.178842 s
# Epoch 36
# Train MAE:0.109239    Val MAE:0.101189    Test MAE:0.100476     Time:23.975566 s
# Epoch 37
# Train MAE:0.107518    Val MAE:0.108229    Test MAE:0.107833     Time:22.908138 s
# Epoch 38
# Train MAE:0.107970    Val MAE:0.101648    Test MAE:0.100735     Time:23.486266 s
# Epoch 39
# Train MAE:0.107436    Val MAE:0.099528    Test MAE:0.099039     Time:23.389158 s
# Epoch 40
# Train MAE:0.106840    Val MAE:0.100717    Test MAE:0.100519     Time:22.895169 s
# Epoch 41
# Train MAE:0.105790    Val MAE:0.101672    Test MAE:0.100484     Time:22.585750 s
# Epoch 42
# Train MAE:0.105514    Val MAE:0.101909    Test MAE:0.101655     Time:22.061310 s
# Epoch 43
# Train MAE:0.105713    Val MAE:0.102377    Test MAE:0.101907     Time:22.257576 s
# Epoch 44
# Train MAE:0.104395    Val MAE:0.104669    Test MAE:0.104529     Time:22.158173 s
# Epoch 45
# Train MAE:0.104807    Val MAE:0.106035    Test MAE:0.105179     Time:22.705307 s
# Epoch 46
# Train MAE:0.104436    Val MAE:0.099675    Test MAE:0.098833     Time:22.553483 s
# Epoch 47
# Train MAE:0.103735    Val MAE:0.111826    Test MAE:0.110945     Time:22.977201 s
# Epoch 48
# Train MAE:0.104337    Val MAE:0.101242    Test MAE:0.100946     Time:23.104295 s
# Epoch 49
# Train MAE:0.102791    Val MAE:0.100933    Test MAE:0.100899     Time:23.615368 s
# Epoch 50
# Train MAE:0.102381    Val MAE:0.095789    Test MAE:0.095705     Time:21.976261 s

# %%
with open("./result/add_OPV_1.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 2

# %%
seed_everything(324)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.data import Batch



train_loader = DataLoader(OPV_train, batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

gcn=GCN(num_features)
optimizer = torch.optim.Adam(params=gcn.parameters(), lr=0.001)
loss_fn=MSELoss()

gcn=gcn.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.900548    Val MAE:0.698292    Test MAE:0.694440     Time:10.491447 s
# Epoch 2
# Train MAE:0.564872    Val MAE:0.426035    Test MAE:0.424888     Time:10.050725 s
# Epoch 3
# Train MAE:0.339086    Val MAE:0.295269    Test MAE:0.298256     Time:10.407543 s
# Epoch 4
# Train MAE:0.276643    Val MAE:0.257259    Test MAE:0.257409     Time:9.696388 s
# Epoch 5
# Train MAE:0.256453    Val MAE:0.241629    Test MAE:0.242629     Time:10.266613 s
# Epoch 6
# Train MAE:0.244935    Val MAE:0.250922    Test MAE:0.250340     Time:10.486255 s
# Epoch 7
# Train MAE:0.237603    Val MAE:0.281863    Test MAE:0.279414     Time:9.942109 s
# Epoch 8
# Train MAE:0.229916    Val MAE:0.217909    Test MAE:0.218774     Time:9.815038 s
# Epoch 9
# Train MAE:0.221922    Val MAE:0.214642    Test MAE:0.216563     Time:9.615483 s
# Epoch 10
# Train MAE:0.214932    Val MAE:0.205916    Test MAE:0.206923     Time:10.022131 s
# Epoch 11
# Train MAE:0.204387    Val MAE:0.207830    Test MAE:0.207158     Time:9.635051 s
# Epoch 12
# Train MAE:0.198759    Val MAE:0.223951    Test MAE:0.226861     Time:10.951118 s
# Epoch 13
# Train MAE:0.195330    Val MAE:0.187193    Test MAE:0.187820     Time:11.168932 s
# Epoch 14
# Train MAE:0.188130    Val MAE:0.194111    Test MAE:0.195109     Time:10.860422 s
# Epoch 15
# Train MAE:0.182661    Val MAE:0.174702    Test MAE:0.174081     Time:11.308979 s
# Epoch 16
# Train MAE:0.177186    Val MAE:0.189501    Test MAE:0.189960     Time:10.937069 s
# Epoch 17
# Train MAE:0.177849    Val MAE:0.163846    Test MAE:0.163569     Time:9.673866 s
# Epoch 18
# Train MAE:0.168929    Val MAE:0.170244    Test MAE:0.168495     Time:10.300301 s
# Epoch 19
# Train MAE:0.164417    Val MAE:0.163914    Test MAE:0.164124     Time:9.554173 s
# Epoch 20
# Train MAE:0.160168    Val MAE:0.157526    Test MAE:0.156582     Time:9.969520 s
# Epoch 21
# Train MAE:0.158614    Val MAE:0.160399    Test MAE:0.160442     Time:10.052688 s
# Epoch 22
# Train MAE:0.155452    Val MAE:0.172440    Test MAE:0.171112     Time:10.401324 s
# Epoch 23
# Train MAE:0.151780    Val MAE:0.149045    Test MAE:0.148302     Time:10.533164 s
# Epoch 24
# Train MAE:0.148291    Val MAE:0.147479    Test MAE:0.146900     Time:10.492274 s
# Epoch 25
# Train MAE:0.146743    Val MAE:0.148557    Test MAE:0.148151     Time:10.077190 s
# Epoch 26
# Train MAE:0.146508    Val MAE:0.143494    Test MAE:0.143034     Time:10.323806 s
# Epoch 27
# Train MAE:0.142032    Val MAE:0.154901    Test MAE:0.154217     Time:10.789940 s
# Epoch 28
# Train MAE:0.139187    Val MAE:0.137706    Test MAE:0.137067     Time:10.326652 s
# Epoch 29
# Train MAE:0.138878    Val MAE:0.131159    Test MAE:0.130710     Time:10.460731 s
# Epoch 30
# Train MAE:0.136124    Val MAE:0.138342    Test MAE:0.138232     Time:10.019613 s
# Epoch 31
# Train MAE:0.135032    Val MAE:0.145489    Test MAE:0.145663     Time:10.130403 s
# Epoch 32
# Train MAE:0.133625    Val MAE:0.139232    Test MAE:0.139588     Time:10.583172 s
# Epoch 33
# Train MAE:0.131869    Val MAE:0.148168    Test MAE:0.148135     Time:10.406360 s
# Epoch 34
# Train MAE:0.130365    Val MAE:0.140396    Test MAE:0.140877     Time:10.498568 s
# Epoch 35
# Train MAE:0.129627    Val MAE:0.127169    Test MAE:0.127565     Time:10.753048 s
# Epoch 36
# Train MAE:0.127103    Val MAE:0.126242    Test MAE:0.126193     Time:10.760740 s
# Epoch 37
# Train MAE:0.125763    Val MAE:0.122535    Test MAE:0.122890     Time:10.619056 s
# Epoch 38
# Train MAE:0.125762    Val MAE:0.120479    Test MAE:0.119618     Time:10.012036 s
# Epoch 39
# Train MAE:0.124248    Val MAE:0.120678    Test MAE:0.120803     Time:9.843797 s
# Epoch 40
# Train MAE:0.123918    Val MAE:0.128073    Test MAE:0.127086     Time:9.866509 s
# Epoch 41
# Train MAE:0.122837    Val MAE:0.122731    Test MAE:0.122323     Time:9.911692 s
# Epoch 42
# Train MAE:0.120913    Val MAE:0.120155    Test MAE:0.119975     Time:9.775263 s
# Epoch 43
# Train MAE:0.121130    Val MAE:0.121066    Test MAE:0.120823     Time:11.041905 s
# Epoch 44
# Train MAE:0.118823    Val MAE:0.116612    Test MAE:0.116461     Time:10.283893 s
# Epoch 45
# Train MAE:0.120123    Val MAE:0.117419    Test MAE:0.116601     Time:10.384407 s
# Epoch 46
# Train MAE:0.117160    Val MAE:0.115994    Test MAE:0.116162     Time:10.466156 s
# Epoch 47
# Train MAE:0.116761    Val MAE:0.124720    Test MAE:0.124503     Time:10.342509 s
# Epoch 48
# Train MAE:0.116280    Val MAE:0.111306    Test MAE:0.111163     Time:10.542458 s
# Epoch 49
# Train MAE:0.115440    Val MAE:0.117262    Test MAE:0.117774     Time:10.358371 s
# Epoch 50
# Train MAE:0.114995    Val MAE:0.112140    Test MAE:0.111882     Time:10.335933 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=gcn.parameters(), lr=0.0005)
train_loader = DataLoader(OPV_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.115992    Val MAE:0.113842    Test MAE:0.113351     Time:22.317189 s
# Epoch 2
# Train MAE:0.115338    Val MAE:0.109012    Test MAE:0.109684     Time:22.224247 s
# Epoch 3
# Train MAE:0.114503    Val MAE:0.118269    Test MAE:0.118280     Time:22.408585 s
# Epoch 4
# Train MAE:0.113110    Val MAE:0.122508    Test MAE:0.122340     Time:21.814739 s
# Epoch 5
# Train MAE:0.111539    Val MAE:0.112248    Test MAE:0.112335     Time:22.590846 s
# Epoch 6
# Train MAE:0.110788    Val MAE:0.115355    Test MAE:0.115561     Time:22.297125 s
# Epoch 7
# Train MAE:0.110043    Val MAE:0.106424    Test MAE:0.106376     Time:21.854786 s
# Epoch 8
# Train MAE:0.108995    Val MAE:0.105572    Test MAE:0.105100     Time:21.760057 s
# Epoch 9
# Train MAE:0.108182    Val MAE:0.106712    Test MAE:0.106800     Time:22.150644 s
# Epoch 10
# Train MAE:0.106965    Val MAE:0.105933    Test MAE:0.105496     Time:22.740145 s
# Epoch 11
# Train MAE:0.106476    Val MAE:0.103346    Test MAE:0.103446     Time:21.934880 s
# Epoch 12
# Train MAE:0.106215    Val MAE:0.107535    Test MAE:0.107694     Time:21.775777 s
# Epoch 13
# Train MAE:0.104095    Val MAE:0.110242    Test MAE:0.111161     Time:22.414597 s
# Epoch 14
# Train MAE:0.103693    Val MAE:0.102223    Test MAE:0.102529     Time:21.824027 s
# Epoch 15
# Train MAE:0.103134    Val MAE:0.113376    Test MAE:0.112476     Time:21.838964 s
# Epoch 16
# Train MAE:0.102284    Val MAE:0.104085    Test MAE:0.103909     Time:21.948171 s
# Epoch 17
# Train MAE:0.102156    Val MAE:0.098789    Test MAE:0.099105     Time:22.101949 s
# Epoch 18
# Train MAE:0.101725    Val MAE:0.099663    Test MAE:0.098789     Time:21.685655 s
# Epoch 19
# Train MAE:0.100421    Val MAE:0.099226    Test MAE:0.099997     Time:21.649523 s
# Epoch 20
# Train MAE:0.100335    Val MAE:0.106080    Test MAE:0.106378     Time:22.352385 s
# Epoch 21
# Train MAE:0.099608    Val MAE:0.099510    Test MAE:0.098997     Time:22.476014 s
# Epoch 22
# Train MAE:0.098866    Val MAE:0.101751    Test MAE:0.101743     Time:23.056553 s
# Epoch 23
# Train MAE:0.098248    Val MAE:0.103197    Test MAE:0.103188     Time:23.240049 s
# Epoch 24
# Train MAE:0.097688    Val MAE:0.096663    Test MAE:0.096714     Time:22.294060 s
# Epoch 25
# Train MAE:0.096920    Val MAE:0.100846    Test MAE:0.100201     Time:21.923627 s
# Epoch 26
# Train MAE:0.097025    Val MAE:0.100950    Test MAE:0.100616     Time:22.748885 s
# Epoch 27
# Train MAE:0.096197    Val MAE:0.092862    Test MAE:0.092031     Time:22.823100 s
# Epoch 28
# Train MAE:0.096004    Val MAE:0.113504    Test MAE:0.112834     Time:22.578335 s
# Epoch 29
# Train MAE:0.095557    Val MAE:0.104761    Test MAE:0.105273     Time:23.111023 s
# Epoch 30
# Train MAE:0.095057    Val MAE:0.093931    Test MAE:0.093381     Time:22.575951 s
# Epoch 31
# Train MAE:0.094460    Val MAE:0.101939    Test MAE:0.102204     Time:21.806596 s
# Epoch 32
# Train MAE:0.094377    Val MAE:0.095894    Test MAE:0.096660     Time:21.753702 s
# Epoch 33
# Train MAE:0.094060    Val MAE:0.102749    Test MAE:0.102933     Time:21.952044 s
# Epoch 34
# Train MAE:0.093487    Val MAE:0.093897    Test MAE:0.094744     Time:21.766477 s
# Epoch 35
# Train MAE:0.093041    Val MAE:0.089596    Test MAE:0.089638     Time:21.705307 s
# Epoch 36
# Train MAE:0.091987    Val MAE:0.091637    Test MAE:0.091358     Time:21.978178 s
# Epoch 37
# Train MAE:0.092468    Val MAE:0.091119    Test MAE:0.090581     Time:21.671541 s
# Epoch 38
# Train MAE:0.091778    Val MAE:0.089206    Test MAE:0.089476     Time:21.701203 s
# Epoch 39
# Train MAE:0.091643    Val MAE:0.087966    Test MAE:0.087301     Time:21.764561 s
# Epoch 40
# Train MAE:0.091002    Val MAE:0.094011    Test MAE:0.094596     Time:21.718314 s
# Epoch 41
# Train MAE:0.090675    Val MAE:0.089521    Test MAE:0.089174     Time:21.961744 s
# Epoch 42
# Train MAE:0.090446    Val MAE:0.087937    Test MAE:0.087591     Time:22.259218 s
# Epoch 43
# Train MAE:0.089641    Val MAE:0.088414    Test MAE:0.088370     Time:21.762824 s
# Epoch 44
# Train MAE:0.089352    Val MAE:0.088593    Test MAE:0.087192     Time:21.760103 s
# Epoch 45
# Train MAE:0.089529    Val MAE:0.091816    Test MAE:0.091707     Time:21.832798 s
# Epoch 46
# Train MAE:0.088516    Val MAE:0.090904    Test MAE:0.090368     Time:21.984219 s
# Epoch 47
# Train MAE:0.088663    Val MAE:0.098625    Test MAE:0.097907     Time:21.638762 s
# Epoch 48
# Train MAE:0.088392    Val MAE:0.095102    Test MAE:0.094682     Time:22.128712 s
# Epoch 49
# Train MAE:0.088223    Val MAE:0.088590    Test MAE:0.088904     Time:22.249165 s
# Epoch 50
# Train MAE:0.087924    Val MAE:0.084985    Test MAE:0.084021     Time:22.233433 s

# %%
with open("./result/add_OPV_2.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 3

# %%
seed_everything(10086)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DataLoader
from torch_geometric.data import Batch



train_loader = DataLoader(OPV_train, batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

gcn=GCN(num_features)
optimizer = torch.optim.Adam(params=gcn.parameters(), lr=0.001)
loss_fn=MSELoss()

gcn=gcn.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:1.198642    Val MAE:0.886652    Test MAE:0.891289     Time:9.821631 s
# Epoch 2
# Train MAE:0.825880    Val MAE:0.760654    Test MAE:0.759565     Time:9.584570 s
# Epoch 3
# Train MAE:0.607271    Val MAE:0.494748    Test MAE:0.489092     Time:9.598932 s
# Epoch 4
# Train MAE:0.404798    Val MAE:0.335594    Test MAE:0.331304     Time:9.478515 s
# Epoch 5
# Train MAE:0.301792    Val MAE:0.269259    Test MAE:0.266798     Time:9.993204 s
# Epoch 6
# Train MAE:0.266146    Val MAE:0.250712    Test MAE:0.249755     Time:9.579704 s
# Epoch 7
# Train MAE:0.252787    Val MAE:0.282961    Test MAE:0.280994     Time:9.583213 s
# Epoch 8
# Train MAE:0.245890    Val MAE:0.244339    Test MAE:0.244014     Time:9.646999 s
# Epoch 9
# Train MAE:0.241617    Val MAE:0.271652    Test MAE:0.270562     Time:10.115134 s
# Epoch 10
# Train MAE:0.241635    Val MAE:0.236415    Test MAE:0.235745     Time:10.341423 s
# Epoch 11
# Train MAE:0.237529    Val MAE:0.235220    Test MAE:0.235930     Time:10.755197 s
# Epoch 12
# Train MAE:0.228970    Val MAE:0.220287    Test MAE:0.220741     Time:10.210110 s
# Epoch 13
# Train MAE:0.224641    Val MAE:0.260478    Test MAE:0.258249     Time:9.912941 s
# Epoch 14
# Train MAE:0.221680    Val MAE:0.218712    Test MAE:0.218697     Time:9.644587 s
# Epoch 15
# Train MAE:0.215289    Val MAE:0.207180    Test MAE:0.206396     Time:9.722677 s
# Epoch 16
# Train MAE:0.208228    Val MAE:0.198060    Test MAE:0.196295     Time:9.993183 s
# Epoch 17
# Train MAE:0.202097    Val MAE:0.193736    Test MAE:0.192559     Time:10.933366 s
# Epoch 18
# Train MAE:0.195254    Val MAE:0.189115    Test MAE:0.188717     Time:10.896396 s
# Epoch 19
# Train MAE:0.194022    Val MAE:0.194457    Test MAE:0.194773     Time:9.881160 s
# Epoch 20
# Train MAE:0.189380    Val MAE:0.185416    Test MAE:0.184673     Time:11.142137 s
# Epoch 21
# Train MAE:0.188015    Val MAE:0.179988    Test MAE:0.180086     Time:10.243649 s
# Epoch 22
# Train MAE:0.183928    Val MAE:0.181904    Test MAE:0.182090     Time:10.466909 s
# Epoch 23
# Train MAE:0.183180    Val MAE:0.177084    Test MAE:0.177275     Time:10.847435 s
# Epoch 24
# Train MAE:0.179342    Val MAE:0.173611    Test MAE:0.173561     Time:10.678876 s
# Epoch 25
# Train MAE:0.179214    Val MAE:0.198782    Test MAE:0.198297     Time:11.307647 s
# Epoch 26
# Train MAE:0.176961    Val MAE:0.173650    Test MAE:0.172597     Time:11.126306 s
# Epoch 27
# Train MAE:0.175059    Val MAE:0.171414    Test MAE:0.169874     Time:10.153830 s
# Epoch 28
# Train MAE:0.174620    Val MAE:0.168828    Test MAE:0.169406     Time:10.021565 s
# Epoch 29
# Train MAE:0.172075    Val MAE:0.188695    Test MAE:0.188711     Time:9.944641 s
# Epoch 30
# Train MAE:0.170606    Val MAE:0.165947    Test MAE:0.165282     Time:9.756028 s
# Epoch 31
# Train MAE:0.167043    Val MAE:0.162648    Test MAE:0.162565     Time:10.164348 s
# Epoch 32
# Train MAE:0.166425    Val MAE:0.167829    Test MAE:0.168055     Time:9.500888 s
# Epoch 33
# Train MAE:0.163412    Val MAE:0.157719    Test MAE:0.157546     Time:9.945284 s
# Epoch 34
# Train MAE:0.161397    Val MAE:0.157986    Test MAE:0.157935     Time:9.645993 s
# Epoch 35
# Train MAE:0.160954    Val MAE:0.161652    Test MAE:0.160994     Time:9.401869 s
# Epoch 36
# Train MAE:0.158832    Val MAE:0.155509    Test MAE:0.154502     Time:9.885450 s
# Epoch 37
# Train MAE:0.158433    Val MAE:0.187095    Test MAE:0.187575     Time:9.713622 s
# Epoch 38
# Train MAE:0.156514    Val MAE:0.154072    Test MAE:0.152567     Time:10.116004 s
# Epoch 39
# Train MAE:0.154530    Val MAE:0.152542    Test MAE:0.151966     Time:10.469918 s
# Epoch 40
# Train MAE:0.154185    Val MAE:0.153893    Test MAE:0.153979     Time:10.597356 s
# Epoch 41
# Train MAE:0.151043    Val MAE:0.179084    Test MAE:0.177374     Time:10.314351 s
# Epoch 42
# Train MAE:0.149406    Val MAE:0.147744    Test MAE:0.147585     Time:10.705255 s
# Epoch 43
# Train MAE:0.149166    Val MAE:0.151641    Test MAE:0.150167     Time:10.166840 s
# Epoch 44
# Train MAE:0.149033    Val MAE:0.149805    Test MAE:0.149599     Time:9.937426 s
# Epoch 45
# Train MAE:0.146692    Val MAE:0.140198    Test MAE:0.138942     Time:10.039092 s
# Epoch 46
# Train MAE:0.145915    Val MAE:0.144480    Test MAE:0.144310     Time:9.898331 s
# Epoch 47
# Train MAE:0.144699    Val MAE:0.149080    Test MAE:0.146922     Time:9.598549 s
# Epoch 48
# Train MAE:0.143438    Val MAE:0.136996    Test MAE:0.135038     Time:10.007458 s
# Epoch 49
# Train MAE:0.144743    Val MAE:0.137077    Test MAE:0.135885     Time:9.574196 s
# Epoch 50
# Train MAE:0.141134    Val MAE:0.150091    Test MAE:0.148633     Time:10.039348 s

# %%
epochs=50
optimizer=torch.optim.Adam(params=gcn.parameters(), lr=0.0005)
train_loader = DataLoader(OPV_train, batch_size=32, shuffle=True)
for i in range(1,epochs+1):
    t_start=time.time()
    gcn,train_mae = train(gcn, train_loader, optimizer, loss_fn)
    val_mae=test(gcn,val_loader)
    test_mae=test(gcn,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.145122    Val MAE:0.147335    Test MAE:0.144656     Time:23.001515 s
# Epoch 2
# Train MAE:0.144472    Val MAE:0.148645    Test MAE:0.146776     Time:23.252312 s
# Epoch 3
# Train MAE:0.142782    Val MAE:0.137422    Test MAE:0.136556     Time:22.754387 s
# Epoch 4
# Train MAE:0.141963    Val MAE:0.137663    Test MAE:0.137343     Time:21.949644 s
# Epoch 5
# Train MAE:0.140854    Val MAE:0.145935    Test MAE:0.143070     Time:22.525177 s
# Epoch 6
# Train MAE:0.140157    Val MAE:0.138851    Test MAE:0.138248     Time:22.885174 s
# Epoch 7
# Train MAE:0.138364    Val MAE:0.137161    Test MAE:0.136511     Time:22.767437 s
# Epoch 8
# Train MAE:0.138178    Val MAE:0.138947    Test MAE:0.139461     Time:21.673560 s
# Epoch 9
# Train MAE:0.136628    Val MAE:0.130228    Test MAE:0.129016     Time:21.612436 s
# Epoch 10
# Train MAE:0.136296    Val MAE:0.133520    Test MAE:0.133687     Time:21.684922 s
# Epoch 11
# Train MAE:0.133859    Val MAE:0.133568    Test MAE:0.132339     Time:21.665143 s
# Epoch 12
# Train MAE:0.133450    Val MAE:0.128048    Test MAE:0.127428     Time:22.561591 s
# Epoch 13
# Train MAE:0.132584    Val MAE:0.155433    Test MAE:0.153580     Time:23.203383 s
# Epoch 14
# Train MAE:0.131853    Val MAE:0.128206    Test MAE:0.127025     Time:22.549156 s
# Epoch 15
# Train MAE:0.130983    Val MAE:0.123765    Test MAE:0.122997     Time:26.511526 s
# Epoch 16
# Train MAE:0.129375    Val MAE:0.133742    Test MAE:0.132381     Time:25.536509 s
# Epoch 17
# Train MAE:0.128156    Val MAE:0.132480    Test MAE:0.131497     Time:23.837353 s
# Epoch 18
# Train MAE:0.128029    Val MAE:0.127960    Test MAE:0.128213     Time:23.960519 s
# Epoch 19
# Train MAE:0.126954    Val MAE:0.121999    Test MAE:0.122600     Time:24.800432 s
# Epoch 20
# Train MAE:0.126142    Val MAE:0.120328    Test MAE:0.120843     Time:23.770715 s
# Epoch 21
# Train MAE:0.125397    Val MAE:0.119578    Test MAE:0.119655     Time:23.412467 s
# Epoch 22
# Train MAE:0.124116    Val MAE:0.120318    Test MAE:0.120232     Time:23.284096 s
# Epoch 23
# Train MAE:0.123015    Val MAE:0.115589    Test MAE:0.115985     Time:22.707472 s
# Epoch 24
# Train MAE:0.122740    Val MAE:0.126726    Test MAE:0.126703     Time:22.334859 s
# Epoch 25
# Train MAE:0.121386    Val MAE:0.124945    Test MAE:0.125742     Time:22.089977 s
# Epoch 26
# Train MAE:0.120533    Val MAE:0.115849    Test MAE:0.116113     Time:22.263192 s
# Epoch 27
# Train MAE:0.119559    Val MAE:0.116412    Test MAE:0.116407     Time:21.808671 s
# Epoch 28
# Train MAE:0.119600    Val MAE:0.118338    Test MAE:0.119769     Time:21.588919 s
# Epoch 29
# Train MAE:0.118419    Val MAE:0.115690    Test MAE:0.115434     Time:21.799182 s
# Epoch 30
# Train MAE:0.118042    Val MAE:0.111844    Test MAE:0.111829     Time:21.698118 s
# Epoch 31
# Train MAE:0.117498    Val MAE:0.114186    Test MAE:0.113668     Time:21.540672 s
# Epoch 32
# Train MAE:0.116012    Val MAE:0.120868    Test MAE:0.120474     Time:21.647513 s
# Epoch 33
# Train MAE:0.115755    Val MAE:0.120349    Test MAE:0.120572     Time:21.760748 s
# Epoch 34
# Train MAE:0.115314    Val MAE:0.115236    Test MAE:0.115011     Time:21.916006 s
# Epoch 35
# Train MAE:0.113745    Val MAE:0.110764    Test MAE:0.109791     Time:22.184957 s
# Epoch 36
# Train MAE:0.113448    Val MAE:0.121749    Test MAE:0.121107     Time:24.725588 s
# Epoch 37
# Train MAE:0.113415    Val MAE:0.108565    Test MAE:0.108150     Time:21.886488 s
# Epoch 38
# Train MAE:0.113254    Val MAE:0.110322    Test MAE:0.109954     Time:22.733619 s
# Epoch 39
# Train MAE:0.111155    Val MAE:0.129008    Test MAE:0.129037     Time:22.052954 s
# Epoch 40
# Train MAE:0.111122    Val MAE:0.106579    Test MAE:0.105523     Time:21.865728 s
# Epoch 41
# Train MAE:0.110247    Val MAE:0.111252    Test MAE:0.109575     Time:22.431390 s
# Epoch 42
# Train MAE:0.109230    Val MAE:0.111772    Test MAE:0.111251     Time:21.715931 s
# Epoch 43
# Train MAE:0.109139    Val MAE:0.106726    Test MAE:0.106792     Time:21.777432 s
# Epoch 44
# Train MAE:0.108420    Val MAE:0.107028    Test MAE:0.106454     Time:22.156107 s
# Epoch 45
# Train MAE:0.107382    Val MAE:0.109169    Test MAE:0.108602     Time:22.122934 s
# Epoch 46
# Train MAE:0.107521    Val MAE:0.113055    Test MAE:0.113217     Time:21.954046 s
# Epoch 47
# Train MAE:0.106021    Val MAE:0.103139    Test MAE:0.102874     Time:22.514143 s
# Epoch 48
# Train MAE:0.105539    Val MAE:0.105838    Test MAE:0.106122     Time:22.422622 s
# Epoch 49
# Train MAE:0.105348    Val MAE:0.101059    Test MAE:0.100606     Time:21.732634 s
# Epoch 50
# Train MAE:0.104224    Val MAE:0.104310    Test MAE:0.103792     Time:21.843811 s

# %%
with open("./result/add_OPV_3.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))
