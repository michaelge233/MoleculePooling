# %%
from torch_geometric.utils import to_networkx
import networkx as nx
import torch

def find_all_rings(graph_data):

    nx_graph = to_networkx(graph_data, to_undirected=True)
    cycles = list(nx.simple_cycles(nx_graph))

    return cycles

def have_edge(adj, node1, node2):

    return adj[node1, node2] == 1 or adj[node2, node1] == 1


def get_S(data):
    S=torch.zeros(max_nodes,max_nodes)
    adj=torch.zeros((data.num_nodes, data.num_nodes))
    adj[data.edge_index[0], data.edge_index[1]] = 1
    rings=find_all_rings(data)
    
    if len(rings)==0:
        return torch.eye(max_nodes)
    i=0
    for ring in rings:
        if i>=max_nodes:
            return torch.eye(max_nodes)
        if len(ring)<9:
            for j in ring:
                S[j][i]=1.0
            i+=1
            
    for j in range(data.x.shape[0]):
        if i>=max_nodes:
            return torch.eye(max_nodes)
        if S[j,:].max()==0:
            S[j,i]=1.0
            for k in range(j+1,data.num_nodes):
                if S[k,:].max()==0 and have_edge(adj, j, k):
                    S[k,i]=1.0
            i+=1
            
    return S



import random
import pandas as pd
import numpy as np
from tqdm import tqdm
from torch_geometric.utils import from_smiles

def split_list(input_list, ratio):
    input_list_copy = input_list.copy()
    total_length = len(input_list_copy)
    a_length = int(ratio[0] * total_length)
    b_length = int(ratio[1] * total_length)
    
    random.shuffle(input_list_copy)
    part_a = input_list_copy[:a_length]
    part_b = input_list_copy[a_length:a_length + b_length]
    part_c = input_list_copy[a_length + b_length:]

    return part_a, part_b, part_c

def load_dataset(filename,x_name,y_name1,y_name2):
    table=pd.read_csv(filename)
    result=[]
    for i in tqdm(range(table.shape[0])):
        cur_data=from_smiles(table[x_name][i])
        cur_data.y=torch.tensor([[table[y_name1][i],table[y_name2][i]]],dtype=torch.float32)
        cur_data.S=get_S(cur_data)
        result.append(cur_data)
    return result

def load_splited_dataset(filename,x_name,y_name1,y_name2,ratio=(0.8,0.1,0.1)):
    all_list=load_dataset(filename,x_name,y_name1,y_name1)
    return split_list(all_list,ratio)

# %%
import torch
from torch.nn import Linear, ReLU
from torch_geometric.nn import DenseGCNConv, global_mean_pool,dense_diff_pool

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels,normalize=False,lin=True):
        super(GNN, self).__init__()
        
        self.convs = torch.nn.ModuleList()
        self.convs.append(DenseGCNConv(in_channels, hidden_channels,normalize))
        self.convs.append(DenseGCNConv(hidden_channels, out_channels,normalize))
        self.act=ReLU()

    def forward(self, x, adj, mask=None):
        
        for step in range(len(self.convs)):
            x = self.act(self.convs[step](x, adj))
        
        return x
class RingPool(torch.nn.Module):
    def __init__(self,in_channels, hidden_channels=32, out_channels=2):
        super(RingPool, self).__init__()
        self.gnn1=GNN(in_channels, hidden_channels, hidden_channels)
        self.gnn2=GNN(hidden_channels, hidden_channels, hidden_channels)
        self.lin1 = torch.nn.Linear(hidden_channels, hidden_channels)
        self.lin2 = torch.nn.Linear(hidden_channels, out_channels)
        self.act=ReLU()
        
    def forward(self, x, adj, s, mask=None):
        x = self.gnn1(x,adj, mask)
        x, adj, l1, e1 = dense_diff_pool(x, adj, s, mask)
        x = self.gnn2(x,adj, mask)
        
        x = x.sum(dim=1)
        x = self.act(self.lin1(x))
        x = self.lin2(x)
        return x

# %%
from torch_geometric.utils import to_dense_batch,to_dense_adj

def train(model, loader, optimizer, loss_func):

    model.train()
    mae=0
    for data in loader:
        data.x=to_dense_batch(data.x,batch=data.batch,max_num_nodes=max_nodes)[0].float()
        data.adj=to_dense_adj(data.edge_index,batch=data.batch,max_num_nodes=max_nodes)
        data.S=data.S.reshape(-1,max_nodes,max_nodes)
        data=data.cuda()
        optimizer.zero_grad()
        pred=model(data.x, data.adj,data.S)
        mae+=torch.sum(torch.abs(pred-data.y)).item()/2
        loss=loss_func(pred,data.y)
        loss.backward()
        optimizer.step()

    return model,mae/len(loader.dataset)

def test(model, loader):
    model.eval()
    mae=0
    with torch.no_grad():
        for data in loader:
            data.x=to_dense_batch(data.x,batch=data.batch,max_num_nodes=max_nodes)[0].float()
            data.adj=to_dense_adj(data.edge_index,batch=data.batch,max_num_nodes=max_nodes)
            data.S=data.S.reshape(-1,max_nodes,max_nodes)
            data=data.cuda()
            out = model(data.x,data.adj,data.S)  
            mae+=torch.sum(torch.abs(out-data.y)).item()/2
        
    return mae / len(loader.dataset)

# %% [markdown]
# # QM9

# %%
from torch_geometric.seed import seed_everything

max_nodes=9
QM9=load_dataset("./dataset/QM9/QM9.csv","smiles","homo","lumo")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 133247/133247 [03:14<00:00, 685.08it/s]

# %% [markdown]
# ### Exp 1

# %%
seed_everything(1222)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader


train_loader=DataLoader(QM9_train,batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

ringpool=RingPool(num_features)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.001)
loss_fn=MSELoss()

ringpool=ringpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.022676    Val MAE:0.012551    Test MAE:0.012404     Time:12.421992 s
# Epoch 2
# Train MAE:0.012059    Val MAE:0.012096    Test MAE:0.012003     Time:12.429872 s
# Epoch 3
# Train MAE:0.011581    Val MAE:0.011118    Test MAE:0.010988     Time:12.592970 s
# Epoch 4
# Train MAE:0.011243    Val MAE:0.010850    Test MAE:0.010730     Time:13.256961 s
# Epoch 5
# Train MAE:0.011182    Val MAE:0.010636    Test MAE:0.010501     Time:12.790881 s
# Epoch 6
# Train MAE:0.011000    Val MAE:0.010561    Test MAE:0.010454     Time:12.809435 s
# Epoch 7
# Train MAE:0.010993    Val MAE:0.010177    Test MAE:0.010071     Time:12.725467 s
# Epoch 8
# Train MAE:0.010686    Val MAE:0.010365    Test MAE:0.010202     Time:12.728839 s
# Epoch 9
# Train MAE:0.010590    Val MAE:0.010144    Test MAE:0.010072     Time:13.023960 s
# Epoch 10
# Train MAE:0.010398    Val MAE:0.010151    Test MAE:0.010084     Time:13.019576 s
# Epoch 11
# Train MAE:0.010225    Val MAE:0.010221    Test MAE:0.010119     Time:12.918438 s
# Epoch 12
# Train MAE:0.010033    Val MAE:0.010074    Test MAE:0.010044     Time:12.995718 s
# Epoch 13
# Train MAE:0.009981    Val MAE:0.009339    Test MAE:0.009285     Time:13.323680 s
# Epoch 14
# Train MAE:0.009765    Val MAE:0.009929    Test MAE:0.009824     Time:13.012016 s
# Epoch 15
# Train MAE:0.009748    Val MAE:0.009329    Test MAE:0.009267     Time:13.326141 s
# Epoch 16
# Train MAE:0.009595    Val MAE:0.009019    Test MAE:0.008915     Time:13.998557 s
# Epoch 17
# Train MAE:0.009502    Val MAE:0.009270    Test MAE:0.009226     Time:14.131844 s
# Epoch 18
# Train MAE:0.009380    Val MAE:0.010016    Test MAE:0.009888     Time:13.606146 s
# Epoch 19
# Train MAE:0.009326    Val MAE:0.010142    Test MAE:0.010215     Time:13.563703 s
# Epoch 20
# Train MAE:0.009364    Val MAE:0.008827    Test MAE:0.008762     Time:12.858767 s
# Epoch 21
# Train MAE:0.009065    Val MAE:0.009070    Test MAE:0.008938     Time:13.073388 s
# Epoch 22
# Train MAE:0.009099    Val MAE:0.008653    Test MAE:0.008569     Time:13.574067 s
# Epoch 23
# Train MAE:0.008952    Val MAE:0.008698    Test MAE:0.008643     Time:13.217063 s
# Epoch 24
# Train MAE:0.008870    Val MAE:0.008713    Test MAE:0.008646     Time:13.061631 s
# Epoch 25
# Train MAE:0.008854    Val MAE:0.008499    Test MAE:0.008429     Time:13.010873 s
# Epoch 26
# Train MAE:0.008821    Val MAE:0.008401    Test MAE:0.008355     Time:13.497530 s
# Epoch 27
# Train MAE:0.008700    Val MAE:0.008641    Test MAE:0.008589     Time:14.869205 s
# Epoch 28
# Train MAE:0.008618    Val MAE:0.008429    Test MAE:0.008370     Time:14.392736 s
# Epoch 29
# Train MAE:0.008705    Val MAE:0.008575    Test MAE:0.008529     Time:13.388508 s
# Epoch 30
# Train MAE:0.008612    Val MAE:0.008958    Test MAE:0.008935     Time:13.006090 s
# Epoch 31
# Train MAE:0.008548    Val MAE:0.008610    Test MAE:0.008567     Time:13.149149 s
# Epoch 32
# Train MAE:0.008508    Val MAE:0.008244    Test MAE:0.008168     Time:13.586831 s
# Epoch 33
# Train MAE:0.008444    Val MAE:0.008587    Test MAE:0.008565     Time:13.501615 s
# Epoch 34
# Train MAE:0.008475    Val MAE:0.008523    Test MAE:0.008487     Time:14.750028 s
# Epoch 35
# Train MAE:0.008402    Val MAE:0.008886    Test MAE:0.008810     Time:13.768291 s
# Epoch 36
# Train MAE:0.008392    Val MAE:0.008331    Test MAE:0.008311     Time:13.473683 s
# Epoch 37
# Train MAE:0.008387    Val MAE:0.008405    Test MAE:0.008394     Time:13.421581 s
# Epoch 38
# Train MAE:0.008305    Val MAE:0.008004    Test MAE:0.007942     Time:14.015781 s
# Epoch 39
# Train MAE:0.008276    Val MAE:0.008066    Test MAE:0.008054     Time:13.876574 s
# Epoch 40
# Train MAE:0.008254    Val MAE:0.009192    Test MAE:0.009186     Time:14.429273 s
# Epoch 41
# Train MAE:0.008225    Val MAE:0.008114    Test MAE:0.008120     Time:14.424028 s
# Epoch 42
# Train MAE:0.008136    Val MAE:0.007907    Test MAE:0.007855     Time:14.542198 s
# Epoch 43
# Train MAE:0.008184    Val MAE:0.007795    Test MAE:0.007729     Time:13.734981 s
# Epoch 44
# Train MAE:0.008159    Val MAE:0.008127    Test MAE:0.008071     Time:13.660470 s
# Epoch 45
# Train MAE:0.008110    Val MAE:0.008006    Test MAE:0.007963     Time:14.306529 s
# Epoch 46
# Train MAE:0.008097    Val MAE:0.007883    Test MAE:0.007794     Time:13.720880 s
# Epoch 47
# Train MAE:0.008020    Val MAE:0.008038    Test MAE:0.007987     Time:13.957172 s
# Epoch 48
# Train MAE:0.008069    Val MAE:0.007777    Test MAE:0.007747     Time:13.342494 s
# Epoch 49
# Train MAE:0.007957    Val MAE:0.008198    Test MAE:0.008151     Time:13.212290 s
# Epoch 50
# Train MAE:0.008015    Val MAE:0.008008    Test MAE:0.008011     Time:13.197668 s

# %%
epochs=50
train_loader=DataLoader(QM9_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.0005)
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.008017    Val MAE:0.008570    Test MAE:0.008549     Time:27.972265 s
# Epoch 2
# Train MAE:0.008023    Val MAE:0.008130    Test MAE:0.008107     Time:28.856439 s
# Epoch 3
# Train MAE:0.008003    Val MAE:0.009079    Test MAE:0.009033     Time:28.098326 s
# Epoch 4
# Train MAE:0.007949    Val MAE:0.007875    Test MAE:0.007828     Time:27.655796 s
# Epoch 5
# Train MAE:0.007917    Val MAE:0.007817    Test MAE:0.007761     Time:27.259597 s
# Epoch 6
# Train MAE:0.007898    Val MAE:0.008894    Test MAE:0.008882     Time:28.234588 s
# Epoch 7
# Train MAE:0.007906    Val MAE:0.008173    Test MAE:0.008117     Time:28.222977 s
# Epoch 8
# Train MAE:0.007894    Val MAE:0.007999    Test MAE:0.007976     Time:28.026615 s
# Epoch 9
# Train MAE:0.007861    Val MAE:0.007865    Test MAE:0.007767     Time:27.388793 s
# Epoch 10
# Train MAE:0.007828    Val MAE:0.007617    Test MAE:0.007574     Time:30.295032 s
# Epoch 11
# Train MAE:0.007796    Val MAE:0.007563    Test MAE:0.007480     Time:28.219040 s
# Epoch 12
# Train MAE:0.007799    Val MAE:0.007839    Test MAE:0.007800     Time:28.671160 s
# Epoch 13
# Train MAE:0.007775    Val MAE:0.007842    Test MAE:0.007811     Time:27.212632 s
# Epoch 14
# Train MAE:0.007720    Val MAE:0.007892    Test MAE:0.007849     Time:26.834368 s
# Epoch 15
# Train MAE:0.007700    Val MAE:0.007466    Test MAE:0.007388     Time:26.852305 s
# Epoch 16
# Train MAE:0.007697    Val MAE:0.008417    Test MAE:0.008286     Time:26.772565 s
# Epoch 17
# Train MAE:0.007728    Val MAE:0.008547    Test MAE:0.008463     Time:26.564568 s
# Epoch 18
# Train MAE:0.007651    Val MAE:0.007575    Test MAE:0.007537     Time:26.748039 s
# Epoch 19
# Train MAE:0.007653    Val MAE:0.007702    Test MAE:0.007652     Time:26.876602 s
# Epoch 20
# Train MAE:0.007650    Val MAE:0.007560    Test MAE:0.007483     Time:28.830738 s
# Epoch 21
# Train MAE:0.007627    Val MAE:0.007423    Test MAE:0.007403     Time:28.031001 s
# Epoch 22
# Train MAE:0.007607    Val MAE:0.007934    Test MAE:0.007945     Time:28.060944 s
# Epoch 23
# Train MAE:0.007576    Val MAE:0.007482    Test MAE:0.007409     Time:28.114848 s
# Epoch 24
# Train MAE:0.007533    Val MAE:0.007367    Test MAE:0.007298     Time:28.535978 s
# Epoch 25
# Train MAE:0.007563    Val MAE:0.008000    Test MAE:0.007919     Time:29.143369 s
# Epoch 26
# Train MAE:0.007568    Val MAE:0.007329    Test MAE:0.007268     Time:28.439033 s
# Epoch 27
# Train MAE:0.007509    Val MAE:0.007857    Test MAE:0.007882     Time:29.020165 s
# Epoch 28
# Train MAE:0.007492    Val MAE:0.007377    Test MAE:0.007330     Time:28.423873 s
# Epoch 29
# Train MAE:0.007510    Val MAE:0.007283    Test MAE:0.007217     Time:28.487404 s
# Epoch 30
# Train MAE:0.007470    Val MAE:0.007447    Test MAE:0.007395     Time:28.315814 s
# Epoch 31
# Train MAE:0.007491    Val MAE:0.007266    Test MAE:0.007243     Time:28.087246 s
# Epoch 32
# Train MAE:0.007472    Val MAE:0.007113    Test MAE:0.007074     Time:28.502034 s
# Epoch 33
# Train MAE:0.007464    Val MAE:0.007777    Test MAE:0.007726     Time:27.663282 s
# Epoch 34
# Train MAE:0.007468    Val MAE:0.007324    Test MAE:0.007276     Time:26.870122 s
# Epoch 35
# Train MAE:0.007435    Val MAE:0.007168    Test MAE:0.007140     Time:26.635068 s
# Epoch 36
# Train MAE:0.007413    Val MAE:0.007259    Test MAE:0.007236     Time:26.576827 s
# Epoch 37
# Train MAE:0.007407    Val MAE:0.007640    Test MAE:0.007627     Time:26.744850 s
# Epoch 38
# Train MAE:0.007438    Val MAE:0.007312    Test MAE:0.007230     Time:26.700693 s
# Epoch 39
# Train MAE:0.007381    Val MAE:0.007691    Test MAE:0.007713     Time:27.725508 s
# Epoch 40
# Train MAE:0.007365    Val MAE:0.007451    Test MAE:0.007430     Time:27.893792 s
# Epoch 41
# Train MAE:0.007344    Val MAE:0.007735    Test MAE:0.007750     Time:26.990535 s
# Epoch 42
# Train MAE:0.007360    Val MAE:0.007168    Test MAE:0.007119     Time:28.420844 s
# Epoch 43
# Train MAE:0.007348    Val MAE:0.007298    Test MAE:0.007216     Time:28.132594 s
# Epoch 44
# Train MAE:0.007324    Val MAE:0.007765    Test MAE:0.007754     Time:28.021103 s
# Epoch 45
# Train MAE:0.007304    Val MAE:0.007524    Test MAE:0.007527     Time:27.767271 s
# Epoch 46
# Train MAE:0.007313    Val MAE:0.007092    Test MAE:0.007066     Time:27.869125 s
# Epoch 47
# Train MAE:0.007285    Val MAE:0.007179    Test MAE:0.007146     Time:27.991798 s
# Epoch 48
# Train MAE:0.007304    Val MAE:0.007289    Test MAE:0.007296     Time:27.676674 s
# Epoch 49
# Train MAE:0.007258    Val MAE:0.007038    Test MAE:0.006982     Time:29.297317 s
# Epoch 50
# Train MAE:0.007259    Val MAE:0.006989    Test MAE:0.006970     Time:27.274523 s

# %%
epochs=20
train_loader=DataLoader(QM9_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.0005)
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.007259    Val MAE:0.007466    Test MAE:0.007490     Time:26.958994 s
# Epoch 2
# Train MAE:0.007228    Val MAE:0.007197    Test MAE:0.007150     Time:27.044929 s
# Epoch 3
# Train MAE:0.007234    Val MAE:0.007454    Test MAE:0.007410     Time:26.726254 s
# Epoch 4
# Train MAE:0.007242    Val MAE:0.007807    Test MAE:0.007845     Time:27.328829 s
# Epoch 5
# Train MAE:0.007211    Val MAE:0.007324    Test MAE:0.007267     Time:26.963239 s
# Epoch 6
# Train MAE:0.007199    Val MAE:0.007242    Test MAE:0.007220     Time:27.286200 s
# Epoch 7
# Train MAE:0.007210    Val MAE:0.007119    Test MAE:0.007072     Time:28.592698 s
# Epoch 8
# Train MAE:0.007183    Val MAE:0.007348    Test MAE:0.007294     Time:28.891621 s
# Epoch 9
# Train MAE:0.007168    Val MAE:0.007254    Test MAE:0.007286     Time:27.838886 s
# Epoch 10
# Train MAE:0.007189    Val MAE:0.007210    Test MAE:0.007203     Time:27.130000 s
# Epoch 11
# Train MAE:0.007159    Val MAE:0.007093    Test MAE:0.007049     Time:27.515774 s
# Epoch 12
# Train MAE:0.007153    Val MAE:0.006966    Test MAE:0.006931     Time:27.395897 s
# Epoch 13
# Train MAE:0.007137    Val MAE:0.006940    Test MAE:0.006916     Time:27.075806 s
# Epoch 14
# Train MAE:0.007137    Val MAE:0.007033    Test MAE:0.007033     Time:26.882118 s
# Epoch 15
# Train MAE:0.007157    Val MAE:0.007155    Test MAE:0.007114     Time:28.126945 s
# Epoch 16
# Train MAE:0.007122    Val MAE:0.007309    Test MAE:0.007332     Time:27.589824 s
# Epoch 17
# Train MAE:0.007108    Val MAE:0.006844    Test MAE:0.006825     Time:28.517477 s
# Epoch 18
# Train MAE:0.007107    Val MAE:0.007060    Test MAE:0.007035     Time:27.701987 s
# Epoch 19
# Train MAE:0.007100    Val MAE:0.007109    Test MAE:0.007099     Time:27.279528 s
# Epoch 20
# Train MAE:0.007075    Val MAE:0.006827    Test MAE:0.006817     Time:27.141953 s

# %%
with open("./result/RING_QM9_1.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 2

# %%
seed_everything(324)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader


train_loader=DataLoader(QM9_train,batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

ringpool=RingPool(num_features)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.001)
loss_fn=MSELoss()

ringpool=ringpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.023151    Val MAE:0.017532    Test MAE:0.017392     Time:11.224392 s
# Epoch 2
# Train MAE:0.016792    Val MAE:0.015906    Test MAE:0.015761     Time:11.818900 s
# Epoch 3
# Train MAE:0.015789    Val MAE:0.015868    Test MAE:0.015757     Time:12.189643 s
# Epoch 4
# Train MAE:0.014977    Val MAE:0.015604    Test MAE:0.015476     Time:12.216589 s
# Epoch 5
# Train MAE:0.014475    Val MAE:0.014381    Test MAE:0.014230     Time:12.402188 s
# Epoch 6
# Train MAE:0.013925    Val MAE:0.013114    Test MAE:0.012970     Time:12.417152 s
# Epoch 7
# Train MAE:0.013589    Val MAE:0.013180    Test MAE:0.013082     Time:12.507293 s
# Epoch 8
# Train MAE:0.013405    Val MAE:0.012466    Test MAE:0.012282     Time:12.391737 s
# Epoch 9
# Train MAE:0.013052    Val MAE:0.014259    Test MAE:0.014068     Time:12.521020 s
# Epoch 10
# Train MAE:0.013084    Val MAE:0.012509    Test MAE:0.012351     Time:12.574980 s
# Epoch 11
# Train MAE:0.012587    Val MAE:0.011902    Test MAE:0.011653     Time:12.750822 s
# Epoch 12
# Train MAE:0.012154    Val MAE:0.011788    Test MAE:0.011591     Time:12.793988 s
# Epoch 13
# Train MAE:0.012106    Val MAE:0.011641    Test MAE:0.011377     Time:12.730229 s
# Epoch 14
# Train MAE:0.011913    Val MAE:0.011662    Test MAE:0.011454     Time:12.718055 s
# Epoch 15
# Train MAE:0.011598    Val MAE:0.012748    Test MAE:0.012581     Time:12.921875 s
# Epoch 16
# Train MAE:0.011673    Val MAE:0.012283    Test MAE:0.012252     Time:12.872091 s
# Epoch 17
# Train MAE:0.011514    Val MAE:0.012479    Test MAE:0.012330     Time:12.828625 s
# Epoch 18
# Train MAE:0.011173    Val MAE:0.011452    Test MAE:0.011403     Time:12.849093 s
# Epoch 19
# Train MAE:0.011402    Val MAE:0.011179    Test MAE:0.011036     Time:12.861372 s
# Epoch 20
# Train MAE:0.011259    Val MAE:0.010760    Test MAE:0.010701     Time:12.791726 s
# Epoch 21
# Train MAE:0.011077    Val MAE:0.010667    Test MAE:0.010524     Time:12.764834 s
# Epoch 22
# Train MAE:0.010977    Val MAE:0.011235    Test MAE:0.011099     Time:12.768749 s
# Epoch 23
# Train MAE:0.010703    Val MAE:0.010383    Test MAE:0.010332     Time:12.826503 s
# Epoch 24
# Train MAE:0.010649    Val MAE:0.009965    Test MAE:0.009907     Time:14.337232 s
# Epoch 25
# Train MAE:0.010626    Val MAE:0.010271    Test MAE:0.010183     Time:15.247901 s
# Epoch 26
# Train MAE:0.010390    Val MAE:0.010718    Test MAE:0.010552     Time:14.759201 s
# Epoch 27
# Train MAE:0.010300    Val MAE:0.009674    Test MAE:0.009579     Time:14.744052 s
# Epoch 28
# Train MAE:0.010316    Val MAE:0.009800    Test MAE:0.009751     Time:13.783696 s
# Epoch 29
# Train MAE:0.010177    Val MAE:0.010183    Test MAE:0.010095     Time:14.272732 s
# Epoch 30
# Train MAE:0.010091    Val MAE:0.010077    Test MAE:0.009913     Time:14.468056 s
# Epoch 31
# Train MAE:0.010101    Val MAE:0.010114    Test MAE:0.010034     Time:13.954646 s
# Epoch 32
# Train MAE:0.010065    Val MAE:0.010248    Test MAE:0.010089     Time:12.999273 s
# Epoch 33
# Train MAE:0.009983    Val MAE:0.011406    Test MAE:0.011361     Time:12.859396 s
# Epoch 34
# Train MAE:0.009860    Val MAE:0.009756    Test MAE:0.009661     Time:13.064677 s
# Epoch 35
# Train MAE:0.009873    Val MAE:0.009454    Test MAE:0.009338     Time:13.148380 s
# Epoch 36
# Train MAE:0.009824    Val MAE:0.009784    Test MAE:0.009684     Time:13.097341 s
# Epoch 37
# Train MAE:0.009792    Val MAE:0.009351    Test MAE:0.009262     Time:13.345458 s
# Epoch 38
# Train MAE:0.009721    Val MAE:0.009480    Test MAE:0.009376     Time:13.122593 s
# Epoch 39
# Train MAE:0.009671    Val MAE:0.009961    Test MAE:0.009926     Time:13.113950 s
# Epoch 40
# Train MAE:0.009575    Val MAE:0.009749    Test MAE:0.009614     Time:13.099688 s
# Epoch 41
# Train MAE:0.009595    Val MAE:0.009389    Test MAE:0.009301     Time:12.973605 s
# Epoch 42
# Train MAE:0.009450    Val MAE:0.009777    Test MAE:0.009690     Time:14.030489 s
# Epoch 43
# Train MAE:0.009524    Val MAE:0.009537    Test MAE:0.009413     Time:14.357298 s
# Epoch 44
# Train MAE:0.009473    Val MAE:0.009046    Test MAE:0.008943     Time:13.084207 s
# Epoch 45
# Train MAE:0.009473    Val MAE:0.009752    Test MAE:0.009577     Time:13.106015 s
# Epoch 46
# Train MAE:0.009390    Val MAE:0.009315    Test MAE:0.009242     Time:12.982867 s
# Epoch 47
# Train MAE:0.009325    Val MAE:0.009176    Test MAE:0.009067     Time:13.146717 s
# Epoch 48
# Train MAE:0.009303    Val MAE:0.009141    Test MAE:0.009066     Time:13.027239 s
# Epoch 49
# Train MAE:0.009353    Val MAE:0.009297    Test MAE:0.009108     Time:13.287472 s
# Epoch 50
# Train MAE:0.009291    Val MAE:0.009122    Test MAE:0.008986     Time:13.039027 s

# %%
epochs=50
train_loader=DataLoader(QM9_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.0005)
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.009409    Val MAE:0.009275    Test MAE:0.009172     Time:25.678294 s
# Epoch 2
# Train MAE:0.009380    Val MAE:0.009325    Test MAE:0.009250     Time:26.401731 s
# Epoch 3
# Train MAE:0.009386    Val MAE:0.010944    Test MAE:0.010753     Time:27.155202 s
# Epoch 4
# Train MAE:0.009274    Val MAE:0.009280    Test MAE:0.009186     Time:27.578329 s
# Epoch 5
# Train MAE:0.009273    Val MAE:0.009052    Test MAE:0.008895     Time:28.733521 s
# Epoch 6
# Train MAE:0.009282    Val MAE:0.008937    Test MAE:0.008778     Time:28.185193 s
# Epoch 7
# Train MAE:0.009228    Val MAE:0.008972    Test MAE:0.008905     Time:27.770976 s
# Epoch 8
# Train MAE:0.009174    Val MAE:0.011172    Test MAE:0.010995     Time:28.375756 s
# Epoch 9
# Train MAE:0.009121    Val MAE:0.009813    Test MAE:0.009592     Time:27.985494 s
# Epoch 10
# Train MAE:0.009074    Val MAE:0.009815    Test MAE:0.009643     Time:27.984039 s
# Epoch 11
# Train MAE:0.009067    Val MAE:0.008733    Test MAE:0.008664     Time:29.149684 s
# Epoch 12
# Train MAE:0.009066    Val MAE:0.009014    Test MAE:0.008942     Time:28.496411 s
# Epoch 13
# Train MAE:0.009014    Val MAE:0.008888    Test MAE:0.008887     Time:27.874415 s
# Epoch 14
# Train MAE:0.008985    Val MAE:0.008846    Test MAE:0.008762     Time:26.695978 s
# Epoch 15
# Train MAE:0.009020    Val MAE:0.008807    Test MAE:0.008665     Time:26.507074 s
# Epoch 16
# Train MAE:0.008892    Val MAE:0.008725    Test MAE:0.008658     Time:26.560903 s
# Epoch 17
# Train MAE:0.008961    Val MAE:0.008932    Test MAE:0.008820     Time:26.614625 s
# Epoch 18
# Train MAE:0.008855    Val MAE:0.008783    Test MAE:0.008707     Time:26.420245 s
# Epoch 19
# Train MAE:0.008874    Val MAE:0.008646    Test MAE:0.008576     Time:26.444301 s
# Epoch 20
# Train MAE:0.008820    Val MAE:0.009079    Test MAE:0.008932     Time:27.211674 s
# Epoch 21
# Train MAE:0.008838    Val MAE:0.008707    Test MAE:0.008643     Time:27.372907 s
# Epoch 22
# Train MAE:0.008856    Val MAE:0.008835    Test MAE:0.008742     Time:29.118346 s
# Epoch 23
# Train MAE:0.008772    Val MAE:0.008896    Test MAE:0.008753     Time:27.706615 s
# Epoch 24
# Train MAE:0.008768    Val MAE:0.008931    Test MAE:0.008877     Time:26.969697 s
# Epoch 25
# Train MAE:0.008771    Val MAE:0.009017    Test MAE:0.008989     Time:27.017397 s
# Epoch 26
# Train MAE:0.008763    Val MAE:0.008499    Test MAE:0.008403     Time:26.860495 s
# Epoch 27
# Train MAE:0.008737    Val MAE:0.008893    Test MAE:0.008774     Time:26.791615 s
# Epoch 28
# Train MAE:0.008702    Val MAE:0.009213    Test MAE:0.009125     Time:29.762503 s
# Epoch 29
# Train MAE:0.008711    Val MAE:0.008197    Test MAE:0.008124     Time:30.150035 s
# Epoch 30
# Train MAE:0.008687    Val MAE:0.008575    Test MAE:0.008459     Time:28.131406 s
# Epoch 31
# Train MAE:0.008642    Val MAE:0.008515    Test MAE:0.008416     Time:30.292542 s
# Epoch 32
# Train MAE:0.008631    Val MAE:0.008726    Test MAE:0.008653     Time:28.023598 s
# Epoch 33
# Train MAE:0.008603    Val MAE:0.009514    Test MAE:0.009395     Time:28.468706 s
# Epoch 34
# Train MAE:0.008548    Val MAE:0.008488    Test MAE:0.008462     Time:28.325615 s
# Epoch 35
# Train MAE:0.008604    Val MAE:0.008334    Test MAE:0.008247     Time:27.304885 s
# Epoch 36
# Train MAE:0.008523    Val MAE:0.008338    Test MAE:0.008221     Time:27.744103 s
# Epoch 37
# Train MAE:0.008580    Val MAE:0.008246    Test MAE:0.008115     Time:27.783793 s
# Epoch 38
# Train MAE:0.008518    Val MAE:0.008327    Test MAE:0.008217     Time:27.875400 s
# Epoch 39
# Train MAE:0.008528    Val MAE:0.008346    Test MAE:0.008296     Time:27.636617 s
# Epoch 40
# Train MAE:0.008518    Val MAE:0.008797    Test MAE:0.008701     Time:28.721883 s
# Epoch 41
# Train MAE:0.008504    Val MAE:0.008660    Test MAE:0.008508     Time:28.011571 s
# Epoch 42
# Train MAE:0.008514    Val MAE:0.008528    Test MAE:0.008432     Time:27.926906 s
# Epoch 43
# Train MAE:0.008470    Val MAE:0.008852    Test MAE:0.008692     Time:27.472209 s
# Epoch 44
# Train MAE:0.008486    Val MAE:0.008568    Test MAE:0.008483     Time:26.699184 s
# Epoch 45
# Train MAE:0.008450    Val MAE:0.009322    Test MAE:0.009301     Time:27.451358 s
# Epoch 46
# Train MAE:0.008433    Val MAE:0.008420    Test MAE:0.008294     Time:26.682422 s
# Epoch 47
# Train MAE:0.008468    Val MAE:0.008277    Test MAE:0.008178     Time:27.209854 s
# Epoch 48
# Train MAE:0.008439    Val MAE:0.008503    Test MAE:0.008395     Time:27.275722 s
# Epoch 49
# Train MAE:0.008441    Val MAE:0.008700    Test MAE:0.008632     Time:28.481477 s
# Epoch 50
# Train MAE:0.008396    Val MAE:0.008184    Test MAE:0.008108     Time:27.900363 s

# %%
with open("./result/RING_QM9_2.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 3

# %%
seed_everything(10086)
QM9_train,QM9_val,QM9_test=split_list(QM9,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader


train_loader=DataLoader(QM9_train,batch_size=128, shuffle=True)
val_loader = DataLoader(QM9_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(QM9_test, batch_size=1024, shuffle=False)
num_features=QM9_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

ringpool=RingPool(num_features)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.001)
loss_fn=MSELoss()

ringpool=ringpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.039286    Val MAE:0.019826    Test MAE:0.019966     Time:11.963722 s
# Epoch 2
# Train MAE:0.019430    Val MAE:0.019534    Test MAE:0.019609     Time:13.157035 s
# Epoch 3
# Train MAE:0.018271    Val MAE:0.017862    Test MAE:0.017881     Time:12.383650 s
# Epoch 4
# Train MAE:0.017506    Val MAE:0.017703    Test MAE:0.017744     Time:12.343323 s
# Epoch 5
# Train MAE:0.017043    Val MAE:0.018043    Test MAE:0.018088     Time:12.704738 s
# Epoch 6
# Train MAE:0.016426    Val MAE:0.015581    Test MAE:0.015679     Time:12.655563 s
# Epoch 7
# Train MAE:0.015947    Val MAE:0.015239    Test MAE:0.015315     Time:12.647420 s
# Epoch 8
# Train MAE:0.015491    Val MAE:0.014903    Test MAE:0.015022     Time:12.630172 s
# Epoch 9
# Train MAE:0.015019    Val MAE:0.015480    Test MAE:0.015506     Time:12.707192 s
# Epoch 10
# Train MAE:0.014719    Val MAE:0.013871    Test MAE:0.014002     Time:12.859712 s
# Epoch 11
# Train MAE:0.014375    Val MAE:0.013869    Test MAE:0.014009     Time:12.746305 s
# Epoch 12
# Train MAE:0.013860    Val MAE:0.013363    Test MAE:0.013518     Time:12.734797 s
# Epoch 13
# Train MAE:0.013518    Val MAE:0.012712    Test MAE:0.012831     Time:12.765862 s
# Epoch 14
# Train MAE:0.013347    Val MAE:0.012629    Test MAE:0.012715     Time:12.876035 s
# Epoch 15
# Train MAE:0.012967    Val MAE:0.012788    Test MAE:0.012959     Time:12.936722 s
# Epoch 16
# Train MAE:0.012958    Val MAE:0.012312    Test MAE:0.012385     Time:13.068340 s
# Epoch 17
# Train MAE:0.012595    Val MAE:0.012762    Test MAE:0.012891     Time:12.688663 s
# Epoch 18
# Train MAE:0.012500    Val MAE:0.012369    Test MAE:0.012520     Time:12.837291 s
# Epoch 19
# Train MAE:0.012377    Val MAE:0.012289    Test MAE:0.012437     Time:12.884075 s
# Epoch 20
# Train MAE:0.012307    Val MAE:0.011768    Test MAE:0.011886     Time:13.156852 s
# Epoch 21
# Train MAE:0.012028    Val MAE:0.012031    Test MAE:0.012247     Time:13.487270 s
# Epoch 22
# Train MAE:0.011755    Val MAE:0.012132    Test MAE:0.012311     Time:13.528529 s
# Epoch 23
# Train MAE:0.011630    Val MAE:0.011613    Test MAE:0.011691     Time:13.751456 s
# Epoch 24
# Train MAE:0.011555    Val MAE:0.011786    Test MAE:0.011961     Time:13.392853 s
# Epoch 25
# Train MAE:0.011462    Val MAE:0.010811    Test MAE:0.011018     Time:13.269496 s
# Epoch 26
# Train MAE:0.011247    Val MAE:0.010771    Test MAE:0.010882     Time:13.119705 s
# Epoch 27
# Train MAE:0.011131    Val MAE:0.010817    Test MAE:0.010960     Time:13.276783 s
# Epoch 28
# Train MAE:0.010944    Val MAE:0.010516    Test MAE:0.010630     Time:13.328202 s
# Epoch 29
# Train MAE:0.010832    Val MAE:0.010291    Test MAE:0.010443     Time:13.091048 s
# Epoch 30
# Train MAE:0.010844    Val MAE:0.010312    Test MAE:0.010431     Time:13.018056 s
# Epoch 31
# Train MAE:0.010628    Val MAE:0.010316    Test MAE:0.010371     Time:12.937385 s
# Epoch 32
# Train MAE:0.010695    Val MAE:0.010462    Test MAE:0.010488     Time:13.215357 s
# Epoch 33
# Train MAE:0.010627    Val MAE:0.010774    Test MAE:0.010823     Time:13.008147 s
# Epoch 34
# Train MAE:0.010456    Val MAE:0.010506    Test MAE:0.010651     Time:12.869240 s
# Epoch 35
# Train MAE:0.010845    Val MAE:0.011170    Test MAE:0.011213     Time:12.782367 s
# Epoch 36
# Train MAE:0.010903    Val MAE:0.010696    Test MAE:0.010830     Time:13.016889 s
# Epoch 37
# Train MAE:0.010721    Val MAE:0.011183    Test MAE:0.011326     Time:13.110071 s
# Epoch 38
# Train MAE:0.010427    Val MAE:0.009986    Test MAE:0.010019     Time:13.296474 s
# Epoch 39
# Train MAE:0.010417    Val MAE:0.010452    Test MAE:0.010449     Time:12.952997 s
# Epoch 40
# Train MAE:0.010299    Val MAE:0.010594    Test MAE:0.010608     Time:13.042662 s
# Epoch 41
# Train MAE:0.010192    Val MAE:0.010311    Test MAE:0.010340     Time:12.951950 s
# Epoch 42
# Train MAE:0.010143    Val MAE:0.010333    Test MAE:0.010403     Time:13.472427 s
# Epoch 43
# Train MAE:0.010101    Val MAE:0.009941    Test MAE:0.009970     Time:14.307721 s
# Epoch 44
# Train MAE:0.010055    Val MAE:0.011473    Test MAE:0.011545     Time:13.121536 s
# Epoch 45
# Train MAE:0.009971    Val MAE:0.010519    Test MAE:0.010545     Time:13.031162 s
# Epoch 46
# Train MAE:0.010019    Val MAE:0.009758    Test MAE:0.009778     Time:12.962454 s
# Epoch 47
# Train MAE:0.009901    Val MAE:0.009732    Test MAE:0.009845     Time:12.935344 s
# Epoch 48
# Train MAE:0.009815    Val MAE:0.009727    Test MAE:0.009832     Time:13.013844 s
# Epoch 49
# Train MAE:0.009832    Val MAE:0.009655    Test MAE:0.009760     Time:12.801002 s
# Epoch 50
# Train MAE:0.009799    Val MAE:0.009979    Test MAE:0.010140     Time:13.166726 s

# %%
epochs=50
train_loader=DataLoader(QM9_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.0005)
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.009975    Val MAE:0.010627    Test MAE:0.010705     Time:27.185938 s
# Epoch 2
# Train MAE:0.009942    Val MAE:0.010039    Test MAE:0.010110     Time:27.159919 s
# Epoch 3
# Train MAE:0.009935    Val MAE:0.010399    Test MAE:0.010438     Time:27.478165 s
# Epoch 4
# Train MAE:0.009868    Val MAE:0.010110    Test MAE:0.010159     Time:26.498406 s
# Epoch 5
# Train MAE:0.009857    Val MAE:0.009486    Test MAE:0.009543     Time:26.296062 s
# Epoch 6
# Train MAE:0.009891    Val MAE:0.009690    Test MAE:0.009739     Time:26.623340 s
# Epoch 7
# Train MAE:0.009813    Val MAE:0.009353    Test MAE:0.009425     Time:26.623347 s
# Epoch 8
# Train MAE:0.009725    Val MAE:0.009958    Test MAE:0.009969     Time:26.410673 s
# Epoch 9
# Train MAE:0.009776    Val MAE:0.009306    Test MAE:0.009412     Time:26.342700 s
# Epoch 10
# Train MAE:0.009692    Val MAE:0.010033    Test MAE:0.010125     Time:28.227495 s
# Epoch 11
# Train MAE:0.009599    Val MAE:0.009196    Test MAE:0.009248     Time:28.447750 s
# Epoch 12
# Train MAE:0.009642    Val MAE:0.009439    Test MAE:0.009455     Time:28.129373 s
# Epoch 13
# Train MAE:0.009581    Val MAE:0.009418    Test MAE:0.009473     Time:27.977628 s
# Epoch 14
# Train MAE:0.009581    Val MAE:0.009418    Test MAE:0.009453     Time:26.512565 s
# Epoch 15
# Train MAE:0.009668    Val MAE:0.009390    Test MAE:0.009507     Time:26.480608 s
# Epoch 16
# Train MAE:0.009600    Val MAE:0.009597    Test MAE:0.009667     Time:26.447310 s
# Epoch 17
# Train MAE:0.009619    Val MAE:0.009378    Test MAE:0.009451     Time:26.480118 s
# Epoch 18
# Train MAE:0.009511    Val MAE:0.009114    Test MAE:0.009176     Time:26.246942 s
# Epoch 19
# Train MAE:0.009439    Val MAE:0.010991    Test MAE:0.011007     Time:28.044310 s
# Epoch 20
# Train MAE:0.009393    Val MAE:0.009817    Test MAE:0.009965     Time:27.058752 s
# Epoch 21
# Train MAE:0.009373    Val MAE:0.009079    Test MAE:0.009111     Time:28.261027 s
# Epoch 22
# Train MAE:0.009305    Val MAE:0.008946    Test MAE:0.009000     Time:27.730897 s
# Epoch 23
# Train MAE:0.009321    Val MAE:0.009021    Test MAE:0.009123     Time:27.713959 s
# Epoch 24
# Train MAE:0.009307    Val MAE:0.009246    Test MAE:0.009331     Time:26.997718 s
# Epoch 25
# Train MAE:0.009373    Val MAE:0.009724    Test MAE:0.009768     Time:26.447333 s
# Epoch 26
# Train MAE:0.009236    Val MAE:0.009256    Test MAE:0.009256     Time:26.353102 s
# Epoch 27
# Train MAE:0.009208    Val MAE:0.009315    Test MAE:0.009456     Time:26.301623 s
# Epoch 28
# Train MAE:0.009236    Val MAE:0.009293    Test MAE:0.009380     Time:26.804708 s
# Epoch 29
# Train MAE:0.009209    Val MAE:0.008911    Test MAE:0.008974     Time:26.830615 s
# Epoch 30
# Train MAE:0.009146    Val MAE:0.008955    Test MAE:0.009096     Time:27.353819 s
# Epoch 31
# Train MAE:0.009111    Val MAE:0.008992    Test MAE:0.009032     Time:27.898492 s
# Epoch 32
# Train MAE:0.009113    Val MAE:0.010588    Test MAE:0.010615     Time:26.878375 s
# Epoch 33
# Train MAE:0.009120    Val MAE:0.011015    Test MAE:0.011206     Time:26.631262 s
# Epoch 34
# Train MAE:0.009069    Val MAE:0.009142    Test MAE:0.009183     Time:26.661534 s
# Epoch 35
# Train MAE:0.009085    Val MAE:0.009458    Test MAE:0.009456     Time:28.660840 s
# Epoch 36
# Train MAE:0.009103    Val MAE:0.008701    Test MAE:0.008756     Time:26.955381 s
# Epoch 37
# Train MAE:0.008991    Val MAE:0.009078    Test MAE:0.009116     Time:26.710271 s
# Epoch 38
# Train MAE:0.009032    Val MAE:0.009335    Test MAE:0.009369     Time:28.440652 s
# Epoch 39
# Train MAE:0.009375    Val MAE:0.008710    Test MAE:0.008785     Time:28.651643 s
# Epoch 40
# Train MAE:0.008967    Val MAE:0.009014    Test MAE:0.009185     Time:28.528507 s
# Epoch 41
# Train MAE:0.008963    Val MAE:0.008841    Test MAE:0.008928     Time:28.259968 s
# Epoch 42
# Train MAE:0.009026    Val MAE:0.009291    Test MAE:0.009433     Time:28.026419 s
# Epoch 43
# Train MAE:0.008889    Val MAE:0.009828    Test MAE:0.009835     Time:27.535800 s
# Epoch 44
# Train MAE:0.008973    Val MAE:0.008642    Test MAE:0.008775     Time:27.143960 s
# Epoch 45
# Train MAE:0.008918    Val MAE:0.008696    Test MAE:0.008743     Time:26.634923 s
# Epoch 46
# Train MAE:0.008906    Val MAE:0.009197    Test MAE:0.009310     Time:27.868018 s
# Epoch 47
# Train MAE:0.008904    Val MAE:0.008667    Test MAE:0.008782     Time:27.692387 s
# Epoch 48
# Train MAE:0.008885    Val MAE:0.009249    Test MAE:0.009252     Time:29.979983 s
# Epoch 49
# Train MAE:0.008913    Val MAE:0.008531    Test MAE:0.008632     Time:28.791202 s
# Epoch 50
# Train MAE:0.008876    Val MAE:0.009320    Test MAE:0.009423     Time:28.037013 s

# %%
with open("./result/RING_QM9_3.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# # OPV

# %%
from torch_geometric.seed import seed_everything


max_nodes=122
OPV=load_dataset("./dataset/OPV/OPV.csv","smile","homo","lumo")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 90823/90823 [17:22<00:00, 87.10it/s]

# %% [markdown]
# ### Exp 1

# %%
seed_everything(1222)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(OPV_train,batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

ringpool=RingPool(num_features)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.001)
loss_fn=MSELoss()

ringpool=ringpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.463740    Val MAE:0.272906    Test MAE:0.273274     Time:14.623544 s
# Epoch 2
# Train MAE:0.268637    Val MAE:0.260347    Test MAE:0.260564     Time:13.861656 s
# Epoch 3
# Train MAE:0.254833    Val MAE:0.238230    Test MAE:0.239736     Time:13.922180 s
# Epoch 4
# Train MAE:0.244952    Val MAE:0.248867    Test MAE:0.248675     Time:14.302477 s
# Epoch 5
# Train MAE:0.240523    Val MAE:0.234533    Test MAE:0.236960     Time:14.420443 s
# Epoch 6
# Train MAE:0.233552    Val MAE:0.222829    Test MAE:0.224555     Time:14.658813 s
# Epoch 7
# Train MAE:0.228031    Val MAE:0.212818    Test MAE:0.214743     Time:14.868886 s
# Epoch 8
# Train MAE:0.222601    Val MAE:0.212670    Test MAE:0.212905     Time:15.051206 s
# Epoch 9
# Train MAE:0.219167    Val MAE:0.203873    Test MAE:0.204314     Time:14.926129 s
# Epoch 10
# Train MAE:0.215982    Val MAE:0.226949    Test MAE:0.227929     Time:15.096057 s
# Epoch 11
# Train MAE:0.213571    Val MAE:0.198211    Test MAE:0.198082     Time:15.531018 s
# Epoch 12
# Train MAE:0.211996    Val MAE:0.198464    Test MAE:0.198308     Time:15.977497 s
# Epoch 13
# Train MAE:0.205291    Val MAE:0.204936    Test MAE:0.204661     Time:15.514573 s
# Epoch 14
# Train MAE:0.205307    Val MAE:0.193332    Test MAE:0.192879     Time:15.659026 s
# Epoch 15
# Train MAE:0.204858    Val MAE:0.195768    Test MAE:0.195459     Time:15.704242 s
# Epoch 16
# Train MAE:0.198693    Val MAE:0.238707    Test MAE:0.237759     Time:15.749446 s
# Epoch 17
# Train MAE:0.198013    Val MAE:0.196888    Test MAE:0.195739     Time:15.689073 s
# Epoch 18
# Train MAE:0.198319    Val MAE:0.209804    Test MAE:0.208140     Time:15.782012 s
# Epoch 19
# Train MAE:0.193574    Val MAE:0.187093    Test MAE:0.187259     Time:15.948106 s
# Epoch 20
# Train MAE:0.194063    Val MAE:0.187376    Test MAE:0.187177     Time:15.985530 s
# Epoch 21
# Train MAE:0.190844    Val MAE:0.194266    Test MAE:0.192057     Time:16.224630 s
# Epoch 22
# Train MAE:0.191709    Val MAE:0.186671    Test MAE:0.186072     Time:16.120179 s
# Epoch 23
# Train MAE:0.188944    Val MAE:0.180577    Test MAE:0.179548     Time:16.255067 s
# Epoch 24
# Train MAE:0.187672    Val MAE:0.177677    Test MAE:0.177137     Time:16.251786 s
# Epoch 25
# Train MAE:0.185171    Val MAE:0.177357    Test MAE:0.176686     Time:16.317700 s
# Epoch 26
# Train MAE:0.185645    Val MAE:0.183389    Test MAE:0.183449     Time:16.506912 s
# Epoch 27
# Train MAE:0.184909    Val MAE:0.178086    Test MAE:0.178537     Time:16.218281 s
# Epoch 28
# Train MAE:0.181807    Val MAE:0.175994    Test MAE:0.174169     Time:16.308420 s
# Epoch 29
# Train MAE:0.182708    Val MAE:0.182736    Test MAE:0.181746     Time:16.444694 s
# Epoch 30
# Train MAE:0.181889    Val MAE:0.180035    Test MAE:0.179401     Time:17.487247 s
# Epoch 31
# Train MAE:0.178924    Val MAE:0.179921    Test MAE:0.179834     Time:16.526564 s
# Epoch 32
# Train MAE:0.180746    Val MAE:0.178456    Test MAE:0.178479     Time:16.411279 s
# Epoch 33
# Train MAE:0.177262    Val MAE:0.172979    Test MAE:0.172759     Time:16.400757 s
# Epoch 34
# Train MAE:0.178563    Val MAE:0.182183    Test MAE:0.182193     Time:16.634427 s
# Epoch 35
# Train MAE:0.174862    Val MAE:0.172491    Test MAE:0.171617     Time:16.640624 s
# Epoch 36
# Train MAE:0.176521    Val MAE:0.171790    Test MAE:0.170891     Time:16.874439 s
# Epoch 37
# Train MAE:0.176118    Val MAE:0.170113    Test MAE:0.170120     Time:16.607220 s
# Epoch 38
# Train MAE:0.173028    Val MAE:0.171108    Test MAE:0.170054     Time:16.723821 s
# Epoch 39
# Train MAE:0.174244    Val MAE:0.164572    Test MAE:0.164403     Time:17.486825 s
# Epoch 40
# Train MAE:0.171344    Val MAE:0.191574    Test MAE:0.190917     Time:16.611370 s
# Epoch 41
# Train MAE:0.170833    Val MAE:0.176783    Test MAE:0.174771     Time:16.553293 s
# Epoch 42
# Train MAE:0.169851    Val MAE:0.162778    Test MAE:0.162365     Time:16.521010 s
# Epoch 43
# Train MAE:0.169429    Val MAE:0.169895    Test MAE:0.170214     Time:16.662212 s
# Epoch 44
# Train MAE:0.168792    Val MAE:0.174684    Test MAE:0.173804     Time:16.462320 s
# Epoch 45
# Train MAE:0.170146    Val MAE:0.162658    Test MAE:0.161989     Time:17.162460 s
# Epoch 46
# Train MAE:0.169033    Val MAE:0.165949    Test MAE:0.164961     Time:18.463694 s
# Epoch 47
# Train MAE:0.167765    Val MAE:0.160309    Test MAE:0.159618     Time:18.017740 s
# Epoch 48
# Train MAE:0.167008    Val MAE:0.206404    Test MAE:0.205660     Time:18.740577 s
# Epoch 49
# Train MAE:0.165979    Val MAE:0.160382    Test MAE:0.160171     Time:17.934560 s
# Epoch 50
# Train MAE:0.165011    Val MAE:0.157550    Test MAE:0.157360     Time:17.978631 s

# %%
epochs=50
train_loader=DataLoader(OPV_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.0005)
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.168288    Val MAE:0.159878    Test MAE:0.159696     Time:27.079040 s
# Epoch 2
# Train MAE:0.167340    Val MAE:0.171106    Test MAE:0.170451     Time:27.863184 s
# Epoch 3
# Train MAE:0.167158    Val MAE:0.194168    Test MAE:0.194500     Time:29.290803 s
# Epoch 4
# Train MAE:0.165629    Val MAE:0.164083    Test MAE:0.163156     Time:30.185520 s
# Epoch 5
# Train MAE:0.163798    Val MAE:0.169360    Test MAE:0.168595     Time:30.559797 s
# Epoch 6
# Train MAE:0.164453    Val MAE:0.156782    Test MAE:0.157076     Time:30.840491 s
# Epoch 7
# Train MAE:0.163372    Val MAE:0.157464    Test MAE:0.156279     Time:31.340067 s
# Epoch 8
# Train MAE:0.162661    Val MAE:0.159185    Test MAE:0.158306     Time:31.450239 s
# Epoch 9
# Train MAE:0.162580    Val MAE:0.158789    Test MAE:0.158027     Time:31.622804 s
# Epoch 10
# Train MAE:0.162184    Val MAE:0.158976    Test MAE:0.157627     Time:32.941289 s
# Epoch 11
# Train MAE:0.161591    Val MAE:0.158913    Test MAE:0.159282     Time:32.142270 s
# Epoch 12
# Train MAE:0.161091    Val MAE:0.158092    Test MAE:0.157175     Time:32.631785 s
# Epoch 13
# Train MAE:0.159791    Val MAE:0.160457    Test MAE:0.160205     Time:34.630132 s
# Epoch 14
# Train MAE:0.158698    Val MAE:0.170292    Test MAE:0.168217     Time:32.909506 s
# Epoch 15
# Train MAE:0.158659    Val MAE:0.151582    Test MAE:0.151720     Time:32.647673 s
# Epoch 16
# Train MAE:0.157435    Val MAE:0.150261    Test MAE:0.149587     Time:33.030905 s
# Epoch 17
# Train MAE:0.157478    Val MAE:0.156863    Test MAE:0.156991     Time:32.515617 s
# Epoch 18
# Train MAE:0.156597    Val MAE:0.157532    Test MAE:0.158216     Time:34.862621 s
# Epoch 19
# Train MAE:0.156943    Val MAE:0.157404    Test MAE:0.158115     Time:33.626462 s
# Epoch 20
# Train MAE:0.155579    Val MAE:0.150089    Test MAE:0.149918     Time:33.038649 s
# Epoch 21
# Train MAE:0.154590    Val MAE:0.163044    Test MAE:0.161205     Time:33.594812 s
# Epoch 22
# Train MAE:0.154788    Val MAE:0.152261    Test MAE:0.151996     Time:33.822658 s
# Epoch 23
# Train MAE:0.154536    Val MAE:0.147371    Test MAE:0.147499     Time:33.210433 s
# Epoch 24
# Train MAE:0.153613    Val MAE:0.154998    Test MAE:0.154478     Time:33.876227 s
# Epoch 25
# Train MAE:0.153015    Val MAE:0.148298    Test MAE:0.147915     Time:33.482081 s
# Epoch 26
# Train MAE:0.152145    Val MAE:0.183342    Test MAE:0.181457     Time:33.514122 s
# Epoch 27
# Train MAE:0.152632    Val MAE:0.144655    Test MAE:0.144711     Time:33.076887 s
# Epoch 28
# Train MAE:0.153238    Val MAE:0.180973    Test MAE:0.179472     Time:32.628316 s
# Epoch 29
# Train MAE:0.151536    Val MAE:0.148540    Test MAE:0.148114     Time:32.932161 s
# Epoch 30
# Train MAE:0.151452    Val MAE:0.145675    Test MAE:0.145587     Time:32.595396 s
# Epoch 31
# Train MAE:0.151178    Val MAE:0.144837    Test MAE:0.144103     Time:34.212559 s
# Epoch 32
# Train MAE:0.150350    Val MAE:0.145068    Test MAE:0.144693     Time:34.910571 s
# Epoch 33
# Train MAE:0.149961    Val MAE:0.146127    Test MAE:0.147053     Time:33.850692 s
# Epoch 34
# Train MAE:0.149277    Val MAE:0.144128    Test MAE:0.144352     Time:33.563185 s
# Epoch 35
# Train MAE:0.149683    Val MAE:0.145805    Test MAE:0.145282     Time:32.814624 s
# Epoch 36
# Train MAE:0.148883    Val MAE:0.159805    Test MAE:0.159064     Time:32.381541 s
# Epoch 37
# Train MAE:0.148902    Val MAE:0.149212    Test MAE:0.149234     Time:37.525235 s
# Epoch 38
# Train MAE:0.148206    Val MAE:0.142473    Test MAE:0.141649     Time:41.130700 s
# Epoch 39
# Train MAE:0.148123    Val MAE:0.143162    Test MAE:0.143482     Time:35.836135 s
# Epoch 40
# Train MAE:0.148080    Val MAE:0.138402    Test MAE:0.138524     Time:33.320242 s
# Epoch 41
# Train MAE:0.146651    Val MAE:0.150971    Test MAE:0.151310     Time:32.745010 s
# Epoch 42
# Train MAE:0.146955    Val MAE:0.143371    Test MAE:0.143561     Time:32.933456 s
# Epoch 43
# Train MAE:0.146212    Val MAE:0.154545    Test MAE:0.155280     Time:32.760279 s
# Epoch 44
# Train MAE:0.145302    Val MAE:0.146304    Test MAE:0.146085     Time:32.790107 s
# Epoch 45
# Train MAE:0.145687    Val MAE:0.148766    Test MAE:0.149495     Time:32.704019 s
# Epoch 46
# Train MAE:0.144213    Val MAE:0.154041    Test MAE:0.152689     Time:32.436193 s
# Epoch 47
# Train MAE:0.145289    Val MAE:0.141465    Test MAE:0.140948     Time:32.933989 s
# Epoch 48
# Train MAE:0.145352    Val MAE:0.141221    Test MAE:0.141656     Time:34.521258 s
# Epoch 49
# Train MAE:0.143811    Val MAE:0.166444    Test MAE:0.165614     Time:32.300958 s
# Epoch 50
# Train MAE:0.144074    Val MAE:0.156090    Test MAE:0.155568     Time:31.875269 s

# %%
with open("./result/RING_OPV_1.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 2

# %%
seed_everything(324)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(OPV_train,batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

ringpool=RingPool(num_features)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.001)
loss_fn=MSELoss()

ringpool=ringpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.429022    Val MAE:0.300691    Test MAE:0.301553     Time:13.447194 s
# Epoch 2
# Train MAE:0.288521    Val MAE:0.319651    Test MAE:0.321415     Time:13.913639 s
# Epoch 3
# Train MAE:0.276111    Val MAE:0.274477    Test MAE:0.276899     Time:14.488191 s
# Epoch 4
# Train MAE:0.265000    Val MAE:0.251078    Test MAE:0.252436     Time:14.391657 s
# Epoch 5
# Train MAE:0.257828    Val MAE:0.253336    Test MAE:0.255456     Time:14.358721 s
# Epoch 6
# Train MAE:0.247473    Val MAE:0.250327    Test MAE:0.251652     Time:14.676046 s
# Epoch 7
# Train MAE:0.243836    Val MAE:0.267534    Test MAE:0.267811     Time:14.811954 s
# Epoch 8
# Train MAE:0.238826    Val MAE:0.225351    Test MAE:0.226539     Time:15.077104 s
# Epoch 9
# Train MAE:0.231091    Val MAE:0.218678    Test MAE:0.219795     Time:15.164153 s
# Epoch 10
# Train MAE:0.228425    Val MAE:0.227664    Test MAE:0.228564     Time:15.462903 s
# Epoch 11
# Train MAE:0.223684    Val MAE:0.238134    Test MAE:0.240104     Time:16.733869 s
# Epoch 12
# Train MAE:0.219549    Val MAE:0.221241    Test MAE:0.222100     Time:17.498521 s
# Epoch 13
# Train MAE:0.215451    Val MAE:0.203532    Test MAE:0.203589     Time:16.224165 s
# Epoch 14
# Train MAE:0.210910    Val MAE:0.197326    Test MAE:0.198381     Time:16.568817 s
# Epoch 15
# Train MAE:0.208351    Val MAE:0.199879    Test MAE:0.200535     Time:16.533730 s
# Epoch 16
# Train MAE:0.205712    Val MAE:0.247623    Test MAE:0.248497     Time:16.672773 s
# Epoch 17
# Train MAE:0.205443    Val MAE:0.197610    Test MAE:0.198865     Time:16.473643 s
# Epoch 18
# Train MAE:0.201399    Val MAE:0.235151    Test MAE:0.236316     Time:16.274404 s
# Epoch 19
# Train MAE:0.198850    Val MAE:0.196197    Test MAE:0.197393     Time:16.162357 s
# Epoch 20
# Train MAE:0.198892    Val MAE:0.198566    Test MAE:0.199705     Time:16.562250 s
# Epoch 21
# Train MAE:0.195452    Val MAE:0.185903    Test MAE:0.187500     Time:17.545364 s
# Epoch 22
# Train MAE:0.193132    Val MAE:0.197415    Test MAE:0.199080     Time:16.600976 s
# Epoch 23
# Train MAE:0.193625    Val MAE:0.183521    Test MAE:0.183807     Time:16.913514 s
# Epoch 24
# Train MAE:0.191223    Val MAE:0.184055    Test MAE:0.184770     Time:17.195048 s
# Epoch 25
# Train MAE:0.190419    Val MAE:0.188933    Test MAE:0.189272     Time:16.598552 s
# Epoch 26
# Train MAE:0.193354    Val MAE:0.183689    Test MAE:0.185101     Time:16.479541 s
# Epoch 27
# Train MAE:0.191355    Val MAE:0.209643    Test MAE:0.209907     Time:16.583137 s
# Epoch 28
# Train MAE:0.187616    Val MAE:0.180238    Test MAE:0.181941     Time:16.855631 s
# Epoch 29
# Train MAE:0.189159    Val MAE:0.184636    Test MAE:0.185265     Time:17.111372 s
# Epoch 30
# Train MAE:0.184619    Val MAE:0.196867    Test MAE:0.198860     Time:18.220615 s
# Epoch 31
# Train MAE:0.184198    Val MAE:0.177708    Test MAE:0.178525     Time:18.533145 s
# Epoch 32
# Train MAE:0.184494    Val MAE:0.182603    Test MAE:0.183204     Time:17.980568 s
# Epoch 33
# Train MAE:0.180526    Val MAE:0.172515    Test MAE:0.173313     Time:17.606749 s
# Epoch 34
# Train MAE:0.180603    Val MAE:0.200446    Test MAE:0.201653     Time:17.317332 s
# Epoch 35
# Train MAE:0.181984    Val MAE:0.186151    Test MAE:0.186403     Time:17.632075 s
# Epoch 36
# Train MAE:0.179595    Val MAE:0.174172    Test MAE:0.174494     Time:18.227286 s
# Epoch 37
# Train MAE:0.178020    Val MAE:0.173739    Test MAE:0.173910     Time:17.287729 s
# Epoch 38
# Train MAE:0.177013    Val MAE:0.190889    Test MAE:0.192068     Time:16.923750 s
# Epoch 39
# Train MAE:0.177213    Val MAE:0.165314    Test MAE:0.166329     Time:16.806187 s
# Epoch 40
# Train MAE:0.175025    Val MAE:0.172343    Test MAE:0.171943     Time:17.371015 s
# Epoch 41
# Train MAE:0.174397    Val MAE:0.179001    Test MAE:0.179438     Time:16.837352 s
# Epoch 42
# Train MAE:0.172430    Val MAE:0.184271    Test MAE:0.185218     Time:17.087126 s
# Epoch 43
# Train MAE:0.173448    Val MAE:0.165155    Test MAE:0.165809     Time:17.039830 s
# Epoch 44
# Train MAE:0.170979    Val MAE:0.191444    Test MAE:0.192253     Time:17.010156 s
# Epoch 45
# Train MAE:0.168711    Val MAE:0.175221    Test MAE:0.175763     Time:17.075071 s
# Epoch 46
# Train MAE:0.167826    Val MAE:0.162849    Test MAE:0.163005     Time:17.638966 s
# Epoch 47
# Train MAE:0.169079    Val MAE:0.168175    Test MAE:0.169668     Time:17.728032 s
# Epoch 48
# Train MAE:0.169477    Val MAE:0.192765    Test MAE:0.193047     Time:17.666233 s
# Epoch 49
# Train MAE:0.167792    Val MAE:0.168272    Test MAE:0.168124     Time:18.049896 s
# Epoch 50
# Train MAE:0.164818    Val MAE:0.160398    Test MAE:0.160064     Time:17.459898 s

# %%
epochs=50
train_loader=DataLoader(OPV_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.0005)
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.168312    Val MAE:0.164667    Test MAE:0.164851     Time:33.878551 s
# Epoch 2
# Train MAE:0.166633    Val MAE:0.168454    Test MAE:0.168030     Time:33.366809 s
# Epoch 3
# Train MAE:0.166536    Val MAE:0.157458    Test MAE:0.157854     Time:32.655408 s
# Epoch 4
# Train MAE:0.164688    Val MAE:0.174030    Test MAE:0.173670     Time:32.770563 s
# Epoch 5
# Train MAE:0.164500    Val MAE:0.159631    Test MAE:0.159778     Time:33.474158 s
# Epoch 6
# Train MAE:0.162887    Val MAE:0.184623    Test MAE:0.184102     Time:35.108790 s
# Epoch 7
# Train MAE:0.161680    Val MAE:0.165758    Test MAE:0.165332     Time:34.022787 s
# Epoch 8
# Train MAE:0.161807    Val MAE:0.158806    Test MAE:0.158758     Time:34.750014 s
# Epoch 9
# Train MAE:0.161423    Val MAE:0.153813    Test MAE:0.154133     Time:34.189102 s
# Epoch 10
# Train MAE:0.158976    Val MAE:0.161532    Test MAE:0.162012     Time:34.751580 s
# Epoch 11
# Train MAE:0.159636    Val MAE:0.160561    Test MAE:0.160199     Time:34.672621 s
# Epoch 12
# Train MAE:0.158232    Val MAE:0.150386    Test MAE:0.149804     Time:33.968860 s
# Epoch 13
# Train MAE:0.157315    Val MAE:0.206299    Test MAE:0.205477     Time:32.936162 s
# Epoch 14
# Train MAE:0.156899    Val MAE:0.158966    Test MAE:0.158794     Time:32.988236 s
# Epoch 15
# Train MAE:0.156252    Val MAE:0.169650    Test MAE:0.169927     Time:32.721587 s
# Epoch 16
# Train MAE:0.154437    Val MAE:0.157690    Test MAE:0.157075     Time:33.184188 s
# Epoch 17
# Train MAE:0.154782    Val MAE:0.155395    Test MAE:0.154435     Time:33.549605 s
# Epoch 18
# Train MAE:0.153546    Val MAE:0.193035    Test MAE:0.191898     Time:34.952918 s
# Epoch 19
# Train MAE:0.153486    Val MAE:0.149782    Test MAE:0.149044     Time:33.182569 s
# Epoch 20
# Train MAE:0.152389    Val MAE:0.161901    Test MAE:0.161947     Time:33.455458 s
# Epoch 21
# Train MAE:0.151679    Val MAE:0.157325    Test MAE:0.157592     Time:33.697199 s
# Epoch 22
# Train MAE:0.151261    Val MAE:0.148546    Test MAE:0.148104     Time:33.797948 s
# Epoch 23
# Train MAE:0.150085    Val MAE:0.155143    Test MAE:0.153613     Time:32.817929 s
# Epoch 24
# Train MAE:0.149087    Val MAE:0.142551    Test MAE:0.141866     Time:34.304101 s
# Epoch 25
# Train MAE:0.150236    Val MAE:0.142932    Test MAE:0.142218     Time:32.615422 s
# Epoch 26
# Train MAE:0.148439    Val MAE:0.145218    Test MAE:0.144956     Time:35.623078 s
# Epoch 27
# Train MAE:0.148005    Val MAE:0.148811    Test MAE:0.148241     Time:33.638195 s
# Epoch 28
# Train MAE:0.146794    Val MAE:0.159530    Test MAE:0.159611     Time:32.809971 s
# Epoch 29
# Train MAE:0.146077    Val MAE:0.142393    Test MAE:0.141488     Time:33.065308 s
# Epoch 30
# Train MAE:0.146309    Val MAE:0.140733    Test MAE:0.139430     Time:32.435330 s
# Epoch 31
# Train MAE:0.146076    Val MAE:0.147553    Test MAE:0.146429     Time:32.969254 s
# Epoch 32
# Train MAE:0.145061    Val MAE:0.146195    Test MAE:0.146518     Time:32.446637 s
# Epoch 33
# Train MAE:0.144291    Val MAE:0.148007    Test MAE:0.147078     Time:32.135395 s
# Epoch 34
# Train MAE:0.143388    Val MAE:0.138626    Test MAE:0.137764     Time:32.432207 s
# Epoch 35
# Train MAE:0.143185    Val MAE:0.170293    Test MAE:0.168876     Time:32.987647 s
# Epoch 36
# Train MAE:0.142884    Val MAE:0.136643    Test MAE:0.135936     Time:32.667727 s
# Epoch 37
# Train MAE:0.141763    Val MAE:0.155984    Test MAE:0.154988     Time:32.065730 s
# Epoch 38
# Train MAE:0.141383    Val MAE:0.138431    Test MAE:0.137851     Time:32.193437 s
# Epoch 39
# Train MAE:0.141364    Val MAE:0.141130    Test MAE:0.139932     Time:32.519851 s
# Epoch 40
# Train MAE:0.139780    Val MAE:0.134890    Test MAE:0.134143     Time:35.361548 s
# Epoch 41
# Train MAE:0.139996    Val MAE:0.150070    Test MAE:0.149688     Time:35.502619 s
# Epoch 42
# Train MAE:0.140117    Val MAE:0.142904    Test MAE:0.142198     Time:35.022814 s
# Epoch 43
# Train MAE:0.138383    Val MAE:0.132217    Test MAE:0.130874     Time:33.208419 s
# Epoch 44
# Train MAE:0.138073    Val MAE:0.142544    Test MAE:0.141312     Time:31.998672 s
# Epoch 45
# Train MAE:0.137441    Val MAE:0.138651    Test MAE:0.137450     Time:31.781294 s
# Epoch 46
# Train MAE:0.136303    Val MAE:0.141790    Test MAE:0.140736     Time:32.056757 s
# Epoch 47
# Train MAE:0.137216    Val MAE:0.133532    Test MAE:0.132525     Time:32.670039 s
# Epoch 48
# Train MAE:0.134859    Val MAE:0.134937    Test MAE:0.132780     Time:32.484272 s
# Epoch 49
# Train MAE:0.134980    Val MAE:0.151571    Test MAE:0.150609     Time:32.384013 s
# Epoch 50
# Train MAE:0.134304    Val MAE:0.137161    Test MAE:0.135756     Time:32.083953 s

# %%
with open("./result/RING_OPV_2.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))

# %% [markdown]
# ### Exp 3

# %%
seed_everything(10086)
OPV_train,OPV_val,OPV_test=split_list(OPV,(0.8,0.1,0.1))

# %%
from torch_geometric.loader import DenseDataLoader,DataLoader

train_loader=DataLoader(OPV_train,batch_size=128, shuffle=True)
val_loader = DataLoader(OPV_val, batch_size=1024, shuffle=False)
test_loader = DataLoader(OPV_test, batch_size=1024, shuffle=False)
num_features=OPV_train[0].num_node_features

# %%
from torch.nn import MSELoss
import time

ringpool=RingPool(num_features)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.001)
loss_fn=MSELoss()

ringpool=ringpool.cuda()
loss_fn=loss_fn.cuda()

epochs=50
train_curve=[]
val_curve=[]
test_curve=[]
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.615568    Val MAE:0.298563    Test MAE:0.299125     Time:13.519033 s
# Epoch 2
# Train MAE:0.286755    Val MAE:0.269729    Test MAE:0.269793     Time:14.024954 s
# Epoch 3
# Train MAE:0.270946    Val MAE:0.288959    Test MAE:0.289749     Time:14.146966 s
# Epoch 4
# Train MAE:0.259993    Val MAE:0.260959    Test MAE:0.260486     Time:14.565308 s
# Epoch 5
# Train MAE:0.245817    Val MAE:0.237576    Test MAE:0.238443     Time:14.909628 s
# Epoch 6
# Train MAE:0.234588    Val MAE:0.230017    Test MAE:0.231555     Time:15.888103 s
# Epoch 7
# Train MAE:0.224737    Val MAE:0.218382    Test MAE:0.219459     Time:16.095260 s
# Epoch 8
# Train MAE:0.220774    Val MAE:0.240064    Test MAE:0.241218     Time:15.929678 s
# Epoch 9
# Train MAE:0.218673    Val MAE:0.210337    Test MAE:0.211236     Time:16.161938 s
# Epoch 10
# Train MAE:0.216538    Val MAE:0.213273    Test MAE:0.214093     Time:16.089619 s
# Epoch 11
# Train MAE:0.213102    Val MAE:0.213272    Test MAE:0.215014     Time:16.490868 s
# Epoch 12
# Train MAE:0.209192    Val MAE:0.201726    Test MAE:0.203258     Time:16.471502 s
# Epoch 13
# Train MAE:0.207132    Val MAE:0.204622    Test MAE:0.205315     Time:16.290312 s
# Epoch 14
# Train MAE:0.203780    Val MAE:0.221502    Test MAE:0.223391     Time:16.498091 s
# Epoch 15
# Train MAE:0.202566    Val MAE:0.197107    Test MAE:0.197649     Time:16.328473 s
# Epoch 16
# Train MAE:0.203440    Val MAE:0.190601    Test MAE:0.191894     Time:16.694420 s
# Epoch 17
# Train MAE:0.198498    Val MAE:0.196106    Test MAE:0.197365     Time:17.337794 s
# Epoch 18
# Train MAE:0.197491    Val MAE:0.201282    Test MAE:0.202182     Time:16.829956 s
# Epoch 19
# Train MAE:0.202860    Val MAE:0.204191    Test MAE:0.206056     Time:16.719297 s
# Epoch 20
# Train MAE:0.195977    Val MAE:0.192716    Test MAE:0.193843     Time:17.048826 s
# Epoch 21
# Train MAE:0.194541    Val MAE:0.188447    Test MAE:0.190170     Time:16.528649 s
# Epoch 22
# Train MAE:0.193562    Val MAE:0.187734    Test MAE:0.188738     Time:16.602149 s
# Epoch 23
# Train MAE:0.191669    Val MAE:0.188914    Test MAE:0.190754     Time:16.890396 s
# Epoch 24
# Train MAE:0.189764    Val MAE:0.193924    Test MAE:0.195110     Time:16.681031 s
# Epoch 25
# Train MAE:0.188534    Val MAE:0.185167    Test MAE:0.186369     Time:16.521564 s
# Epoch 26
# Train MAE:0.189574    Val MAE:0.182154    Test MAE:0.182941     Time:17.144433 s
# Epoch 27
# Train MAE:0.186720    Val MAE:0.180531    Test MAE:0.181309     Time:16.983257 s
# Epoch 28
# Train MAE:0.186368    Val MAE:0.183834    Test MAE:0.184979     Time:16.684673 s
# Epoch 29
# Train MAE:0.186520    Val MAE:0.179442    Test MAE:0.180119     Time:16.876360 s
# Epoch 30
# Train MAE:0.185674    Val MAE:0.176923    Test MAE:0.178264     Time:16.833132 s
# Epoch 31
# Train MAE:0.183013    Val MAE:0.187000    Test MAE:0.188627     Time:17.627308 s
# Epoch 32
# Train MAE:0.181930    Val MAE:0.179607    Test MAE:0.180551     Time:17.498543 s
# Epoch 33
# Train MAE:0.183942    Val MAE:0.189930    Test MAE:0.190732     Time:17.465128 s
# Epoch 34
# Train MAE:0.182452    Val MAE:0.183071    Test MAE:0.184345     Time:17.145799 s
# Epoch 35
# Train MAE:0.182157    Val MAE:0.178384    Test MAE:0.179985     Time:16.997454 s
# Epoch 36
# Train MAE:0.177462    Val MAE:0.196563    Test MAE:0.196484     Time:16.894917 s
# Epoch 37
# Train MAE:0.180000    Val MAE:0.234096    Test MAE:0.235475     Time:16.963219 s
# Epoch 38
# Train MAE:0.179885    Val MAE:0.177499    Test MAE:0.179379     Time:16.892809 s
# Epoch 39
# Train MAE:0.178543    Val MAE:0.170831    Test MAE:0.171907     Time:17.078612 s
# Epoch 40
# Train MAE:0.177678    Val MAE:0.172562    Test MAE:0.174020     Time:17.130830 s
# Epoch 41
# Train MAE:0.175553    Val MAE:0.175541    Test MAE:0.176082     Time:17.838585 s
# Epoch 42
# Train MAE:0.176511    Val MAE:0.174664    Test MAE:0.175588     Time:17.161010 s
# Epoch 43
# Train MAE:0.175223    Val MAE:0.171018    Test MAE:0.171962     Time:16.980760 s
# Epoch 44
# Train MAE:0.173710    Val MAE:0.168141    Test MAE:0.169014     Time:16.745178 s
# Epoch 45
# Train MAE:0.172629    Val MAE:0.177462    Test MAE:0.177734     Time:16.952196 s
# Epoch 46
# Train MAE:0.173404    Val MAE:0.181111    Test MAE:0.182058     Time:17.145214 s
# Epoch 47
# Train MAE:0.172417    Val MAE:0.172830    Test MAE:0.172539     Time:17.056174 s
# Epoch 48
# Train MAE:0.172650    Val MAE:0.168415    Test MAE:0.169374     Time:17.158254 s
# Epoch 49
# Train MAE:0.172275    Val MAE:0.169630    Test MAE:0.169555     Time:17.089601 s
# Epoch 50
# Train MAE:0.167220    Val MAE:0.173880    Test MAE:0.174749     Time:16.892822 s

# %%
epochs=50
train_loader=DataLoader(OPV_train,batch_size=32, shuffle=True)
optimizer=torch.optim.Adam(params=ringpool.parameters(), lr=0.0005)
for i in range(1,epochs+1):
    t_start=time.time()
    ringpool,train_mae = train(ringpool, train_loader, optimizer, loss_fn)
    val_mae=test(ringpool,val_loader)
    test_mae=test(ringpool,test_loader)
    t_end=time.time()
    print("Epoch %d"%i)
    print("Train MAE:%f    Val MAE:%f    Test MAE:%f     Time:%f s"%(train_mae,val_mae,test_mae,t_end-t_start))
    
    train_curve.append(train_mae)
    val_curve.append(val_mae)
    test_curve.append(test_mae)
# Out:
# Epoch 1
# Train MAE:0.172753    Val MAE:0.184926    Test MAE:0.185749     Time:28.345949 s
# Epoch 2
# Train MAE:0.171670    Val MAE:0.165159    Test MAE:0.165924     Time:29.357146 s
# Epoch 3
# Train MAE:0.170395    Val MAE:0.169529    Test MAE:0.169977     Time:31.037376 s
# Epoch 4
# Train MAE:0.168680    Val MAE:0.160409    Test MAE:0.161362     Time:31.696175 s
# Epoch 5
# Train MAE:0.168975    Val MAE:0.166046    Test MAE:0.166636     Time:31.062864 s
# Epoch 6
# Train MAE:0.168868    Val MAE:0.168323    Test MAE:0.168680     Time:31.506913 s
# Epoch 7
# Train MAE:0.167076    Val MAE:0.192197    Test MAE:0.194540     Time:33.320707 s
# Epoch 8
# Train MAE:0.167173    Val MAE:0.180786    Test MAE:0.182133     Time:36.029058 s
# Epoch 9
# Train MAE:0.165743    Val MAE:0.164239    Test MAE:0.165466     Time:34.717663 s
# Epoch 10
# Train MAE:0.166300    Val MAE:0.161557    Test MAE:0.162387     Time:33.749334 s
# Epoch 11
# Train MAE:0.165078    Val MAE:0.162651    Test MAE:0.163451     Time:32.722123 s
# Epoch 12
# Train MAE:0.164506    Val MAE:0.164991    Test MAE:0.165120     Time:33.174069 s
# Epoch 13
# Train MAE:0.163929    Val MAE:0.166594    Test MAE:0.167259     Time:33.354431 s
# Epoch 14
# Train MAE:0.163780    Val MAE:0.158785    Test MAE:0.159153     Time:32.336929 s
# Epoch 15
# Train MAE:0.164360    Val MAE:0.159372    Test MAE:0.160872     Time:32.231791 s
# Epoch 16
# Train MAE:0.162472    Val MAE:0.167910    Test MAE:0.168671     Time:34.624375 s
# Epoch 17
# Train MAE:0.162187    Val MAE:0.155936    Test MAE:0.157144     Time:32.958470 s
# Epoch 18
# Train MAE:0.162540    Val MAE:0.157929    Test MAE:0.158964     Time:33.048426 s
# Epoch 19
# Train MAE:0.161265    Val MAE:0.155272    Test MAE:0.156885     Time:33.590952 s
# Epoch 20
# Train MAE:0.161632    Val MAE:0.164998    Test MAE:0.166356     Time:32.269304 s
# Epoch 21
# Train MAE:0.160318    Val MAE:0.154094    Test MAE:0.154978     Time:32.033358 s
# Epoch 22
# Train MAE:0.159772    Val MAE:0.154391    Test MAE:0.155177     Time:31.912961 s
# Epoch 23
# Train MAE:0.159642    Val MAE:0.162825    Test MAE:0.164767     Time:32.499433 s
# Epoch 24
# Train MAE:0.159285    Val MAE:0.187154    Test MAE:0.186878     Time:31.782874 s
# Epoch 25
# Train MAE:0.157829    Val MAE:0.156418    Test MAE:0.158494     Time:31.860062 s
# Epoch 26
# Train MAE:0.158065    Val MAE:0.158015    Test MAE:0.158586     Time:32.374930 s
# Epoch 27
# Train MAE:0.157909    Val MAE:0.151574    Test MAE:0.152230     Time:32.684942 s
# Epoch 28
# Train MAE:0.157178    Val MAE:0.165304    Test MAE:0.166796     Time:33.938426 s
# Epoch 29
# Train MAE:0.157610    Val MAE:0.153888    Test MAE:0.154826     Time:34.372182 s
# Epoch 30
# Train MAE:0.156656    Val MAE:0.148826    Test MAE:0.150005     Time:34.247795 s
# Epoch 31
# Train MAE:0.156190    Val MAE:0.161484    Test MAE:0.162148     Time:32.724010 s
# Epoch 32
# Train MAE:0.154974    Val MAE:0.162330    Test MAE:0.164328     Time:34.534595 s
# Epoch 33
# Train MAE:0.155462    Val MAE:0.150139    Test MAE:0.151044     Time:33.981691 s
# Epoch 34
# Train MAE:0.155214    Val MAE:0.153784    Test MAE:0.155179     Time:32.846359 s
# Epoch 35
# Train MAE:0.154378    Val MAE:0.162972    Test MAE:0.165188     Time:32.551846 s
# Epoch 36
# Train MAE:0.153374    Val MAE:0.150345    Test MAE:0.151204     Time:32.702330 s
# Epoch 37
# Train MAE:0.153090    Val MAE:0.152226    Test MAE:0.152984     Time:34.123055 s
# Epoch 38
# Train MAE:0.152952    Val MAE:0.152002    Test MAE:0.152491     Time:33.615744 s
# Epoch 39
# Train MAE:0.152039    Val MAE:0.154083    Test MAE:0.154488     Time:33.569604 s
# Epoch 40
# Train MAE:0.152932    Val MAE:0.149290    Test MAE:0.150545     Time:33.759686 s
# Epoch 41
# Train MAE:0.151133    Val MAE:0.160823    Test MAE:0.162479     Time:33.923690 s
# Epoch 42
# Train MAE:0.150932    Val MAE:0.150049    Test MAE:0.151313     Time:34.151198 s
# Epoch 43
# Train MAE:0.150520    Val MAE:0.147591    Test MAE:0.148126     Time:34.511936 s
# Epoch 44
# Train MAE:0.151817    Val MAE:0.148719    Test MAE:0.149749     Time:35.837992 s
# Epoch 45
# Train MAE:0.150228    Val MAE:0.156643    Test MAE:0.157886     Time:36.266386 s
# Epoch 46
# Train MAE:0.150384    Val MAE:0.145208    Test MAE:0.145723     Time:33.763070 s
# Epoch 47
# Train MAE:0.149920    Val MAE:0.144498    Test MAE:0.145611     Time:34.799216 s
# Epoch 48
# Train MAE:0.149345    Val MAE:0.147230    Test MAE:0.148062     Time:33.571199 s
# Epoch 49
# Train MAE:0.149118    Val MAE:0.140777    Test MAE:0.141335     Time:33.590332 s
# Epoch 50
# Train MAE:0.148072    Val MAE:0.144999    Test MAE:0.146007     Time:33.960049 s

# %%
with open("./result/RING_OPV_3.csv","w") as fo:
    fo.write("epoch,train,val,test\n")
    for i in range(len(train_curve)):
        fo.write("%d,%f,%f,%f\n"%(i+1,train_curve[i],val_curve[i],test_curve[i]))
